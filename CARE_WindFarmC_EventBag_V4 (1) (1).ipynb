# %% [markdown]
# # CARE Wind Farm C — Event-Level Early Fault Detection (Event-Bag / V4)
#
# Protocol `CARE_C_EVENT_MIL_V4`. This is a corrected rebuild of the earlier
# `CARE_C_NATIVE_EVENT_MSWT_V3` benchmark.
#
# ## Read this before running
#
# **This notebook does not guarantee excellent metrics, and no notebook can.** The
# achievable ceiling is set by the data: 58 events from 22 turbines, with the label
# attached to a prediction frame that averages ~375 h. What the changes below do is
# remove the mechanisms by which V3 was demonstrably *losing* signal, and remove the
# mechanisms by which it may have been *gaining fake* signal. Whether that produces
# strong numbers is an empirical question this notebook answers honestly, including
# printing a refusal to claim SOTA when the ranking does not support it.
#
# ## What changed from V3, and why
#
# **Objective/metric mismatch (largest effect).** V3 trained window-level BCE but scored
# events with top-10% pooling. A window 300 h before a fault was labelled `1` and pushed
# toward 1 by the loss, which degrades exactly the direction the top-10% aggregate needs.
# V4 trains at the event-bag level:
#
# ```
# bag_logit = mean(top-k window logits),  k/K = 0.10
# L = BCE(bag_logit, y_event) + 0.3 * BCE(window_logits, 0) on normal events only
# ```
#
# The first term optimises the statistic that is thresholded at test time. The second
# exploits the asymmetry V3 ignored: every window in a normal event is a genuine negative,
# whereas most windows in an anomaly event are not genuine positives.
#
# **A 10-hour window cannot see a degradation trend.** V4 adds a multi-horizon
# baseline-deviation context vector: trailing means of every channel over 1 d / 7 d / 30 d
# in the same robust units, through a small MLP branch. Every model in the main comparison
# receives it, so the proposed model has no structural advantage; `use_ctx=False` appears
# only as ablation rung A4.
#
# **Normalisation artefacts.** When a channel was near-constant in the baseline year, V3's
# `scale` fell back to `1.0` and values saturated at ±12. Which channels saturated differed
# per event, so those columns acted as a turbine fingerprint. V4 clips at ±8, records the
# degeneracy, and drops channels that are degenerate in >20% of events, that behave as
# cumulative counters, or whose *clipping rate alone* predicts the label.
#
# **Selection on noise.** V3 early-stopped on validation event PR-AUC over 6 positives,
# which takes a handful of discrete values, with `PATIENCE=3` and `MAX_EPOCHS=12` — so most
# runs stopped mid-anneal. V4 uses `0.7 * event ROC-AUC + 0.3 * window ROC-AUC` on inner
# validation, EMA weights, warmup + full cosine, 40 epochs, patience 8.
#
# **Statistical power.** V3 reported 13 test events (6 positive), where recall is quantised
# at 1/6. V4's primary evaluation is 5-fold asset-grouped nested CV over all 58 events
# (27 positive), with the threshold taken from each fold's own inner validation. The frozen
# 32/13/13 split is retained as a secondary result. Confidence intervals use a cluster
# bootstrap over **assets**, because events from one turbine are not independent.
#
# **Bugs fixed.** Endpoint underflow crash in the cache; `torch.load` without
# `weights_only`; "predict everything positive" being a legal threshold candidate;
# DataLoader worker forks of the whole dataset; event-count bootstrap on 4 test assets;
# duplicated and truncated figure cells; hardcoded confusion-matrix and lead-time numbers.
#
# ## Honesty constraints
#
# - Every choice here — architecture, epochs, threshold, aggregation, hygiene tolerances —
#   must be fixed from inner validation folds only. Decide the design, run it once, report
#   what it says. The moment you tune against the pooled 58-event numbers, the confidence
#   intervals and any SOTA statement become invalid.
# - The independent test units are **events** (58 out-of-fold, 27 positive). Window counts
#   are repeated, overlapping observations of those events and must never be reported as a
#   sample size.
# - The named modern architectures are task adaptations under one common CARE protocol, not
#   byte-identical reproductions of external repositories.
#
# ## Before the first run
#
# Delete or rename any existing `cache_CARE_C_EVENT_MIL_V4` directory. The npz layout
# gained a `ctx` key and stale files will raise `KeyError`.

# %%
# CELL 1 — Imports and fixed protocol

import os, gc, json, math, random, warnings, hashlib
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    average_precision_score, roc_auc_score,
    precision_recall_curve, roc_curve,
    precision_score, recall_score, f1_score,
    matthews_corrcoef, balanced_accuracy_score,
    accuracy_score, confusion_matrix
)

import torch
import torch.nn as nn
import torch.nn.functional as F

warnings.filterwarnings("ignore")

PROTOCOL_VERSION = "CARE_C_EVENT_MIL_V4"

SEEDS = [42, 123, 2026]

LOOKBACK = 60                        # 10 h at 10-min resolution
HEALTHY_STATUS_IDS = {0, 2}          # filtering/calibration only, never a model input

# --- normalisation hygiene -----------------------------------------------------------
CLIP = 8.0                           # was 12: +/-12 saturation was fingerprinting events
DEGEN_TOL = 1e-5
DEGEN_MAX_EVENT_FRAC = 0.20          # drop a channel degenerate in >20% of events
RAMP_TOL = 0.90                      # drop cumulative-counter channels
SAT_AUC_TOL = 0.75                   # drop channels whose clip rate alone predicts the label

# --- multi-horizon baseline-deviation context ----------------------------------------
CTX_HORIZONS = (144, 1008, 4320)     # 1 day, 7 days, 30 days

# --- event-bag (MIL) training --------------------------------------------------------
K_PER_BAG = 32
BAGS_PER_CLASS = 6
TOP_FRACTION = 0.10                  # k/K at train == tail quantile at eval
LAMBDA_NEG = 0.3                     # clean-negative window supervision weight

STEPS_PER_EPOCH = 60
MAX_EPOCHS = 40
WARMUP_EPOCHS = 3
PATIENCE = 8
VAL_STRIDE = 6                       # per-epoch validation subsampling: 1 window / hour
EMA_DECAY = 0.998

LR = 8e-4
WEIGHT_DECAY = 0.03
DROPOUT = 0.25
D_MODEL = 64

AUG_CHAN_DROP = 0.10
AUG_JITTER = 0.05
AUG_TIME_MASK = 8

EVAL_CHUNK = 4096                    # windows per forward pass at eval time

# --- evaluation protocol -------------------------------------------------------------
N_FOLDS = 5
OP_WINDOW = 36                       # rolling 6 h
OP_TAIL_Q = 0.90                     # tail quantile of the rolling risk, not its max

# Set True only when you are certain the checkpoints on disk match these hyperparameters.
RESUME_FROM_CHECKPOINTS = False

# --- runtime budget ------------------------------------------------------------------
# A0 and A3 are architecturally identical to "Plain Transformer" and to the proposed
# model, so by default the ablation reuses those runs instead of retraining them.
REUSE_A0_A3 = True
ABLATION_SEEDS = [42]            # the ladder is a relative comparison; 1 seed is enough

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEV = DEVICE

random.seed(SEEDS[0])
np.random.seed(SEEDS[0])
torch.manual_seed(SEEDS[0])
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEEDS[0])

plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Liberation Serif", "DejaVu Serif", "Times New Roman"],
    "font.size": 12, "axes.titlesize": 14, "axes.labelsize": 14,
    "xtick.labelsize": 11, "ytick.labelsize": 11, "legend.fontsize": 9.5,
    "axes.linewidth": 1.0, "lines.linewidth": 2.0,
    "figure.dpi": 130, "savefig.dpi": 600,
    "pdf.fonttype": 42, "ps.fonttype": 42,
})

PROPOSED = "MS-WTFormer (Proposed)"

print("=" * 100)
print("CARE WIND FARM C — EVENT-BAG BENCHMARK")
print("=" * 100)
print("Protocol :", PROTOCOL_VERSION)
print("Device   :", DEVICE)
print("Seeds    :", SEEDS)
print("Objective: event-bag MIL, top-%d%% window logits" % int(TOP_FRACTION * 100))
# Out:
# ====================================================================================================
# CARE WIND FARM C — EVENT-BAG BENCHMARK
# ====================================================================================================
# Protocol : CARE_C_EVENT_MIL_V4
# Device   : cuda
# Seeds    : [42, 123, 2026]
# Objective: event-bag MIL, top-10% window logits

# %%
# CELL 2 — Mount Drive and locate the fully extracted CARE dataset
#
# UNCHANGED from the original notebook. Because PROTOCOL_VERSION changed in CELL 1,
# RESULT / CACHE_DIR / CKPT_DIR now resolve to *_CARE_C_EVENT_MIL_V4 and the previous
# V3 outputs are left intact.

from google.colab import drive

MOUNT = Path("/content/gdrive_care_final")

if not (MOUNT / "MyDrive").exists():
    drive.mount(str(MOUNT))
else:
    print("Google Drive already mounted.")

BASE = MOUNT / "MyDrive" / "Tarun" / "new dataset"
EXTRACT_ROOT = BASE / "CARE_To_Compare"
PROJECT = BASE / "CARE_WindFarmC_Project"

assert EXTRACT_ROOT.exists(), f"Missing extracted folder: {EXTRACT_ROOT}"

wind_c_candidates = [
    p for p in EXTRACT_ROOT.rglob("*")
    if p.is_dir() and p.name.strip().lower() == "wind farm c"
]

assert wind_c_candidates, "Wind Farm C was not found below CARE_To_Compare."
WFC = wind_c_candidates[0]

EVENT_INFO_PATH = WFC / "event_info.csv"
FEATURE_DESCRIPTION_PATH = WFC / "feature_description.csv"
DATASET_DIR = WFC / "datasets"

assert EVENT_INFO_PATH.exists()
assert FEATURE_DESCRIPTION_PATH.exists()
assert DATASET_DIR.exists()

RESULT = PROJECT / f"results_{PROTOCOL_VERSION}"
CACHE_DIR = PROJECT / f"cache_{PROTOCOL_VERSION}"
CKPT_DIR = RESULT / "checkpoints"

for d in [PROJECT, RESULT, CACHE_DIR, CKPT_DIR]:
    d.mkdir(parents=True, exist_ok=True)

print("Wind Farm C  :", WFC)
print("Result dir   :", RESULT)
print("Cache dir    :", CACHE_DIR)
print("Checkpoints  :", CKPT_DIR)
# Out:
# Mounted at /content/gdrive_care_final
# Wind Farm C  : /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_To_Compare/CARE_To_Compare/Wind Farm C
# Result dir   : /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4
# Cache dir    : /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/cache_CARE_C_EVENT_MIL_V4
# Checkpoints  : /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4/checkpoints

# %%
# CELL 3 — Verify the exact extracted schema
#
# UNCHANGED from the original notebook. The feature_description preview at the end is
# new: use it to confirm that the channels dropped by CELL 5B are counters/accumulators
# rather than physically meaningful sensors.

def read_auto(path, **kwargs):
    df = pd.read_csv(path, sep=";", **kwargs)
    if df.shape[1] == 1:
        df = pd.read_csv(path, sep=",", **kwargs)
    return df

raw_event_info = read_auto(EVENT_INFO_PATH)

required_event_cols = {"asset_id", "event_id", "event_label", "event_start", "event_end"}
assert required_event_cols.issubset(raw_event_info.columns)

raw_event_info["event_id"] = pd.to_numeric(raw_event_info["event_id"]).astype(int)
raw_event_info["asset_id"] = raw_event_info["asset_id"].astype(str)
raw_event_info["event_label"] = raw_event_info["event_label"].astype(str).str.lower().str.strip()
raw_event_info["is_anomaly"] = raw_event_info["event_label"].eq("anomaly")
raw_event_info["event_start_dt"] = pd.to_datetime(raw_event_info["event_start"])
raw_event_info["event_end_dt"] = pd.to_datetime(raw_event_info["event_end"])

event_files = sorted(
    [p for p in DATASET_DIR.glob("*.csv") if p.stem.isdigit()],
    key=lambda p: int(p.stem)
)

assert len(raw_event_info) == 58, len(raw_event_info)
assert len(event_files) == 58, len(event_files)
assert int(raw_event_info["is_anomaly"].sum()) == 27
assert int((~raw_event_info["is_anomaly"]).sum()) == 31
assert raw_event_info["asset_id"].nunique() == 22
assert {int(p.stem) for p in event_files} == set(raw_event_info["event_id"].tolist())

headers = {int(p.stem): read_auto(p, nrows=0).columns.tolist() for p in event_files}
assert set(len(x) for x in headers.values()) == {957}

common_cols = set(next(iter(headers.values())))
for cols in headers.values():
    common_cols &= set(cols)
assert len(common_cols) == 957

reference_cols = headers[next(iter(headers))]
AVG_FEATURES = [c for c in reference_cols if c.lower().endswith("_avg") and c in common_cols]

NF = len(AVG_FEATURES)
assert NF == 238, f"Expected 238 common Avg features, got {NF}"

for c in ["time_stamp", "asset_id", "id", "train_test", "status_type_id"]:
    assert c in common_cols, f"Missing metadata column {c}"

print("Events             :", len(raw_event_info))
print("Anomaly / normal   :", int(raw_event_info.is_anomaly.sum()), "/",
      int((~raw_event_info.is_anomaly).sum()))
print("Assets             :", raw_event_info.asset_id.nunique())
print("Columns/event CSV  :", len(reference_cols))
print("Common Avg features:", NF)

print("\nFEATURE DESCRIPTION (first 20 rows)")
print(read_auto(FEATURE_DESCRIPTION_PATH).head(20).to_string(index=False))
# Out:
# Events             : 58
# Anomaly / normal   : 27 / 31
# Assets             : 22
# Columns/event CSV  : 957
# Common Avg features: 238
#
# FEATURE DESCRIPTION (first 20 rows)
# sensor_name                 statistics_type                         description    unit  is_angle  is_counter
#    sensor_0 maximum,minimum,std_dev,average                ABB-LS Input K1, IL1       A     False       False
#    sensor_1 maximum,minimum,std_dev,average              Generator acceleration   rpm/s     False       False
#     power_2 average,maximum,std_dev,minimum                 ABB-LS Active Power      kW     False       False
#    sensor_3 average,maximum,minimum,std_dev       Active power aeration motor A       %     False       False
#    sensor_4 average,maximum,minimum,std_dev       Active power aeration motor B       %     False       False
#     power_5 average,maximum,minimum,std_dev    Active power grid side converter      kW     False       False
#     power_6 average,maximum,minimum,std_dev                Active power HV grid      kW     False       False
#    sensor_7 average,maximum,minimum,std_dev                 Ambient temperature Celsius     False       False
#    sensor_8 average,maximum,minimum,std_dev               Generator angle speed   rad/s     False       False
#    sensor_9 average,maximum,minimum,std_dev                    Battery charge 1       A     False       False
#   sensor_10 average,maximum,minimum,std_dev                    Battery charge 2       A     False       False
#   sensor_11 average,maximum,minimum,std_dev                    Battery charge 3       A     False       False
#   sensor_12 average,maximum,minimum,std_dev    Battery discharge current axis 1       A     False       False
#   sensor_13 average,maximum,minimum,std_dev    Battery discharge current axis 2       A     False       False
#   sensor_14 average,minimum,std_dev,maximum    Battery discharge current axis 3       A     False       False
#   sensor_15 average,maximum,minimum,std_dev                   Board temperature Celsius     False       False
#   sensor_16 average,maximum,minimum,std_dev    Compensation angle I/U converter     deg      True       False
#    power_17 average,minimum,std_dev,maximum              Active power converter      kW     False       False
#   sensor_18 average,maximum,minimum,std_dev Generator cooling air temperature A Celsius     False       False
#   sensor_19 average,maximum,minimum,std_dev Generator cooling air temperature B Celsius     False       False

# %%
# CELL 4 — Frozen asset-disjoint split (SECONDARY) + asset folds (PRIMARY)
#
# The first half is UNCHANGED: the frozen 32/13/13 split is retained, but it is now the
# SECONDARY result. The primary evaluation is the 5-fold asset-grouped CV appended at
# the bottom of this cell, which uses all 58 events (27 positives) instead of 13 (6).

LEGACY_SPLIT = PROJECT / "results_final_6h" / "event_split.csv"
FROZEN_SPLIT = RESULT / "event_split.csv"

def verify_split(df):
    assert set(df["split"].unique()) == {"train", "val", "test"}
    assets = {s: set(df.loc[df.split == s, "asset_id"].astype(str))
              for s in ["train", "val", "test"]}
    assert assets["train"].isdisjoint(assets["val"])
    assert assets["train"].isdisjoint(assets["test"])
    assert assets["val"].isdisjoint(assets["test"])
    for s in ["train", "val", "test"]:
        x = df[df.split == s]
        assert x["is_anomaly"].any(), f"{s} contains no anomaly event"
        assert (~x["is_anomaly"]).any(), f"{s} contains no normal event"
    return assets

_V3_SPLIT = PROJECT / "results_CARE_C_NATIVE_EVENT_MSWT_V3" / "event_split.csv"

if FROZEN_SPLIT.exists():
    saved = pd.read_csv(FROZEN_SPLIT)
    event_info = raw_event_info.merge(
        saved[["event_id", "split"]].drop_duplicates(), on="event_id", how="left")
    split_source = "existing V4 split"
elif _V3_SPLIT.exists():
    saved = pd.read_csv(_V3_SPLIT)
    event_info = raw_event_info.merge(
        saved[["event_id", "split"]].drop_duplicates(), on="event_id", how="left")
    split_source = "V3 split (carried over so the secondary result stays comparable)"
elif LEGACY_SPLIT.exists():
    saved = pd.read_csv(LEGACY_SPLIT)
    event_info = raw_event_info.merge(
        saved[["event_id", "split"]].drop_duplicates(), on="event_id", how="left")
    split_source = "previous asset-disjoint split"
else:
    rng = np.random.default_rng(20260824)
    assets_all = raw_event_info["asset_id"].unique().tolist()
    best = None
    for _ in range(20000):
        perm = rng.permutation(assets_all)
        aset = {"train": set(perm[:14]), "val": set(perm[14:18]), "test": set(perm[18:22])}
        temp = raw_event_info.copy()
        temp["split"] = temp["asset_id"].map(
            lambda a: "train" if a in aset["train"] else ("val" if a in aset["val"] else "test"))
        ok = True
        for s in ["train", "val", "test"]:
            z = temp[temp.split == s]
            if len(z) == 0 or z.is_anomaly.sum() == 0 or (~z.is_anomaly).sum() == 0:
                ok = False
                break
        if not ok:
            continue
        targets = {"train": 32, "val": 13, "test": 13}
        score = 0.0
        for s in ["train", "val", "test"]:
            z = temp[temp.split == s]
            score += abs(len(z) - targets[s])
            score += 4 * abs(z.is_anomaly.mean() - raw_event_info.is_anomaly.mean())
        if best is None or score < best[0]:
            best = (score, temp)
    assert best is not None
    event_info = best[1]
    split_source = "deterministically generated asset-disjoint split"

assert event_info["split"].notna().all()
assets = verify_split(event_info)
event_info.to_csv(FROZEN_SPLIT, index=False)

print("Split source:", split_source)
for s in ["train", "val", "test"]:
    x = event_info[event_info.split == s]
    print(f"{s.upper():5s}: events={len(x):2d} | anomaly={int(x.is_anomaly.sum()):2d} | "
          f"normal={int((~x.is_anomaly).sum()):2d} | assets={x.asset_id.nunique():2d}")
print("\nAsset overlap checks: PASS\n")
print("-" * 80)

def asset_folds(event_frame, n_splits=N_FOLDS, seed=20260824):
    """
    Asset-grouped folds. Assets containing at least one anomaly event and assets
    containing none are dealt out separately so every fold has both classes.
    """
    ag = (event_frame.assign(lab=event_frame["is_anomaly"].astype(int))
                     .groupby("asset_id")
                     .agg(n=("lab", "size"), pos=("lab", "sum"))
                     .reset_index())
    ag["has_pos"] = ag["pos"] > 0
    rng = np.random.default_rng(seed)
    folds = [[] for _ in range(n_splits)]
    for grp in (ag[ag.has_pos], ag[~ag.has_pos]):
        for i, a in enumerate(rng.permutation(grp.asset_id.to_numpy())):
            folds[i % n_splits].append(str(a))
    return [set(f) for f in folds]


FOLDS = asset_folds(event_info)

print("ASSET-GROUPED FOLDS (primary evaluation, all 58 events)")
ok = True
for i, f in enumerate(FOLDS):
    sub = event_info[event_info.asset_id.isin(f)]
    n_a, n_n = int(sub.is_anomaly.sum()), int((~sub.is_anomaly).sum())
    ok &= (n_a > 0 and n_n > 0)
    print(f"  fold {i}: assets={len(f):2d} events={len(sub):2d} anomaly={n_a:2d} normal={n_n:2d}")
assert ok, "a fold has only one class - change the seed in asset_folds()"

pd.DataFrame([{"fold": i, "asset_id": a} for i, f in enumerate(FOLDS) for a in sorted(f)]
             ).to_csv(RESULT / "asset_folds.csv", index=False)
print("saved:", RESULT / "asset_folds.csv")
# Out:
# Split source: existing V4 split
# TRAIN: events=32 | anomaly=15 | normal=17 | assets=14
# VAL  : events=13 | anomaly= 6 | normal= 7 | assets= 4
# TEST : events=13 | anomaly= 6 | normal= 7 | assets= 4
#
# Asset overlap checks: PASS
#
# --------------------------------------------------------------------------------
# ASSET-GROUPED FOLDS (primary evaluation, all 58 events)
#   fold 0: assets= 5 events=13 anomaly= 6 normal= 7
#   fold 1: assets= 5 events=12 anomaly= 5 normal= 7
#   fold 2: assets= 5 events=17 anomaly= 8 normal= 9
#   fold 3: assets= 4 events= 8 anomaly= 4 normal= 4
#   fold 4: assets= 3 events= 8 anomaly= 4 normal= 4
# saved: /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4/asset_folds.csv

# %% [markdown]
# ---
# ### Checkpoint 1
#
# Read the printed fold table above. **Every fold must contain at least one anomaly and one
# normal event.** If not, change the `seed` argument to `asset_folds`.

# %%
# CELL 5 — Preprocess/cache each event (hygiene flags + 1d/7d/30d context)

def mask_train(series):
    return series.astype(str).str.lower().str.strip().eq("train").to_numpy()


def mask_prediction(series):
    return series.astype(str).str.lower().str.strip().eq("prediction").to_numpy()


def valid_continuity(times, lookback=LOOKBACK):
    """True where the trailing `lookback` samples contain no gap and no reversal."""
    t = pd.Series(times)
    d = t.diff().dt.total_seconds().to_numpy()

    bad = np.zeros(len(t), dtype=np.int64)
    bad[1:] = ((~np.isfinite(d[1:])) | (d[1:] <= 0) | (d[1:] > 20 * 60)).astype(np.int64)

    cs = np.cumsum(bad)
    good = np.zeros(len(t), dtype=bool)
    if len(t) >= lookback:
        i = np.arange(lookback - 1, len(t))
        good[i] = (cs[i] - cs[i - lookback + 1]) == 0
    return good


def build_cache_v2(erow, path_csv, out_path):
    usecols = ["time_stamp", "train_test", "status_type_id"] + AVG_FEATURES
    df = read_auto(path_csv, usecols=usecols, low_memory=False)

    df["time_stamp"] = pd.to_datetime(df["time_stamp"], errors="coerce")
    df = (df.dropna(subset=["time_stamp"])
            .sort_values("time_stamp")
            .drop_duplicates("time_stamp")
            .reset_index(drop=True))

    X = df[AVG_FEATURES].apply(pd.to_numeric, errors="coerce").to_numpy(dtype=np.float32)
    status = pd.to_numeric(df["status_type_id"], errors="coerce").to_numpy()
    train_m = mask_train(df["train_test"])
    pred_m = mask_prediction(df["train_test"])
    healthy = np.isin(status, list(HEALTHY_STATUS_IDS))

    # unsupervised per-event calibration from historical TRAIN rows only
    baseline_m = train_m & healthy
    if baseline_m.sum() < 1000:
        baseline_m = train_m
    B = X[baseline_m]

    med = np.nan_to_num(np.nanmedian(B, axis=0), nan=0.0).astype(np.float32)
    q25 = np.nanpercentile(B, 25, axis=0)
    q75 = np.nanpercentile(B, 75, axis=0)
    iqr = (q75 - q25).astype(np.float32)
    sd = np.nan_to_num(np.nanstd(B, axis=0), nan=0.0).astype(np.float32)

    # remember WHICH channels had no usable scale instead of silently using 1.0
    degen = (((~np.isfinite(iqr)) | (iqr < DEGEN_TOL)) &
             ((~np.isfinite(sd)) | (sd < DEGEN_TOL)))
    scale = np.where((~np.isfinite(iqr)) | (iqr < DEGEN_TOL), sd, iqr)
    scale = np.where((~np.isfinite(scale)) | (scale < DEGEN_TOL), 1.0, scale).astype(np.float32)

    # normalise the FULL series: the 30-day context needs the historical year
    Z = np.where(np.isfinite(X), X, med)
    Z = np.clip((Z - med) / scale, -CLIP, CLIP).astype(np.float32)

    times = pd.to_datetime(df["time_stamp"])
    tnp = times.to_numpy(dtype="datetime64[ns]")
    ev_start = pd.Timestamp(erow.event_start_dt)
    ev_end = pd.Timestamp(erow.event_end_dt)

    # CARE-native event frame; abnormal-status endpoints excluded
    event_m = (pred_m
               & (tnp >= np.datetime64(ev_start))
               & (tnp < np.datetime64(ev_end))
               & healthy)

    ep_global = np.flatnonzero(event_m & valid_continuity(times))

    # an endpoint needs LOOKBACK-1 real predecessors, otherwise the window slice underflows
    ep_global = ep_global[ep_global >= (LOOKBACK - 1)]
    assert len(ep_global) > 0, f"No valid event-frame windows for event {int(erow.event_id)}"

    # multi-horizon trailing means via float64 prefix sums
    csum = np.zeros((len(Z) + 1, NF), dtype=np.float64)
    csum[1:] = np.cumsum(Z, axis=0, dtype=np.float64)
    parts = []
    for H in CTX_HORIZONS:
        lo = np.maximum(0, ep_global - H + 1)
        cnt = (ep_global + 1 - lo).astype(np.float64)[:, None]
        parts.append(((csum[ep_global + 1] - csum[lo]) / cnt).astype(np.float32))
    ctx = np.concatenate(parts, axis=1)
    del csum

    st = int(ep_global.min()) - LOOKBACK + 1
    en = int(ep_global.max()) + 1
    Xs = Z[st:en]
    ep_local = (ep_global - st).astype(np.int32)
    assert ep_local.min() >= LOOKBACK - 1

    # diagnostics stored per event, consumed globally by CELL 5B
    xe = Xs[ep_local].astype(np.float64)
    t = np.arange(len(xe), dtype=np.float64)
    t = (t - t.mean()) / (t.std() + 1e-12)
    ramp = (((xe - xe.mean(0)) / (xe.std(0) + 1e-12)) * t[:, None]).mean(0).astype(np.float32)
    satrate = (np.abs(Xs[ep_local]) >= 0.98 * CLIP).mean(0).astype(np.float32)

    np.savez_compressed(
        out_path,
        x=Xs,
        ctx=ctx.astype(np.float16),
        endpoints=ep_local,
        times_ns=times.iloc[st:en].astype("int64").to_numpy(dtype=np.int64),
        event_start_ns=np.array([ev_start.value], dtype=np.int64),
        event_end_ns=np.array([ev_end.value], dtype=np.int64),
        degen=degen.astype(np.uint8),
        ramp=ramp,
        satrate=satrate,
    )
    return int(baseline_m.sum())


file_map = {int(p.stem): p for p in event_files}

print("=" * 115)
print("PREPROCESSING / CACHE v2")
print("=" * 115)

for k, erow in event_info.sort_values("event_id").reset_index(drop=True).iterrows():
    eid = int(erow.event_id)
    cache_path = CACHE_DIR / f"event_{eid}.npz"

    if cache_path.exists():
        z = np.load(cache_path, allow_pickle=False)
        if "ctx" not in z.files:
            raise KeyError(
                f"{cache_path.name} is a stale v1 cache with no 'ctx'. "
                f"Delete {CACHE_DIR} and rerun this cell."
            )
        print(f"{k+1:02d}/58 event={eid:3d} split={erow.split:5s} cache=HIT  "
              f"windows={len(z['endpoints']):5d} ctx_dim={z['ctx'].shape[1]}")
        continue

    nb = build_cache_v2(erow, file_map[eid], cache_path)
    z = np.load(cache_path, allow_pickle=False)
    print(f"{k+1:02d}/58 event={eid:3d} split={erow.split:5s} cache=NEW  "
          f"windows={len(z['endpoints']):5d} ctx_dim={z['ctx'].shape[1]} baseline_rows={nb:5d}")

print("\nCached events:", len(list(CACHE_DIR.glob('event_*.npz'))))
# Out:
# ===================================================================================================================
# PREPROCESSING / CACHE v2
# ===================================================================================================================
# 01/58 event=  1 split=test  cache=HIT  windows= 1568 ctx_dim=714
# 02/58 event=  4 split=train cache=HIT  windows= 2595 ctx_dim=714
# 03/58 event=  5 split=train cache=HIT  windows=  244 ctx_dim=714
# 04/58 event=  6 split=train cache=HIT  windows= 1979 ctx_dim=714
# 05/58 event=  8 split=test  cache=HIT  windows= 1932 ctx_dim=714
# 06/58 event=  9 split=train cache=HIT  windows= 2886 ctx_dim=714
# 07/58 event= 11 split=train cache=HIT  windows= 2101 ctx_dim=714
# 08/58 event= 12 split=train cache=HIT  windows= 2949 ctx_dim=714
# 09/58 event= 15 split=train cache=HIT  windows= 2425 ctx_dim=714
# 10/58 event= 16 split=test  cache=HIT  windows=  302 ctx_dim=714
# 11/58 event= 18 split=train cache=HIT  windows=  552 ctx_dim=714
# 12/58 event= 20 split=test  cache=HIT  windows= 1427 ctx_dim=714
# 13/58 event= 28 split=val   cache=HIT  windows= 2375 ctx_dim=714
# 14/58 event= 29 split=train cache=HIT  windows= 1995 ctx_dim=714
# 15/58 event= 30 split=val   cache=HIT  windows=  432 ctx_dim=714
# 16/58 event= 31 split=test  cache=HIT  windows=  223 ctx_dim=714
# 17/58 event= 32 split=train cache=HIT  windows= 1853 ctx_dim=714
# 18/58 event= 33 split=train cache=HIT  windows= 1822 ctx_dim=714
# 19/58 event= 35 split=test  cache=HIT  windows=  886 ctx_dim=714
# 20/58 event= 36 split=train cache=HIT  windows= 1643 ctx_dim=714
# 21/58 event= 37 split=val   cache=HIT  windows= 1710 ctx_dim=714
# 22/58 event= 39 split=val   cache=HIT  windows=  241 ctx_dim=714
# 23/58 event= 41 split=train cache=HIT  windows= 3905 ctx_dim=714
# 24/58 event= 43 split=val   cache=HIT  windows= 1832 ctx_dim=714
# 25/58 event= 44 split=train cache=HIT  windows= 8787 ctx_dim=714
# 26/58 event= 46 split=val   cache=HIT  windows= 1983 ctx_dim=714
# 27/58 event= 47 split=train cache=HIT  windows=  691 ctx_dim=714
# 28/58 event= 48 split=test  cache=HIT  windows= 1850 ctx_dim=714
# 29/58 event= 49 split=train cache=HIT  windows=  595 ctx_dim=714
# 30/58 event= 50 split=train cache=HIT  windows= 1996 ctx_dim=714
# 31/58 event= 54 split=val   cache=HIT  windows= 1543 ctx_dim=714
# 32/58 event= 55 split=test  cache=HIT  windows= 2370 ctx_dim=714
# 33/58 event= 56 split=train cache=HIT  windows= 1855 ctx_dim=714
# 34/58 event= 57 split=train cache=HIT  windows= 1703 ctx_dim=714
# 35/58 event= 58 split=test  cache=HIT  windows= 1430 ctx_dim=714
# 36/58 event= 59 split=train cache=HIT  windows= 2002 ctx_dim=714
# 37/58 event= 60 split=test  cache=HIT  windows= 1525 ctx_dim=714
# 38/58 event= 61 split=train cache=HIT  windows= 1997 ctx_dim=714
# 39/58 event= 62 split=train cache=HIT  windows= 1025 ctx_dim=714
# 40/58 event= 63 split=train cache=HIT  windows= 1425 ctx_dim=714
# 41/58 event= 64 split=val   cache=HIT  windows= 1416 ctx_dim=714
# 42/58 event= 65 split=val   cache=HIT  windows= 2044 ctx_dim=714
# 43/58 event= 66 split=train cache=HIT  windows=  168 ctx_dim=714
# 44/58 event= 67 split=test  cache=HIT  windows= 8132 ctx_dim=714
# 45/58 event= 70 split=val   cache=HIT  windows= 2633 ctx_dim=714
# 46/58 event= 75 split=train cache=HIT  windows= 2708 ctx_dim=714
# 47/58 event= 76 split=test  cache=HIT  windows=  191 ctx_dim=714
# 48/58 event= 78 split=val   cache=HIT  windows=  249 ctx_dim=714
# 49/58 event= 79 split=val   cache=HIT  windows=  169 ctx_dim=714
# 50/58 event= 80 split=val   cache=HIT  windows= 2040 ctx_dim=714
# 51/58 event= 81 split=train cache=HIT  windows=  197 ctx_dim=714
# 52/58 event= 85 split=test  cache=HIT  windows= 1424 ctx_dim=714
# 53/58 event= 88 split=train cache=HIT  windows= 1721 ctx_dim=714
# 54/58 event= 89 split=train cache=HIT  windows= 1846 ctx_dim=714
# 55/58 event= 90 split=train cache=HIT  windows= 1466 ctx_dim=714
# 56/58 event= 91 split=train cache=HIT  windows= 2462 ctx_dim=714
# 57/58 event= 93 split=train cache=HIT  windows= 3092 ctx_dim=714
# 58/58 event= 94 split=train cache=HIT  windows= 1230 ctx_dim=714
#
# Cached events: 58

# %%
# CELL 5B — Global channel hygiene

def build_hygiene(event_frame, cache_dir):
    dg, rp, st, lb = [], [], [], []
    for _, erow in event_frame.iterrows():
        z = np.load(cache_dir / f"event_{int(erow.event_id)}.npz", allow_pickle=False)
        dg.append(z["degen"]); rp.append(z["ramp"]); st.append(z["satrate"])
        lb.append(int(bool(erow.is_anomaly)))

    degen_frac = np.stack(dg).mean(0)
    ramp_mean = np.abs(np.stack(rp)).mean(0)
    sat_mat = np.stack(st)
    lb = np.array(lb)

    sat_auc = np.full(NF, 0.5)
    for j in range(NF):
        if np.ptp(sat_mat[:, j]) > 0:
            sat_auc[j] = roc_auc_score(lb, sat_mat[:, j])

    d_deg = degen_frac > DEGEN_MAX_EVENT_FRAC
    d_ramp = ramp_mean > RAMP_TOL
    d_sat = np.abs(sat_auc - 0.5) > (SAT_AUC_TOL - 0.5)
    drop = d_deg | d_ramp | d_sat

    report = pd.DataFrame({
        "channel": AVG_FEATURES,
        "degen_frac": degen_frac,
        "ramp_mean_abs": ramp_mean,
        "sat_rate_auc": sat_auc,
        "drop_degenerate": d_deg,
        "drop_counter": d_ramp,
        "drop_sat_leak": d_sat,
        "dropped": drop,
    })

    print("CHANNEL HYGIENE")
    print(f"  degenerate baseline scale in >{DEGEN_MAX_EVENT_FRAC:.0%} of events : "
          f"{int(d_deg.sum())}")
    print(f"  cumulative/counter-like (mean |r(value,t)| > {RAMP_TOL})        : "
          f"{int(d_ramp.sum())}")
    print(f"  clipping rate alone predicts the label (AUC > {SAT_AUC_TOL})     : "
          f"{int(d_sat.sum())}")
    print(f"  KEPT                                                          : "
          f"{int((~drop).sum())} / {NF}")

    if int(d_sat.sum()) > 0:
        print("\n  channels whose clipping rate leaks the label (report this in the paper):")
        for j in np.flatnonzero(d_sat)[:15]:
            print(f"    {AVG_FEATURES[j]:45s} AUC={sat_auc[j]:.3f}")

    return np.flatnonzero(~drop).astype(np.int64), report


KEEP_CH, hygiene_report = build_hygiene(event_info, CACHE_DIR)
hygiene_report.to_csv(RESULT / "channel_hygiene.csv", index=False)

NKEEP = len(KEEP_CH)
CTX_KEEP = np.concatenate([KEEP_CH + h * NF for h in range(len(CTX_HORIZONS))])
NCTX = len(CTX_KEEP)

print(f"\nNKEEP = {NKEEP}   NCTX = {NCTX}")
print("saved:", RESULT / "channel_hygiene.csv")
if NKEEP < 150:
    print("\nWARNING: fewer than 150 channels kept. Inspect channel_hygiene.csv against "
          "feature_description.csv and consider raising RAMP_TOL before continuing.")
# Out:
# CHANNEL HYGIENE
#   degenerate baseline scale in >20% of events : 4
#   cumulative/counter-like (mean |r(value,t)| > 0.9)        : 0
#   clipping rate alone predicts the label (AUC > 0.75)     : 0
#   KEPT                                                          : 234 / 238
#
# NKEEP = 234   NCTX = 702
# saved: /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4/channel_hygiene.csv

# %% [markdown]
# ---
# ### Checkpoint 2 — the hygiene report
#
# Read `KEPT n / 238` from the cell above before continuing.
#
# - If `drop_sat_leak` is non-empty, that is direct evidence the old ±12 clipping was
#   leaking the label. Say so in the paper.
# - If fewer than ~150 channels survive, open `channel_hygiene.csv` and compare the dropped
#   channels against `feature_description.csv`. Raise `RAMP_TOL` rather than losing real
#   sensors.

# %%
# CELL 6 — GPU-resident event store (replaces WindowDataset / DataLoader)

def build_store(event_frame, cache_dir, keep_ch, ctx_keep, device):
    store = []
    offs = torch.arange(-LOOKBACK + 1, 1, device=device)
    for _, erow in event_frame.sort_values("event_id").reset_index(drop=True).iterrows():
        z = np.load(cache_dir / f"event_{int(erow.event_id)}.npz", allow_pickle=False)
        store.append({
            "event_id": int(erow.event_id),
            "asset_id": str(erow.asset_id),
            "label": int(bool(erow.is_anomaly)),
            "split": str(erow.split),
            "x": torch.from_numpy(np.ascontiguousarray(z["x"][:, keep_ch])
                                  ).to(device, torch.float16),
            "ctx": torch.from_numpy(np.ascontiguousarray(
                z["ctx"].astype(np.float32)[:, ctx_keep])).to(device, torch.float16),
            "ep": torch.from_numpy(z["endpoints"].astype(np.int64)).to(device),
            "offs": offs,
            "times_ns": z["times_ns"],
            "event_start_ns": int(z["event_start_ns"][0]),
            "event_end_ns": int(z["event_end_ns"][0]),
        })
    return store


# estimate footprint, fall back to CPU-resident storage if the GPU is small
_est_mb = 0.0
for _, _e in event_info.iterrows():
    _z = np.load(CACHE_DIR / f"event_{int(_e.event_id)}.npz", allow_pickle=False)
    _est_mb += (_z["x"].shape[0] * NKEEP + _z["ctx"].shape[0] * NCTX) * 2 / 1e6

STORE_DEVICE = DEV
if torch.cuda.is_available():
    free_mb = torch.cuda.mem_get_info()[0] / 1e6
    if _est_mb > 0.35 * free_mb:
        STORE_DEVICE = torch.device("cpu")
        print(f"store {_est_mb:.0f} MB vs {free_mb:.0f} MB free -> keeping data on CPU")

STORE = build_store(event_info, CACHE_DIR, KEEP_CH, CTX_KEEP, STORE_DEVICE)

ASSET_OF = np.array([s["asset_id"] for s in STORE])
LABEL_OF = np.array([s["label"] for s in STORE])
EVENTID_OF = np.array([s["event_id"] for s in STORE])

print(f"{len(STORE)} events resident on {STORE_DEVICE} ({_est_mb:.0f} MB)")
print(f"input per window: {LOOKBACK} x {NKEEP}   context: {NCTX}")
for sp in ["train", "val", "test"]:
    idx = [i for i, s in enumerate(STORE) if s["split"] == sp]
    w = sum(len(STORE[i]["ep"]) for i in idx)
    print(f"  {sp.upper():5s}: events={len(idx):2d} windows={w:6d} "
          f"anomaly={int(LABEL_OF[idx].sum()):2d} normal={int((LABEL_OF[idx] == 0).sum()):2d}")


def gather_windows(rec, sel):
    """
    sel : LongTensor of POSITIONS into rec['ep'] (any device)
    ->  (n, LOOKBACK, NKEEP) and (n, NCTX), both float32 on DEV
    """
    sel = sel.to(rec["x"].device)
    rows = rec["ep"][sel][:, None] + rec["offs"][None, :]
    x = rec["x"][rows].float()
    c = rec["ctx"][sel].float()
    if x.device != DEV:
        x = x.to(DEV, non_blocking=True)
        c = c.to(DEV, non_blocking=True)
    return x, c
# Out:
# 58 events resident on cuda (205 MB)
# input per window: 60 x 234   context: 702
#   TRAIN: events=32 windows= 63915 anomaly=15 normal=17
#   VAL  : events=13 windows= 18667 anomaly= 6 normal= 7
#   TEST : events=13 windows= 23260 anomaly= 6 normal= 7

# %%
# CELL 6D — DIAGNOSTICS (run ONCE, before any training)
#
# D3 asks whether trivial event properties leak the label.
# D5 gives a classical baseline the deep models must beat, on the SAME folds.
# D6 is the leakage control: with uninformative labels, OOF AUC must collapse to ~0.5.
#
# Set RUN_DIAGNOSTICS = False to skip on later runs.

RUN_DIAGNOSTICS = True

if RUN_DIAGNOSTICS:
    from sklearn.linear_model import LogisticRegression
    from sklearn.preprocessing import StandardScaler
    from sklearn.pipeline import make_pipeline
    from sklearn.ensemble import HistGradientBoostingClassifier

    lab = LABEL_OF
    ast_ = ASSET_OF

    # ---- D3  trivial shortcut baselines ---------------------------------------------
    print("=" * 100)
    print("D3  TRIVIAL SHORTCUT BASELINES")
    print("=" * 100)
    dur_h = np.array([(s["event_end_ns"] - s["event_start_ns"]) / 3.6e12 for s in STORE])
    n_win = np.array([len(s["ep"]) for s in STORE], dtype=float)
    d3 = {}
    for nm, v in [("event duration (h)", dur_h), ("n eligible windows", n_win)]:
        d3[nm] = float(roc_auc_score(lab, v))
        print(f"  {nm:22s} ROC-AUC over all {len(lab)} events = {d3[nm]:.3f}")
    if max(abs(v - 0.5) for v in d3.values()) > 0.15:
        print("  >0.65 or <0.35: a trivial event property carries label information.")
        print("  Report the control and keep the tail-quantile operational statistic.")
    else:
        print("  Both are close to 0.5, so neither event duration nor window count carries")
        print("  usable label information. The length-bias concern is retired empirically;")
        print("  the tail-quantile operational statistic is now prudence, not a fix.")

    # ---- shared fold machinery -------------------------------------------------------
    # Use the SAME asset folds as the deep models, and the same train/val/test roles, so
    # the classical baseline is a like-for-like comparison rather than a looser one.
    def fold_indices(folds):
        out = []
        for fi in range(len(folds)):
            te_a, va_a = folds[fi], folds[(fi + 1) % len(folds)]
            te = np.array([i for i in range(len(STORE)) if ast_[i] in te_a])
            tr = np.array([i for i in range(len(STORE))
                           if ast_[i] not in (te_a | va_a)])
            out.append((tr, te))
        return out

    FOLD_IDX = fold_indices(FOLDS)
    print(f"\n  fold sizes (train/test), val fold excluded from train to match the deep "
          f"models:")
    for fi, (tr, te) in enumerate(FOLD_IDX):
        print(f"    fold {fi}: train={len(tr):2d} (pos={int(lab[tr].sum()):2d})  "
              f"test={len(te):2d} (pos={int(lab[te].sum()):2d})")

    def oof_predict(model, X, y, fold_idx):
        """Returns out-of-fold scores, or None if any fold is unusable."""
        oof = np.full(len(y), np.nan)
        for tr, te in fold_idx:
            if len(np.unique(y[tr])) < 2:
                return None
            model.fit(X[tr], y[tr])
            oof[te] = model.predict_proba(X[te])[:, 1]
        m = ~np.isnan(oof)
        if len(np.unique(y[m])) < 2:
            return None
        return oof

    # ---- D5  classical event-summary baseline ----------------------------------------
    print("\n" + "=" * 100)
    print("D5  CLASSICAL EVENT-SUMMARY BASELINE (same asset folds as the deep models)")
    print("=" * 100)

    def event_summary(rec, roll=36):
        x = rec["x"][rec["ep"]].float().cpu().numpy()
        if len(x) >= roll:
            k = np.ones(roll, dtype=np.float32) / roll
            sm = np.apply_along_axis(lambda c: np.convolve(c, k, mode="valid"), 0, x)
        else:
            sm = x
        return np.concatenate([sm.mean(0), np.quantile(sm, 0.95, axis=0),
                               np.quantile(sm, 0.05, axis=0), np.abs(sm).max(0)]
                              ).astype(np.float32)

    Xev = np.nan_to_num(np.stack([event_summary(r) for r in STORE]),
                        nan=0.0, posinf=0.0, neginf=0.0)
    print("  event feature matrix:", Xev.shape)

    MODELS = {
        "L2 logistic (C=0.003)": make_pipeline(
            StandardScaler(), LogisticRegression(C=0.003, max_iter=5000,
                                                 class_weight="balanced")),
        "L2 logistic (C=0.01)": make_pipeline(
            StandardScaler(), LogisticRegression(C=0.01, max_iter=5000,
                                                 class_weight="balanced")),
        "L2 logistic (C=0.1)": make_pipeline(
            StandardScaler(), LogisticRegression(C=0.1, max_iter=5000,
                                                 class_weight="balanced")),
        "HistGB (depth 2)": HistGradientBoostingClassifier(
            max_depth=2, max_iter=200, learning_rate=0.05, random_state=0),
    }

    d5_oof, d5_scores = {}, {}
    for nm, mdl in MODELS.items():
        oof = oof_predict(mdl, Xev, lab, FOLD_IDX)
        if oof is None:
            print(f"  {nm:22s} SKIPPED (unusable fold)")
            continue
        d5_oof[nm] = oof
        d5_scores[nm] = (roc_auc_score(lab, oof), average_precision_score(lab, oof))
        print(f"  {nm:22s} OOF ROC-AUC={d5_scores[nm][0]:.3f}  "
              f"OOF PR-AUC={d5_scores[nm][1]:.3f}")

    BEST_CLASSICAL = max(d5_scores, key=lambda k: d5_scores[k][0])
    BAR_ROC, BAR_PR = d5_scores[BEST_CLASSICAL]
    prevalence = float(lab.mean())

    pd.DataFrame({"event_id": EVENTID_OF, "asset_id": ast_, "label": lab,
                  **{f"oof_{k}": v for k, v in d5_oof.items()}}
                 ).to_csv(RESULT / "D5_classical_baseline_oof.csv", index=False)

    print(f"\n  event prevalence           : {prevalence:.3f}")
    print(f"  BAR TO BEAT ({BEST_CLASSICAL}): ROC-AUC {BAR_ROC:.3f} | PR-AUC {BAR_PR:.3f}")
    print("  This is the number the transformers must beat to justify themselves, and it")
    print("  goes in the paper as a baseline row regardless of the outcome.")
    if d5_scores.get("HistGB (depth 2)", (1, 1))[0] < BAR_ROC - 0.05:
        print("  Note: the heavily regularised linear model beats gradient boosting, which")
        print("  is the signature of a very small effective sample size. Expect the deep")
        print("  models to need at least the current DROPOUT/WEIGHT_DECAY, possibly more.")
    print("  saved:", RESULT / "D5_classical_baseline_oof.csv")

    # ---- D6  leakage control ---------------------------------------------------------
    print("\n" + "=" * 100)
    print("D6  LABEL PERMUTATION CONTROL (leakage check)")
    print("=" * 100)

    # Asset label composition, printed because it determines which nulls are feasible.
    comp = pd.DataFrame([{"asset_id": a, "n": int((ast_ == a).sum()),
                          "pos": int(lab[ast_ == a].sum())} for a in np.unique(ast_)])
    print(f"  {len(comp)} assets | all-normal={int((comp.pos == 0).sum())} "
          f"all-anomaly={int((comp.pos == comp.n).sum())} "
          f"mixed={int(((comp.pos > 0) & (comp.pos < comp.n)).sum())}")
    print(f"  events per asset: min={comp.n.min()} median={int(comp.n.median())} "
          f"max={comp.n.max()}")

    mdl = MODELS[BEST_CLASSICAL]
    rng = np.random.default_rng(7)
    N_PERM = 50

    # Null A - global label permutation. Preserves the positive count exactly and cannot
    # produce a single-class training fold at this prevalence. This is the primary null.
    a_vals, a_skip = [], 0
    for _ in range(N_PERM):
        yp = rng.permutation(lab)
        oof = oof_predict(mdl, Xev, yp, FOLD_IDX)
        if oof is None:
            a_skip += 1
            continue
        a_vals.append(roc_auc_score(yp, oof))
    a_vals = np.array(a_vals)

    # Null B - asset-block permutation. Reassigns whole assets' label vectors between
    # assets of equal event count, so group structure AND the positive count survive.
    sizes = {}
    for a in np.unique(ast_):
        sizes.setdefault(int((ast_ == a).sum()), []).append(a)
    blocks = {a: lab[ast_ == a].copy() for a in np.unique(ast_)}
    permutable = sum(len(v) for v in sizes.values() if len(v) >= 2)

    b_vals, b_skip = [], 0
    if permutable >= 4:
        for _ in range(N_PERM):
            yp = np.empty(len(lab), int)
            for sz, members in sizes.items():
                dst = rng.permutation(members) if len(members) >= 2 else members
                for src, d in zip(members, dst):
                    yp[ast_ == d] = blocks[src]
            oof = oof_predict(mdl, Xev, yp, FOLD_IDX)
            if oof is None:
                b_skip += 1
                continue
            b_vals.append(roc_auc_score(yp, oof))
    b_vals = np.array(b_vals)

    print(f"\n  model under test: {BEST_CLASSICAL}")
    print(f"  real-label OOF ROC-AUC                    : {BAR_ROC:.3f}")
    if len(a_vals):
        print(f"  null A, global permutation   n={len(a_vals):2d} skipped={a_skip:2d} : "
              f"mean={a_vals.mean():.3f} p95={np.quantile(a_vals, .95):.3f} "
              f"max={a_vals.max():.3f}")
    if len(b_vals):
        print(f"  null B, asset-block swap     n={len(b_vals):2d} skipped={b_skip:2d} : "
              f"mean={b_vals.mean():.3f} p95={np.quantile(b_vals, .95):.3f} "
              f"max={b_vals.max():.3f}")
    else:
        print(f"  null B, asset-block swap                  : not feasible "
              f"({permutable} assets sit in size groups of >=2)")

    ref = a_vals if len(a_vals) else b_vals
    if len(ref):
        p_emp = float((ref >= BAR_ROC).mean())
        print(f"\n  empirical p(null >= real) = {p_emp:.3f}   "
              f"(n={len(ref)} permutations)")
        if ref.mean() > 0.60:
            print("  FAIL: the null mean is well above chance. Something leaks - revisit the")
            print("  CELL 5B hygiene report before trusting any downstream result.")
        elif BAR_ROC <= np.quantile(ref, 0.95):
            print("  CAUTION: the real score does not clear the null p95. The classical")
            print("  baseline's advantage over chance is not established at n=58; treat any")
            print("  small deep-model margin over it with the same scepticism.")
        else:
            print("  PASS: null collapses to chance and the real score clears its p95.")
    print("\n  Note: D6 permutes labels only. It cannot detect a shortcut that is genuinely")
    print("  correlated with the true label, which is what D3 and the CELL 5B clip-rate")
    print("  test are for.")
else:
    print("diagnostics skipped (RUN_DIAGNOSTICS = False)")
# Out:
# ====================================================================================================
# D3  TRIVIAL SHORTCUT BASELINES
# ====================================================================================================
#   event duration (h)     ROC-AUC over all 58 events = 0.502
#   n eligible windows     ROC-AUC over all 58 events = 0.403
#   Both are close to 0.5, so neither event duration nor window count carries
#   usable label information. The length-bias concern is retired empirically;
#   the tail-quantile operational statistic is now prudence, not a fix.
#
#   fold sizes (train/test), val fold excluded from train to match the deep models:
#     fold 0: train=33 (pos=16)  test=13 (pos= 6)
#     fold 1: train=29 (pos=14)  test=12 (pos= 5)
#     fold 2: train=33 (pos=15)  test=17 (pos= 8)
#     fold 3: train=42 (pos=19)  test= 8 (pos= 4)
#     fold 4: train=37 (pos=17)  test= 8 (pos= 4)
#
# ====================================================================================================
# D5  CLASSICAL EVENT-SUMMARY BASELINE (same asset folds as the deep models)
# ====================================================================================================
#   event feature matrix: (58, 936)
#   L2 logistic (C=0.003)  OOF ROC-AUC=0.679  OOF PR-AUC=0.670
#   L2 logistic (C=0.01)   OOF ROC-AUC=0.687  OOF PR-AUC=0.690
#   L2 logistic (C=0.1)    OOF ROC-AUC=0.685  OOF PR-AUC=0.687
#   HistGB (depth 2)       OOF ROC-AUC=0.555  OOF PR-AUC=0.533
#
#   event prevalence           : 0.466
#   BAR TO BEAT (L2 logistic (C=0.01)): ROC-AUC 0.687 | PR-AUC 0.690
#   This is the number the transformers must beat to justify themselves, and it
#   goes in the paper as a baseline row regardless of the outcome.
#   Note: the heavily regularised linear model beats gradient boosting, which
#   is the signature of a very small effective sample size. Expect the deep
#   models to need at least the current DROPOUT/WEIGHT_DECAY, possibly more.
#   saved: /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4/D5_classical_baseline_oof.csv
#
# ====================================================================================================
# D6  LABEL PERMUTATION CONTROL (leakage check)
# ====================================================================================================
#   22 assets | all-normal=3 all-anomaly=0 mixed=19
#   events per asset: min=1 median=2 max=6
#
#   model under test: L2 logistic (C=0.01)
#   real-label OOF ROC-AUC                    : 0.687
#   null A, global permutation   n=50 skipped= 0 : mean=0.504 p95=0.644 max=0.718
#   null B, asset-block swap     n=50 skipped= 0 : mean=0.547 p95=0.651 max=0.682
#
#   empirical p(null >= real) = 0.020   (n=50 permutations)
#   PASS: null collapses to chance and the real score clears its p95.
#
#   Note: D6 permutes labels only. It cannot detect a shortcut that is genuinely
#   correlated with the true label, which is what D3 and the CELL 5B clip-rate
#   test are for.

# %% [markdown]
# ---
# ### Checkpoint 3 — diagnostics decide whether the rewrite was needed
#
# D5 is the informative one. If the classical event-summary baseline reaches out-of-fold
# ROC-AUC ≈ 0.8 while the transformers land at 0.6–0.7, the deep pipeline was the limiter
# rather than the data — and that baseline belongs in the paper either way.
#
# D6 must collapse to ≈ 0.5. If permuted labels still score well above chance, there is
# leakage left in the features.

# %%
# CELL 8 — Event scoring, threshold selection, metrics

@torch.no_grad()
def score_events(model, idxs, chunk=EVAL_CHUNK, return_windows=False, stride=1):
    """
    Event score = mean of the top TOP_FRACTION window LOGITS - identical to the
    statistic optimised by the bag loss in CELL 11.
    stride > 1 subsamples endpoints (use for the per-epoch criterion only).
    """
    model.eval()
    rows, win = [], []
    for i in idxs:
        r = STORE[i]
        pos = torch.arange(0, len(r["ep"]), stride)
        n = len(pos)
        out = torch.empty(n, device=DEV)
        for s in range(0, n, chunk):
            sel = pos[s:s + chunk]
            xb, cb = gather_windows(r, sel)
            out[s:s + len(sel)] = model(xb, cb).float()
        k = max(1, int(math.ceil(TOP_FRACTION * n)))
        rows.append({"event_id": r["event_id"], "asset_id": r["asset_id"],
                     "label": r["label"], "score": float(out.topk(k).values.mean()),
                     "n_windows": n})
        if return_windows:
            ep_np = r["ep"].cpu().numpy()[pos.numpy()]
            win.append(pd.DataFrame({
                "event_id": r["event_id"], "asset_id": r["asset_id"],
                "label": r["label"],
                "timestamp_ns": r["times_ns"][ep_np],
                "event_end_ns": r["event_end_ns"],
                "logit": out.cpu().numpy(),
                "prob": torch.sigmoid(out).cpu().numpy()}))
    ev = pd.DataFrame(rows)
    return (ev, pd.concat(win, ignore_index=True)) if return_windows else ev


def choose_threshold(y, s):
    """
    Interior midpoints only, so 'predict everything positive' is not a legal candidate.
    Objective is MCC-led: MCC uses all four confusion cells and is far less degenerate
    than F1 on a small event set.
    """
    y = np.asarray(y, int)
    s = np.asarray(s, float)
    u = np.unique(s)
    cand = (u[:-1] + u[1:]) / 2.0 if len(u) > 1 else u
    if len(cand) == 0:
        return float(s.mean())
    best = (-2.0, float(cand[0]))
    for t in cand:
        p = (s >= t).astype(int)
        v = 0.7 * matthews_corrcoef(y, p) + 0.3 * f1_score(y, p, zero_division=0)
        if v > best[0]:
            best = (v, float(t))
    return best[1]


def metrics_from_event_df(df, tau=None, pred_col=None):
    y = df.label.to_numpy(int)
    s = df.score.to_numpy(float)
    p = df[pred_col].to_numpy(int) if pred_col else (s >= tau).astype(int)
    tn, fp, fn, tp = confusion_matrix(y, p, labels=[0, 1]).ravel()
    return {
        "PR-AUC": float(average_precision_score(y, s)),
        "ROC-AUC": float(roc_auc_score(y, s)),
        "Precision": float(precision_score(y, p, zero_division=0)),
        "Recall": float(recall_score(y, p, zero_division=0)),
        "F1": float(f1_score(y, p, zero_division=0)),
        "MCC": float(matthews_corrcoef(y, p)),
        "Balanced Accuracy": float(balanced_accuracy_score(y, p)),
        "Accuracy": float(accuracy_score(y, p)),
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp),
        "Threshold": float(tau) if tau is not None else np.nan,
    }


print("Event-level scoring utilities ready (logit-space top-%d%% aggregation)."
      % int(TOP_FRACTION * 100))
# Out:
# Event-level scoring utilities ready (logit-space top-10% aggregation).

# %%
# CELL 9 — Backbones, shared context head, EMA

class AttentivePool(nn.Module):
    def __init__(self, d):
        super().__init__()
        self.score = nn.Sequential(nn.Linear(d, d // 2), nn.Tanh(), nn.Linear(d // 2, 1))

    def forward(self, z):
        a = torch.softmax(self.score(z).squeeze(-1), dim=1)
        return torch.sum(z * a.unsqueeze(-1), dim=1)


class MultiScaleFront(nn.Module):
    """Multi-scale temporal convolution, plus an optional fixed one-level Haar branch."""

    def __init__(self, nf, d, with_wavelet):
        super().__init__()
        self.with_wavelet = with_wavelet
        b = d // 3
        self.c3 = nn.Conv1d(nf, b, 3, padding=1)
        self.c9 = nn.Conv1d(nf, b, 9, padding=4)
        self.c27 = nn.Conv1d(nf, d - 2 * b, 27, padding=13)
        self.res = nn.Linear(nf, d)
        if with_wavelet:
            self.wave = nn.Linear(2 * nf, d)
        self.norm = nn.LayerNorm(d)

    def forward(self, x):
        xc = x.transpose(1, 2)
        ms = torch.cat([F.gelu(self.c3(xc)),
                        F.gelu(self.c9(xc)),
                        F.gelu(self.c27(xc))], dim=1).transpose(1, 2)
        z = ms + self.res(x)
        if self.with_wavelet:
            s = math.sqrt(2.0)
            low = F.pad((x[:, 1:, :] + x[:, :-1, :]) / s, (0, 0, 1, 0))
            high = F.pad((x[:, 1:, :] - x[:, :-1, :]) / s, (0, 0, 1, 0))
            z = z + self.wave(torch.cat([low, high], dim=-1))
        return self.norm(z)


def _encoder(d, h, layers, drop):
    layer = nn.TransformerEncoderLayer(d_model=d, nhead=h, dim_feedforward=2 * d,
                                       dropout=drop, batch_first=True,
                                       activation="gelu", norm_first=True)
    return nn.TransformerEncoder(layer, layers)


class TransformerBB(nn.Module):
    """
    One class covering the whole ablation ladder:
      multiscale=False, wavelet=False, attn_pool=False  -> Plain Transformer
      multiscale=True                                   -> + Multi-scale Temporal
      multiscale=True, wavelet=True                     -> + Haar Wavelet
      multiscale=True, wavelet=True, attn_pool=True     -> MS-WTFormer
    Returns a (B, d) embedding; the head lives in EventModel.
    """

    def __init__(self, nf, d=D_MODEL, h=4, layers=2, drop=DROPOUT,
                 multiscale=False, wavelet=False, attn_pool=False):
        super().__init__()
        self.d = d
        self.front = (MultiScaleFront(nf, d, wavelet) if multiscale
                      else nn.Linear(nf, d))
        self.pos = nn.Parameter(torch.zeros(1, LOOKBACK, d))
        self.enc = _encoder(d, h, layers, drop)
        self.pool = AttentivePool(d) if attn_pool else None

    def forward(self, x):
        z = self.enc(self.front(x) + self.pos)
        return self.pool(z) if self.pool is not None else z.mean(1)


class EventModel(nn.Module):
    """
    backbone -> (+ multi-horizon context branch) -> classification head.
    use_ctx=False reproduces the 10-hours-only input, used as ablation rung A4.
    """

    def __init__(self, backbone, nctx, drop=DROPOUT, use_ctx=True):
        super().__init__()
        self.bb = backbone
        d = backbone.d
        self.use_ctx = use_ctx
        if use_ctx:
            self.ctx = nn.Sequential(nn.LayerNorm(nctx), nn.Dropout(drop),
                                     nn.Linear(nctx, d), nn.GELU(), nn.Linear(d, d))
        self.head = nn.Sequential(nn.LayerNorm(d), nn.Linear(d, 32), nn.GELU(),
                                  nn.Dropout(drop), nn.Linear(32, 1))

    def forward(self, x, c=None):
        z = self.bb(x)
        if self.use_ctx and c is not None:
            z = z + self.ctx(c)
        return self.head(z).squeeze(-1)


class EMA:
    """Weight averaging - removes most of the checkpoint-selection variance."""

    def __init__(self, model, decay=EMA_DECAY):
        self.decay = decay
        self.shadow = {k: v.detach().clone().float() for k, v in model.state_dict().items()}

    @torch.no_grad()
    def update(self, model):
        for k, v in model.state_dict().items():
            if v.dtype.is_floating_point:
                self.shadow[k].mul_(self.decay).add_(v.detach().float(), alpha=1 - self.decay)
            else:
                self.shadow[k] = v.detach().clone().float()

    def state(self, model):
        return {k: self.shadow[k].to(v.dtype) for k, v in model.state_dict().items()}


print("Backbones, context head and EMA ready.")
# Out:
# Backbones, context head and EMA ready.

# %%
# CELL 10 — Modern time-series baseline backbones

class iTransformerBB(nn.Module):
    """Variables are tokens; each token embeds the complete 10-hour history."""

    def __init__(self, nf, d=D_MODEL, h=4, layers=2, drop=DROPOUT):
        super().__init__()
        self.d = d
        self.embed = nn.Sequential(nn.Linear(LOOKBACK, d), nn.GELU(), nn.LayerNorm(d))
        self.enc = _encoder(d, h, layers, drop)
        self.gate = nn.Linear(d, 1)

    def forward(self, x):
        z = self.enc(self.embed(x.transpose(1, 2)))
        a = torch.softmax(self.gate(z).squeeze(-1), dim=1)
        return torch.sum(z * a.unsqueeze(-1), dim=1)


class ModernTCNBlock(nn.Module):
    def __init__(self, d, k, drop):
        super().__init__()
        self.dw = nn.Conv1d(d, d, k, padding=k // 2, groups=d)
        self.pw = nn.Sequential(nn.Conv1d(d, 2 * d, 1), nn.GELU(),
                                nn.Dropout(drop), nn.Conv1d(2 * d, d, 1))
        self.norm = nn.BatchNorm1d(d)

    def forward(self, x):
        return self.norm(x + self.pw(self.dw(x)))


class ModernTCNBB(nn.Module):
    def __init__(self, nf, d=D_MODEL, drop=DROPOUT):
        super().__init__()
        self.d = d
        self.stem = nn.Conv1d(nf, d, 1)
        self.blocks = nn.Sequential(*[ModernTCNBlock(d, k, drop) for k in (7, 15, 31, 15)])

    def forward(self, x):
        return self.blocks(self.stem(x.transpose(1, 2))).mean(-1)


class ScaleMixer(nn.Module):
    def __init__(self, nf, d, drop):
        super().__init__()
        self.proj = nn.Conv1d(nf, d, 3, padding=1)
        self.mix = nn.Sequential(nn.Conv1d(d, d, 5, padding=2, groups=d), nn.GELU(),
                                 nn.Conv1d(d, d, 1), nn.GELU(), nn.Dropout(drop))
        self.norm = nn.BatchNorm1d(d)

    def forward(self, x):
        z = self.proj(x)
        return self.norm(z + self.mix(z)).mean(-1)


class TimeMixerPPBB(nn.Module):
    """Compact TimeMixer++-style multi-resolution adaptation."""

    def __init__(self, nf, d=D_MODEL, drop=DROPOUT):
        super().__init__()
        self.d = d
        self.s = nn.ModuleList([ScaleMixer(nf, d, drop) for _ in range(3)])
        self.gate = nn.Sequential(nn.Linear(d, d // 2), nn.Tanh(), nn.Linear(d // 2, 1))

    def forward(self, x):
        x = x.transpose(1, 2)
        z = torch.stack([self.s[0](x),
                         self.s[1](F.avg_pool1d(x, 2, 2)),
                         self.s[2](F.avg_pool1d(x, 4, 4))], dim=1)
        a = torch.softmax(self.gate(z).squeeze(-1), dim=1)
        return torch.sum(z * a.unsqueeze(-1), dim=1)


class NonstationaryBB(nn.Module):
    """Series stationarisation + statistics-conditioned Transformer adaptation."""

    def __init__(self, nf, d=D_MODEL, h=4, layers=2, drop=DROPOUT):
        super().__init__()
        self.d = d
        self.inp = nn.Linear(nf, d)
        self.pos = nn.Parameter(torch.zeros(1, LOOKBACK, d))
        self.enc = _encoder(d, h, layers, drop)
        self.stats = nn.Sequential(nn.Linear(2 * nf, d), nn.GELU(), nn.Linear(d, d))

    def forward(self, x):
        mu = x.mean(1, keepdim=True)
        sd = x.std(1, keepdim=True).clamp_min(1e-4)
        z = self.enc(self.inp((x - mu) / sd) + self.pos).mean(1)
        stat = torch.cat([mu.squeeze(1), torch.log(sd.squeeze(1) + 1e-6)], dim=-1)
        return z + self.stats(stat)


print("Modern baseline backbones ready.")
# Out:
# Modern baseline backbones ready.

# %%
# CELL 11 — Event-bag (MIL) training

def topk_bag(logits, k):
    """logits: (nbags, K) -> (nbags,). Differentiable through the selected entries."""
    k = max(1, min(k, logits.shape[1]))
    return logits.topk(k, dim=1).values.mean(1)


def augment(x):
    if AUG_CHAN_DROP > 0:
        m = (torch.rand(x.shape[0], 1, x.shape[2], device=x.device) > AUG_CHAN_DROP).float()
        x = x * m
    if AUG_JITTER > 0:
        x = x + AUG_JITTER * torch.randn_like(x)
    if AUG_TIME_MASK > 0 and LOOKBACK > AUG_TIME_MASK:
        s = int(torch.randint(0, LOOKBACK - AUG_TIME_MASK, (1,)).item())
        x[:, s:s + AUG_TIME_MASK] = 0.0
    return x


def train_bag_model(model_fn, train_idx, val_idx, seed, ckpt=None, log=True):
    """
    Event-bag multiple-instance training.

        bag_logit_e = mean of the top-k window logits of event e      (k/K = TOP_FRACTION)
        L = BCE(bag_logit_e, y_e)                                     all events
          + LAMBDA_NEG * BCE(window_logits, 0)                        normal events only

    The first term optimises exactly the statistic thresholded at test time. The second
    exploits the fact that every window in a normal event is a genuine negative, whereas
    a window 300 h before a fault is not a genuine positive.
    """
    if ckpt is not None and RESUME_FROM_CHECKPOINTS and Path(ckpt).exists():
        m = model_fn().to(DEV)
        m.load_state_dict(torch.load(ckpt, map_location="cpu", weights_only=True))
        if log:
            print(f"    seed={seed}: loaded checkpoint {Path(ckpt).name}")
        return m, pd.DataFrame()

    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    model = model_fn().to(DEV)
    eval_model = model_fn().to(DEV)          # reused holder for the EMA weights
    ema = EMA(model)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    total = MAX_EPOCHS * STEPS_PER_EPOCH
    warm = WARMUP_EPOCHS * STEPS_PER_EPOCH
    sched = torch.optim.lr_scheduler.LambdaLR(
        opt, lambda s: (s + 1) / max(1, warm) if s < warm
        else 0.5 * (1 + math.cos(math.pi * (s - warm) / max(1, total - warm))))
    bce = nn.BCEWithLogitsLoss()

    pos = [i for i in train_idx if STORE[i]["label"] == 1]
    neg = [i for i in train_idx if STORE[i]["label"] == 0]
    assert pos and neg, "training split must contain both classes"
    rng = np.random.default_rng(seed)
    kbag = max(1, int(round(TOP_FRACTION * K_PER_BAG)))

    best, best_state, wait, hist = -np.inf, None, 0, []

    for ep in range(1, MAX_EPOCHS + 1):
        model.train()
        run = 0.0
        for _ in range(STEPS_PER_EPOCH):
            chosen = (list(rng.choice(pos, min(BAGS_PER_CLASS, len(pos)), replace=False)) +
                      list(rng.choice(neg, min(BAGS_PER_CLASS, len(neg)), replace=False)))
            xs, cs, ys = [], [], []
            for ridx in chosen:
                r = STORE[ridx]
                sel = torch.from_numpy(rng.integers(0, len(r["ep"]), K_PER_BAG))
                xb, cb = gather_windows(r, sel)
                xs.append(xb); cs.append(cb); ys.append(float(r["label"]))

            x = augment(torch.cat(xs, 0))
            c = torch.cat(cs, 0)
            y = torch.tensor(ys, device=DEV)

            logit_w = model(x, c).view(len(chosen), K_PER_BAG)

            loss = bce(topk_bag(logit_w, kbag), y)

            nm = y < 0.5
            if nm.any():
                lw = logit_w[nm].reshape(-1)
                loss = loss + LAMBDA_NEG * bce(lw, torch.zeros_like(lw))

            opt.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step(); sched.step(); ema.update(model)
            run += float(loss.item())

        # selection criterion: inner validation only, smoothed with window-level ROC
        eval_model.load_state_dict(ema.state(model))
        ve, vw = score_events(eval_model, val_idx, return_windows=True, stride=VAL_STRIDE)
        ev_roc = roc_auc_score(ve.label, ve.score) if ve.label.nunique() == 2 else 0.5
        ev_pr = float(average_precision_score(ve.label, ve.score))
        wi_roc = roc_auc_score(vw.label, vw.logit) if vw.label.nunique() == 2 else 0.5
        crit = 0.7 * ev_roc + 0.3 * wi_roc

        hist.append({"epoch": ep, "loss": run / STEPS_PER_EPOCH,
                     "val_event_roc": ev_roc, "val_event_pr": ev_pr,
                     "val_window_roc": wi_roc, "criterion": crit,
                     "lr": opt.param_groups[0]["lr"]})
        if log:
            print(f"    ep={ep:02d} loss={hist[-1]['loss']:.4f} "
                  f"val_ev_ROC={ev_roc:.3f} val_ev_PR={ev_pr:.3f} "
                  f"val_win_ROC={wi_roc:.3f} crit={crit:.4f}")

        if crit > best + 1e-6:
            best, wait = crit, 0
            best_state = {k: v.detach().cpu().clone() for k, v in ema.state(model).items()}
        else:
            wait += 1
            if wait >= PATIENCE:
                if log:
                    print(f"    early stop at epoch {ep} (best crit={best:.4f})")
                break

    assert best_state is not None
    out = model_fn().to(DEV)
    out.load_state_dict({k: v.to(DEV) for k, v in best_state.items()})
    if ckpt is not None:
        torch.save(best_state, ckpt)
    return out, pd.DataFrame(hist)


print("Event-bag MIL trainer ready.")
# Out:
# Event-bag MIL trainer ready.

# %%
# CELL 12 — Model registry

def safe_name(n):
    return (n.replace(" ", "_").replace("/", "_").replace("+", "plus")
             .replace("(", "").replace(")", "").replace("-", "_")
             .replace("\u2014", "-"))


def make_registry(nf, nctx):
    def M(bb_fn, use_ctx=True):
        return lambda: EventModel(bb_fn(), nctx, drop=DROPOUT, use_ctx=use_ctx)

    main = {
        "Plain Transformer": M(lambda: TransformerBB(nf)),
        "iTransformer (adapted)": M(lambda: iTransformerBB(nf)),
        "ModernTCN (adapted)": M(lambda: ModernTCNBB(nf)),
        "TimeMixer++-style (adapted)": M(lambda: TimeMixerPPBB(nf)),
        "Non-stationary Transformer (adapted)": M(lambda: NonstationaryBB(nf)),
        PROPOSED: M(lambda: TransformerBB(nf, multiscale=True, wavelet=True, attn_pool=True)),
    }
    ablation = {
        "A0 Plain Transformer": M(lambda: TransformerBB(nf)),
        "A1 + Multi-scale Temporal": M(lambda: TransformerBB(nf, multiscale=True)),
        "A2 + Multi-scale + Haar": M(lambda: TransformerBB(nf, multiscale=True,
                                                           wavelet=True)),
        "A3 + Attentive Pooling": M(lambda: TransformerBB(nf, multiscale=True,
                                                          wavelet=True, attn_pool=True)),
        "A4 - context branch (10 h only)": M(
            lambda: TransformerBB(nf, multiscale=True, wavelet=True, attn_pool=True),
            use_ctx=False),
    }
    return main, ablation


MAIN_MODELS, ABLATION_MODELS = make_registry(NKEEP, NCTX)

print("MODEL REGISTRY")
print("  every main-comparison model receives the context branch, so the proposed model")
print("  has no structural advantage; use_ctx=False appears only as ablation rung A4.\n")
for grp, reg in [("MAIN", MAIN_MODELS), ("ABLATION", ABLATION_MODELS)]:
    for k, fn in reg.items():
        print(f"  {grp:9s} {k:40s} params={sum(p.numel() for p in fn().parameters()):,}")
# Out:
# MODEL REGISTRY
#   every main-comparison model receives the context branch, so the proposed model
#   has no structural advantage; use_ctx=False appears only as ablation rung A4.
#
#   MAIN      Plain Transformer                        params=138,621
#   MAIN      iTransformer (adapted)                   params=123,838
#   MAIN      ModernTCN (adapted)                      params=139,261
#   MAIN      TimeMixer++-style (adapted)              params=203,902
#   MAIN      Non-stationary Transformer (adapted)     params=172,797
#   MAIN      MS-WTFormer (Proposed)                   params=368,906
#   ABLATION  A0 Plain Transformer                     params=138,621
#   ABLATION  A1 + Multi-scale Temporal                params=336,777
#   ABLATION  A2 + Multi-scale + Haar                  params=366,793
#   ABLATION  A3 + Attentive Pooling                   params=368,906
#   ABLATION  A4 - context branch (10 h only)          params=318,350

# %% [markdown]
# ---
# ## Training
#
# **Runtime warning.** As written the next cell trains 6 main models + 5 ablation rungs +
# 1 frozen-split model × 5 folds × 3 seeds ≈ **168 trainings**, roughly 8–19 h on a T4.
# That will not survive one Colab session. Three reductions, in order:
#
# 1. `A0` and `A3` are architecturally identical to `Plain Transformer` and the proposed
#    model. `REUSE_A0_A3 = True` (default) skips retraining them — saves 30 runs.
# 2. `ABLATION_SEEDS = [42]` (default) — saves 20 more.
# 3. Set `RESUME_FROM_CHECKPOINTS = True` in CELL 1 for every run *after* the first. Only
#    while CELL 1 is unchanged; stale checkpoints load silently and will quietly invalidate
#    the benchmark.
#
# Time one fold first:
#
# ```python
# import time
# t0 = time.time()
# run_grouped_cv(PROPOSED, MAIN_MODELS[PROPOSED], FOLDS[:1], seeds=[42])
# print((time.time() - t0) / 60, "min")
# ```
#
# Multiply by ~108 and decide before committing.

# %%
# CELL 13 — Asset-grouped nested CV (primary) + frozen split (secondary)

def _avg_windows(frames):
    return (pd.concat(frames, ignore_index=True)
              .groupby(["event_id", "timestamp_ns"], as_index=False)
              .agg(asset_id=("asset_id", "first"), label=("label", "first"),
                   event_end_ns=("event_end_ns", "first"), logit=("logit", "mean")))


def run_grouped_cv(name, model_fn, folds, seeds=SEEDS, verbose=True, keep_windows=False):
    """
    PRIMARY evaluation. Per outer fold: test = fold assets, inner validation = next
    fold's assets, train = the rest. The operating threshold comes from each fold's own
    inner validation and is applied to that fold's test events; binary predictions are
    then pooled. Result: 58 out-of-fold events, 27 positives.
    """
    oof, hists, wt_all, wv_all = [], [], [], []

    for fi in range(len(folds)):
        te_a, va_a = folds[fi], folds[(fi + 1) % len(folds)]
        te = [i for i in range(len(STORE)) if ASSET_OF[i] in te_a]
        va = [i for i in range(len(STORE)) if ASSET_OF[i] in va_a]
        tr = [i for i in range(len(STORE)) if ASSET_OF[i] not in (te_a | va_a)]
        if verbose:
            print(f"  fold {fi}: train={len(tr)} val={len(va)} test={len(te)} events")

        vs, ts, wt, wv = [], [], [], []
        for sd in seeds:
            ck = CKPT_DIR / f"{safe_name(name)}__fold{fi}__seed{sd}.pt"
            m, h = train_bag_model(model_fn, tr, va, sd, ckpt=ck, log=verbose)
            h["fold"], h["seed"], h["model"] = fi, sd, name
            hists.append(h)

            if keep_windows:
                vev, vwin = score_events(m, va, return_windows=True)
                tev, twin = score_events(m, te, return_windows=True)
                wv.append(vwin); wt.append(twin)
            else:
                vev = score_events(m, va)
                tev = score_events(m, te)

            vs.append(vev.sort_values("event_id").reset_index(drop=True))
            ts.append(tev.sort_values("event_id").reset_index(drop=True))

            del m
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        ve = vs[0].copy(); ve["score"] = np.mean([d.score.to_numpy() for d in vs], axis=0)
        tf = ts[0].copy(); tf["score"] = np.mean([d.score.to_numpy() for d in ts], axis=0)

        tau = choose_threshold(ve.label.to_numpy(), ve.score.to_numpy())
        tf["pred"] = (tf.score.to_numpy() >= tau).astype(int)
        tf["fold"] = fi
        tf["threshold"] = tau
        oof.append(tf)

        if keep_windows:
            a = _avg_windows(wt); a["fold"] = fi; wt_all.append(a)
            b = _avg_windows(wv); b["fold"] = fi; wv_all.append(b)

        if verbose:
            print(f"    fold {fi}: tau={tau:+.4f}  "
                  f"test TP={int(((tf.label==1)&(tf.pred==1)).sum())} "
                  f"FN={int(((tf.label==1)&(tf.pred==0)).sum())} "
                  f"FP={int(((tf.label==0)&(tf.pred==1)).sum())} "
                  f"TN={int(((tf.label==0)&(tf.pred==0)).sum())}")

    oof = pd.concat(oof, ignore_index=True)
    oof["model"] = name
    hist = pd.concat(hists, ignore_index=True)

    if keep_windows:
        return oof, hist, pd.concat(wt_all, ignore_index=True), \
               pd.concat(wv_all, ignore_index=True)
    return oof, hist


def run_frozen_split(name, model_fn, seeds=SEEDS, verbose=True):
    """SECONDARY evaluation on the original frozen 32/13/13 asset-disjoint split."""
    tr = [i for i in range(len(STORE)) if STORE[i]["split"] == "train"]
    va = [i for i in range(len(STORE)) if STORE[i]["split"] == "val"]
    te = [i for i in range(len(STORE)) if STORE[i]["split"] == "test"]

    vs, ts = [], []
    for sd in seeds:
        ck = CKPT_DIR / f"{safe_name(name)}__frozen__seed{sd}.pt"
        m, _ = train_bag_model(model_fn, tr, va, sd, ckpt=ck, log=verbose)
        vs.append(score_events(m, va).sort_values("event_id").reset_index(drop=True))
        ts.append(score_events(m, te).sort_values("event_id").reset_index(drop=True))
        del m
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    ve = vs[0].copy(); ve["score"] = np.mean([d.score.to_numpy() for d in vs], axis=0)
    tf = ts[0].copy(); tf["score"] = np.mean([d.score.to_numpy() for d in ts], axis=0)
    tau = choose_threshold(ve.label.to_numpy(), ve.score.to_numpy())
    tf["pred"] = (tf.score.to_numpy() >= tau).astype(int)
    return ve, tf, tau


# ---- PRIMARY: main comparison -------------------------------------------------------
oof_bank, hist_bank, win_bank = {}, {}, {}

for nm, fn in MAIN_MODELS.items():
    print("\n" + "=" * 110)
    print("MAIN  " + nm)
    print("=" * 110)
    if nm == PROPOSED:
        o, h, wt, wv = run_grouped_cv(nm, fn, FOLDS, keep_windows=True)
        win_bank[nm] = {"test": wt, "val": wv}
    else:
        o, h = run_grouped_cv(nm, fn, FOLDS)
    oof_bank[nm], hist_bank[nm] = o, h

# ---- PRIMARY: ablation ladder -------------------------------------------------------
# A0 == Plain Transformer and A3 == the proposed model. With REUSE_A0_A3 = True those two
# rungs reuse the main-comparison runs (30 fewer trainings). State this in the caption.
REUSED = {"A0 Plain Transformer": "Plain Transformer",
          "A3 + Attentive Pooling": PROPOSED} if REUSE_A0_A3 else {}

abl_bank, abl_hist = {}, {}
for nm, fn in ABLATION_MODELS.items():
    if nm in REUSED:
        src = REUSED[nm]
        abl_bank[nm] = oof_bank[src].copy()
        abl_bank[nm]["model"] = nm
        abl_hist[nm] = hist_bank[src].copy()
        abl_hist[nm]["model"] = nm
        print(f"\nABLATION  {nm}  <- reusing the '{src}' runs (identical architecture)")
        continue
    print("\n" + "=" * 110)
    print("ABLATION  " + nm)
    print("=" * 110)
    o, h = run_grouped_cv(nm, fn, FOLDS, seeds=ABLATION_SEEDS)
    abl_bank[nm], abl_hist[nm] = o, h

# ---- SECONDARY: frozen 13-event split, proposed model only --------------------------
print("\n" + "=" * 110)
print("SECONDARY  frozen 32/13/13 split  —  " + PROPOSED)
print("=" * 110)
frozen_val, frozen_test, frozen_tau = run_frozen_split(PROPOSED, MAIN_MODELS[PROPOSED])

pd.concat(oof_bank.values(), ignore_index=True).to_csv(
    RESULT / "OOF_event_scores_main.csv", index=False)
pd.concat(abl_bank.values(), ignore_index=True).to_csv(
    RESULT / "OOF_event_scores_ablation.csv", index=False)
pd.concat(list(hist_bank.values()) + list(abl_hist.values()), ignore_index=True).to_csv(
    RESULT / "training_histories.csv", index=False)
frozen_test.to_csv(RESULT / "FROZEN_split_test_event_scores.csv", index=False)
win_bank[PROPOSED]["test"].to_csv(RESULT / "OOF_window_logits_proposed_test.csv", index=False)

print("\nAll models trained. Event scores and window logits saved to", RESULT)
# Out:
# ==============================================================================================================
# MAIN  Plain Transformer
# ==============================================================================================================
#   fold 0: train=33 val=12 test=13 events
#     ep=01 loss=0.7752 val_ev_ROC=0.343 val_ev_PR=0.379 val_win_ROC=0.587 crit=0.4161
#     ep=02 loss=0.2369 val_ev_ROC=0.286 val_ev_PR=0.360 val_win_ROC=0.628 crit=0.3884
#     ep=03 loss=0.0316 val_ev_ROC=0.371 val_ev_PR=0.396 val_win_ROC=0.652 crit=0.4556
#     ep=04 loss=0.0165 val_ev_ROC=0.371 val_ev_PR=0.405 val_win_ROC=0.663 crit=0.4589
#     ep=05 loss=0.0057 val_ev_ROC=0.314 val_ev_PR=0.389 val_win_ROC=0.668 crit=0.4205
#     ep=06 loss=0.0019 val_ev_ROC=0.314 val_ev_PR=0.389 val_win_ROC=0.671 crit=0.4214
#     ep=07 loss=0.0048 val_ev_ROC=0.314 val_ev_PR=0.389 val_win_ROC=0.672 crit=0.4216
#     ep=08 loss=0.0011 val_ev_ROC=0.314 val_ev_PR=0.389 val_win_ROC=0.673 crit=0.4220
#     ep=09 loss=0.0008 val_ev_ROC=0.286 val_ev_PR=0.383 val_win_ROC=0.673 crit=0.4018
#     ep=10 loss=0.0006 val_ev_ROC=0.314 val_ev_PR=0.389 val_win_ROC=0.670 crit=0.4211
#     ep=11 loss=0.0005 val_ev_ROC=0.314 val_ev_PR=0.389 val_win_ROC=0.667 crit=0.4202
#     ep=12 loss=0.0004 val_ev_ROC=0.314 val_ev_PR=0.378 val_win_ROC=0.665 crit=0.4195
#     early stop at epoch 12 (best crit=0.4589)
#     ep=01 loss=0.7792 val_ev_ROC=0.429 val_ev_PR=0.526 val_win_ROC=0.590 crit=0.4769
#     ep=02 loss=0.2319 val_ev_ROC=0.457 val_ev_PR=0.531 val_win_ROC=0.543 crit=0.4830
#     ep=03 loss=0.0156 val_ev_ROC=0.486 val_ev_PR=0.557 val_win_ROC=0.497 crit=0.4891
#     ep=04 loss=0.0051 val_ev_ROC=0.514 val_ev_PR=0.504 val_win_ROC=0.490 crit=0.5069
#     ep=05 loss=0.0117 val_ev_ROC=0.514 val_ev_PR=0.480 val_win_ROC=0.489 crit=0.5068
#     ep=06 loss=0.0067 val_ev_ROC=0.429 val_ev_PR=0.432 val_win_ROC=0.470 crit=0.4411
#     ep=07 loss=0.0017 val_ev_ROC=0.429 val_ev_PR=0.435 val_win_ROC=0.482 crit=0.4445
#     ep=08 loss=0.0021 val_ev_ROC=0.457 val_ev_PR=0.455 val_win_ROC=0.493 crit=0.4679
#     ep=09 loss=0.0007 val_ev_ROC=0.457 val_ev_PR=0.455 val_win_ROC=0.494 crit=0.4681
#     ep=10 loss=0.0005 val_ev_ROC=0.457 val_ev_PR=0.431 val_win_ROC=0.493 crit=0.4679
#     ep=11 loss=0.0042 val_ev_ROC=0.457 val_ev_PR=0.431 val_win_ROC=0.493 crit=0.4680
#     ep=12 loss=0.0005 val_ev_ROC=0.457 val_ev_PR=0.431 val_win_ROC=0.492 crit=0.4677
#     early stop at epoch 12 (best crit=0.5069)
#     ep=01 loss=0.7368 val_ev_ROC=0.400 val_ev_PR=0.413 val_win_ROC=0.518 crit=0.4355
#     ep=02 loss=0.2112 val_ev_ROC=0.400 val_ev_PR=0.401 val_win_ROC=0.538 crit=0.4414
#     ep=03 loss=0.0369 val_ev_ROC=0.429 val_ev_PR=0.410 val_win_ROC=0.564 crit=0.4692
#     ep=04 loss=0.0098 val_ev_ROC=0.429 val_ev_PR=0.410 val_win_ROC=0.590 crit=0.4769
#     ep=05 loss=0.0061 val_ev_ROC=0.457 val_ev_PR=0.443 val_win_ROC=0.601 crit=0.5002
#     ep=06 loss=0.0015 val_ev_ROC=0.457 val_ev_PR=0.443 val_win_ROC=0.604 crit=0.5012
#     ep=07 loss=0.0010 val_ev_ROC=0.486 val_ev_PR=0.457 val_win_ROC=0.597 crit=0.5192
#     ep=08 loss=0.0032 val_ev_ROC=0.486 val_ev_PR=0.457 val_win_ROC=0.603 crit=0.5210
#     ep=09 loss=0.0020 val_ev_ROC=0.514 val_ev_PR=0.471 val_win_ROC=0.614 crit=0.5443
#     ep=10 loss=0.0005 val_ev_ROC=0.514 val_ev_PR=0.471 val_win_ROC=0.623 crit=0.5470
#     ep=11 loss=0.0032 val_ev_ROC=0.486 val_ev_PR=0.460 val_win_ROC=0.626 crit=0.5278
#     ep=12 loss=0.0005 val_ev_ROC=0.457 val_ev_PR=0.452 val_win_ROC=0.615 crit=0.5046
#     ep=13 loss=0.0003 val_ev_ROC=0.429 val_ev_PR=0.419 val_win_ROC=0.605 crit=0.4815
#     ep=14 loss=0.0002 val_ev_ROC=0.371 val_ev_PR=0.393 val_win_ROC=0.596 crit=0.4389
#     ep=15 loss=0.0002 val_ev_ROC=0.400 val_ev_PR=0.410 val_win_ROC=0.588 crit=0.4565
#     ep=16 loss=0.0002 val_ev_ROC=0.371 val_ev_PR=0.403 val_win_ROC=0.581 crit=0.4342
#     ep=17 loss=0.0002 val_ev_ROC=0.371 val_ev_PR=0.403 val_win_ROC=0.574 crit=0.4321
#     ep=18 loss=0.0001 val_ev_ROC=0.371 val_ev_PR=0.403 val_win_ROC=0.567 crit=0.4302
#     early stop at epoch 18 (best crit=0.5470)
#     fold 0: tau=-0.4297  test TP=5 FN=1 FP=5 TN=2
#   fold 1: train=29 val=17 test=12 events
#     ep=01 loss=0.8132 val_ev_ROC=0.806 val_ev_PR=0.712 val_win_ROC=0.565 crit=0.7334
#     ep=02 loss=0.2460 val_ev_ROC=0.792 val_ev_PR=0.707 val_win_ROC=0.584 crit=0.7293
#     ep=03 loss=0.0292 val_ev_ROC=0.847 val_ev_PR=0.862 val_win_ROC=0.594 crit=0.7712
#     ep=04 loss=0.0091 val_ev_ROC=0.833 val_ev_PR=0.867 val_win_ROC=0.595 crit=0.7619
#     ep=05 loss=0.0128 val_ev_ROC=0.833 val_ev_PR=0.867 val_win_ROC=0.577 crit=0.7565
#     ep=06 loss=0.0018 val_ev_ROC=0.833 val_ev_PR=0.867 val_win_ROC=0.566 crit=0.7531
#     ep=07 loss=0.0012 val_ev_ROC=0.819 val_ev_PR=0.859 val_win_ROC=0.560 crit=0.7417
#     ep=08 loss=0.0009 val_ev_ROC=0.806 val_ev_PR=0.851 val_win_ROC=0.558 crit=0.7312
#     ep=09 loss=0.0007 val_ev_ROC=0.806 val_ev_PR=0.851 val_win_ROC=0.556 crit=0.7307
#     ep=10 loss=0.0005 val_ev_ROC=0.806 val_ev_PR=0.851 val_win_ROC=0.556 crit=0.7306
#     ep=11 loss=0.0005 val_ev_ROC=0.806 val_ev_PR=0.851 val_win_ROC=0.557 crit=0.7309
#     early stop at epoch 11 (best crit=0.7712)
#     ep=01 loss=0.7482 val_ev_ROC=0.306 val_ev_PR=0.390 val_win_ROC=0.325 crit=0.3113
#     ep=02 loss=0.1780 val_ev_ROC=0.306 val_ev_PR=0.389 val_win_ROC=0.371 crit=0.3253
#     ep=03 loss=0.0136 val_ev_ROC=0.333 val_ev_PR=0.407 val_win_ROC=0.425 crit=0.3609
#     ep=04 loss=0.0038 val_ev_ROC=0.361 val_ev_PR=0.428 val_win_ROC=0.468 crit=0.3932
#     ep=05 loss=0.0020 val_ev_ROC=0.403 val_ev_PR=0.454 val_win_ROC=0.497 crit=0.4312
#     ep=06 loss=0.0019 val_ev_ROC=0.458 val_ev_PR=0.487 val_win_ROC=0.516 crit=0.4756
#     ep=07 loss=0.0477 val_ev_ROC=0.500 val_ev_PR=0.516 val_win_ROC=0.530 crit=0.5089
#     ep=08 loss=0.0012 val_ev_ROC=0.486 val_ev_PR=0.520 val_win_ROC=0.514 crit=0.4946
#     ep=09 loss=0.0007 val_ev_ROC=0.500 val_ev_PR=0.620 val_win_ROC=0.504 crit=0.5012
#     ep=10 loss=0.0005 val_ev_ROC=0.528 val_ev_PR=0.633 val_win_ROC=0.497 crit=0.5184
#     ep=11 loss=0.0005 val_ev_ROC=0.542 val_ev_PR=0.637 val_win_ROC=0.493 crit=0.5271
#     ep=12 loss=0.0012 val_ev_ROC=0.528 val_ev_PR=0.628 val_win_ROC=0.488 crit=0.5159
#     ep=13 loss=0.0007 val_ev_ROC=0.542 val_ev_PR=0.630 val_win_ROC=0.497 crit=0.5283
#     ep=14 loss=0.0003 val_ev_ROC=0.542 val_ev_PR=0.630 val_win_ROC=0.508 crit=0.5316
#     ep=15 loss=0.0002 val_ev_ROC=0.542 val_ev_PR=0.630 val_win_ROC=0.518 crit=0.5347
#     ep=16 loss=0.0002 val_ev_ROC=0.556 val_ev_PR=0.634 val_win_ROC=0.528 crit=0.5474
#     ep=17 loss=0.0002 val_ev_ROC=0.556 val_ev_PR=0.634 val_win_ROC=0.537 crit=0.5501
#     ep=18 loss=0.0002 val_ev_ROC=0.556 val_ev_PR=0.634 val_win_ROC=0.545 crit=0.5525
#     ep=19 loss=0.0002 val_ev_ROC=0.556 val_ev_PR=0.634 val_win_ROC=0.553 crit=0.5547
#     ep=20 loss=0.0001 val_ev_ROC=0.556 val_ev_PR=0.634 val_win_ROC=0.559 crit=0.5566
#     ep=21 loss=0.0001 val_ev_ROC=0.556 val_ev_PR=0.634 val_win_ROC=0.565 crit=0.5583
#     ep=22 loss=0.0001 val_ev_ROC=0.569 val_ev_PR=0.646 val_win_ROC=0.570 crit=0.5695
#     ep=23 loss=0.0001 val_ev_ROC=0.569 val_ev_PR=0.646 val_win_ROC=0.574 crit=0.5708
#     ep=24 loss=0.0001 val_ev_ROC=0.569 val_ev_PR=0.646 val_win_ROC=0.578 crit=0.5721
#     ep=25 loss=0.0001 val_ev_ROC=0.569 val_ev_PR=0.646 val_win_ROC=0.582 crit=0.5732
#     ep=26 loss=0.0001 val_ev_ROC=0.569 val_ev_PR=0.646 val_win_ROC=0.586 crit=0.5743
#     ep=27 loss=0.0001 val_ev_ROC=0.583 val_ev_PR=0.665 val_win_ROC=0.589 crit=0.5850
#     ep=28 loss=0.0001 val_ev_ROC=0.583 val_ev_PR=0.665 val_win_ROC=0.591 crit=0.5858
#     ep=29 loss=0.0001 val_ev_ROC=0.583 val_ev_PR=0.665 val_win_ROC=0.594 crit=0.5865
#     ep=30 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.596 crit=0.5969
#     ep=31 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.598 crit=0.5975
#     ep=32 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.600 crit=0.5980
#     ep=33 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.601 crit=0.5984
#     ep=34 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.602 crit=0.5987
#     ep=35 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.603 crit=0.5990
#     ep=36 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.604 crit=0.5993
#     ep=37 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.605 crit=0.5996
#     ep=38 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.606 crit=0.5998
#     ep=39 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.606 crit=0.6000
#     ep=40 loss=0.0001 val_ev_ROC=0.597 val_ev_PR=0.670 val_win_ROC=0.607 crit=0.6002
#     ep=01 loss=0.7328 val_ev_ROC=0.444 val_ev_PR=0.523 val_win_ROC=0.342 crit=0.4136
#     ep=02 loss=0.1537 val_ev_ROC=0.500 val_ev_PR=0.550 val_win_ROC=0.381 crit=0.4642
#     ep=03 loss=0.0136 val_ev_ROC=0.500 val_ev_PR=0.555 val_win_ROC=0.434 crit=0.4803
#     ep=04 loss=0.0066 val_ev_ROC=0.556 val_ev_PR=0.572 val_win_ROC=0.468 crit=0.5292
#     ep=05 loss=0.0033 val_ev_ROC=0.583 val_ev_PR=0.583 val_win_ROC=0.490 crit=0.5555
#     ep=06 loss=0.0046 val_ev_ROC=0.625 val_ev_PR=0.617 val_win_ROC=0.506 crit=0.5892
#     ep=07 loss=0.0017 val_ev_ROC=0.597 val_ev_PR=0.596 val_win_ROC=0.502 crit=0.5687
#     ep=08 loss=0.0009 val_ev_ROC=0.625 val_ev_PR=0.614 val_win_ROC=0.505 crit=0.5889
#     ep=09 loss=0.0071 val_ev_ROC=0.681 val_ev_PR=0.655 val_win_ROC=0.504 crit=0.6276
#     ep=10 loss=0.0034 val_ev_ROC=0.708 val_ev_PR=0.704 val_win_ROC=0.501 crit=0.6462
#     ep=11 loss=0.0006 val_ev_ROC=0.708 val_ev_PR=0.704 val_win_ROC=0.505 crit=0.6472
#     ep=12 loss=0.0003 val_ev_ROC=0.736 val_ev_PR=0.722 val_win_ROC=0.514 crit=0.6694
#     ep=13 loss=0.0003 val_ev_ROC=0.736 val_ev_PR=0.722 val_win_ROC=0.518 crit=0.6707
#     ep=14 loss=0.0002 val_ev_ROC=0.750 val_ev_PR=0.741 val_win_ROC=0.521 crit=0.6814
#     ep=15 loss=0.0002 val_ev_ROC=0.736 val_ev_PR=0.733 val_win_ROC=0.524 crit=0.6725
#     ep=16 loss=0.0002 val_ev_ROC=0.722 val_ev_PR=0.725 val_win_ROC=0.527 crit=0.6635
#     ep=17 loss=0.0002 val_ev_ROC=0.722 val_ev_PR=0.725 val_win_ROC=0.529 crit=0.6643
#     ep=18 loss=0.0001 val_ev_ROC=0.722 val_ev_PR=0.725 val_win_ROC=0.531 crit=0.6649
#     ep=19 loss=0.0001 val_ev_ROC=0.722 val_ev_PR=0.725 val_win_ROC=0.533 crit=0.6655
#     ep=20 loss=0.0001 val_ev_ROC=0.708 val_ev_PR=0.706 val_win_ROC=0.535 crit=0.6565
#     ep=21 loss=0.0001 val_ev_ROC=0.694 val_ev_PR=0.697 val_win_ROC=0.537 crit=0.6473
#     ep=22 loss=0.0001 val_ev_ROC=0.694 val_ev_PR=0.697 val_win_ROC=0.539 crit=0.6479
#     early stop at epoch 22 (best crit=0.6814)
#     fold 1: tau=-5.8180  test TP=3 FN=2 FP=4 TN=3
#   fold 2: train=33 val=8 test=17 events
#     ep=01 loss=0.8145 val_ev_ROC=0.250 val_ev_PR=0.440 val_win_ROC=0.443 crit=0.3080
#     ep=02 loss=0.3006 val_ev_ROC=0.500 val_ev_PR=0.525 val_win_ROC=0.449 crit=0.4847
#     ep=03 loss=0.0233 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.459 crit=0.4878
#     ep=04 loss=0.0062 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.473 crit=0.5795
#     ep=05 loss=0.0188 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.488 crit=0.4964
#     ep=06 loss=0.0230 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.513 crit=0.5040
#     ep=07 loss=0.0028 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.533 crit=0.5098
#     ep=08 loss=0.0014 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.541 crit=0.5124
#     ep=09 loss=0.0006 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.547 crit=0.5142
#     ep=10 loss=0.0005 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.550 crit=0.5588
#     ep=11 loss=0.0004 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.548 crit=0.5582
#     ep=12 loss=0.0003 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.545 crit=0.5573
#     early stop at epoch 12 (best crit=0.5795)
#     ep=01 loss=0.7747 val_ev_ROC=0.375 val_ev_PR=0.483 val_win_ROC=0.310 crit=0.3555
#     ep=02 loss=0.2309 val_ev_ROC=0.375 val_ev_PR=0.483 val_win_ROC=0.400 crit=0.3826
#     ep=03 loss=0.0247 val_ev_ROC=0.375 val_ev_PR=0.483 val_win_ROC=0.504 crit=0.4137
#     ep=04 loss=0.0047 val_ev_ROC=0.375 val_ev_PR=0.500 val_win_ROC=0.565 crit=0.4319
#     ep=05 loss=0.0019 val_ev_ROC=0.438 val_ev_PR=0.542 val_win_ROC=0.602 crit=0.4869
#     ep=06 loss=0.0012 val_ev_ROC=0.438 val_ev_PR=0.542 val_win_ROC=0.628 crit=0.4946
#     ep=07 loss=0.0009 val_ev_ROC=0.438 val_ev_PR=0.542 val_win_ROC=0.648 crit=0.5008
#     ep=08 loss=0.0006 val_ev_ROC=0.375 val_ev_PR=0.500 val_win_ROC=0.663 crit=0.4614
#     ep=09 loss=0.0011 val_ev_ROC=0.438 val_ev_PR=0.625 val_win_ROC=0.678 crit=0.5095
#     ep=10 loss=0.0004 val_ev_ROC=0.438 val_ev_PR=0.625 val_win_ROC=0.676 crit=0.5090
#     ep=11 loss=0.0003 val_ev_ROC=0.438 val_ev_PR=0.625 val_win_ROC=0.675 crit=0.5087
#     ep=12 loss=0.0003 val_ev_ROC=0.438 val_ev_PR=0.625 val_win_ROC=0.673 crit=0.5082
#     ep=13 loss=0.0002 val_ev_ROC=0.438 val_ev_PR=0.625 val_win_ROC=0.673 crit=0.5082
#     ep=14 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.673 crit=0.5520
#     ep=15 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.671 crit=0.5514
#     ep=16 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.669 crit=0.5508
#     ep=17 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.666 crit=0.5499
#     ep=18 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.664 crit=0.5492
#     ep=19 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.663 crit=0.5490
#     ep=20 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.663 crit=0.5490
#     ep=21 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.663 crit=0.5928
#     ep=22 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.664 crit=0.5929
#     ep=23 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.662 crit=0.5925
#     ep=24 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.661 crit=0.5482
#     ep=25 loss=0.0014 val_ev_ROC=0.500 val_ev_PR=0.650 val_win_ROC=0.659 crit=0.5477
#     ep=26 loss=0.0006 val_ev_ROC=0.438 val_ev_PR=0.525 val_win_ROC=0.653 crit=0.5022
#     ep=27 loss=0.0001 val_ev_ROC=0.438 val_ev_PR=0.525 val_win_ROC=0.645 crit=0.4997
#     ep=28 loss=0.0001 val_ev_ROC=0.375 val_ev_PR=0.500 val_win_ROC=0.637 crit=0.4536
#     ep=29 loss=0.0001 val_ev_ROC=0.375 val_ev_PR=0.500 val_win_ROC=0.630 crit=0.4516
#     ep=30 loss=0.0002 val_ev_ROC=0.375 val_ev_PR=0.500 val_win_ROC=0.629 crit=0.4511
#     early stop at epoch 30 (best crit=0.5929)
#     ep=01 loss=0.7378 val_ev_ROC=0.312 val_ev_PR=0.458 val_win_ROC=0.313 crit=0.3126
#     ep=02 loss=0.2044 val_ev_ROC=0.375 val_ev_PR=0.476 val_win_ROC=0.448 crit=0.3969
#     ep=03 loss=0.0345 val_ev_ROC=0.500 val_ev_PR=0.525 val_win_ROC=0.568 crit=0.5205
#     ep=04 loss=0.0106 val_ev_ROC=0.500 val_ev_PR=0.543 val_win_ROC=0.651 crit=0.5454
#     ep=05 loss=0.0021 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.710 crit=0.6505
#     ep=06 loss=0.0012 val_ev_ROC=0.562 val_ev_PR=0.604 val_win_ROC=0.734 crit=0.6138
#     ep=07 loss=0.0018 val_ev_ROC=0.562 val_ev_PR=0.604 val_win_ROC=0.739 crit=0.6156
#     ep=08 loss=0.0009 val_ev_ROC=0.562 val_ev_PR=0.585 val_win_ROC=0.731 crit=0.6131
#     ep=09 loss=0.0007 val_ev_ROC=0.562 val_ev_PR=0.585 val_win_ROC=0.730 crit=0.6127
#     ep=10 loss=0.0008 val_ev_ROC=0.562 val_ev_PR=0.585 val_win_ROC=0.723 crit=0.6107
#     ep=11 loss=0.0010 val_ev_ROC=0.562 val_ev_PR=0.585 val_win_ROC=0.714 crit=0.6081
#     ep=12 loss=0.0250 val_ev_ROC=0.562 val_ev_PR=0.585 val_win_ROC=0.711 crit=0.6072
#     ep=13 loss=0.0008 val_ev_ROC=0.562 val_ev_PR=0.668 val_win_ROC=0.722 crit=0.6104
#     early stop at epoch 13 (best crit=0.6505)
#     fold 2: tau=+1.5782  test TP=0 FN=8 FP=1 TN=8
#   fold 3: train=42 val=8 test=8 events
#     ep=01 loss=0.8199 val_ev_ROC=0.500 val_ev_PR=0.643 val_win_ROC=0.596 crit=0.5289
#     ep=02 loss=0.4346 val_ev_ROC=0.562 val_ev_PR=0.750 val_win_ROC=0.666 crit=0.5936
#     ep=03 loss=0.1364 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.715 crit=0.6521
#     ep=04 loss=0.0148 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.726 crit=0.6553
#     ep=05 loss=0.0049 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.724 crit=0.6546
#     ep=06 loss=0.0036 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.724 crit=0.6546
#     ep=07 loss=0.0055 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.725 crit=0.6988
#     ep=08 loss=0.0009 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.727 crit=0.6555
#     ep=09 loss=0.0006 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.728 crit=0.6559
#     ep=10 loss=0.0005 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.730 crit=0.6564
#     ep=11 loss=0.0004 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.731 crit=0.7004
#     ep=12 loss=0.0004 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.731 crit=0.7006
#     ep=13 loss=0.0003 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.731 crit=0.6569
#     ep=14 loss=0.0004 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.732 crit=0.6570
#     ep=15 loss=0.0003 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.732 crit=0.6572
#     ep=16 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.732 crit=0.6572
#     ep=17 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.732 crit=0.6572
#     ep=18 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.732 crit=0.6572
#     ep=19 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.732 crit=0.6572
#     ep=20 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.733 crit=0.6573
#     early stop at epoch 20 (best crit=0.7006)
#     ep=01 loss=0.7969 val_ev_ROC=0.438 val_ev_PR=0.518 val_win_ROC=0.565 crit=0.4757
#     ep=02 loss=0.3665 val_ev_ROC=0.438 val_ev_PR=0.518 val_win_ROC=0.621 crit=0.4925
#     ep=03 loss=0.0779 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.659 crit=0.5476
#     ep=04 loss=0.0100 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.676 crit=0.5528
#     ep=05 loss=0.0450 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.686 crit=0.5559
#     ep=06 loss=0.0066 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.695 crit=0.5584
#     ep=07 loss=0.0013 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.703 crit=0.5608
#     ep=08 loss=0.0008 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.708 crit=0.5624
#     ep=09 loss=0.0005 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.711 crit=0.5633
#     ep=10 loss=0.0004 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.713 crit=0.5638
#     ep=11 loss=0.0007 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.715 crit=0.5645
#     ep=12 loss=0.0003 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.717 crit=0.5652
#     ep=13 loss=0.0003 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.717 crit=0.5652
#     ep=14 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.717 crit=0.5651
#     ep=15 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.717 crit=0.5651
#     ep=16 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.717 crit=0.5650
#     ep=17 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.715 crit=0.5645
#     ep=18 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.714 crit=0.5642
#     ep=19 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.713 crit=0.5640
#     ep=20 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.713 crit=0.5638
#     ep=21 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.712 crit=0.5636
#     early stop at epoch 21 (best crit=0.5652)
#     ep=01 loss=0.7656 val_ev_ROC=0.812 val_ev_PR=0.804 val_win_ROC=0.728 crit=0.7872
#     ep=02 loss=0.3336 val_ev_ROC=0.875 val_ev_PR=0.917 val_win_ROC=0.746 crit=0.8363
#     ep=03 loss=0.0944 val_ev_ROC=0.688 val_ev_PR=0.733 val_win_ROC=0.756 crit=0.7080
#     ep=04 loss=0.0240 val_ev_ROC=0.750 val_ev_PR=0.771 val_win_ROC=0.771 crit=0.7563
#     ep=05 loss=0.0030 val_ev_ROC=0.750 val_ev_PR=0.771 val_win_ROC=0.782 crit=0.7597
#     ep=06 loss=0.0015 val_ev_ROC=0.750 val_ev_PR=0.771 val_win_ROC=0.791 crit=0.7624
#     ep=07 loss=0.0008 val_ev_ROC=0.812 val_ev_PR=0.854 val_win_ROC=0.799 crit=0.8083
#     ep=08 loss=0.0086 val_ev_ROC=0.812 val_ev_PR=0.854 val_win_ROC=0.802 crit=0.8094
#     ep=09 loss=0.0060 val_ev_ROC=0.812 val_ev_PR=0.854 val_win_ROC=0.805 crit=0.8102
#     ep=10 loss=0.0005 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.805 crit=0.7666
#     early stop at epoch 10 (best crit=0.8363)
#     fold 3: tau=+0.9076  test TP=3 FN=1 FP=2 TN=2
#   fold 4: train=37 val=13 test=8 events
#     ep=01 loss=0.7951 val_ev_ROC=0.286 val_ev_PR=0.419 val_win_ROC=0.348 crit=0.3045
#     ep=02 loss=0.3205 val_ev_ROC=0.310 val_ev_PR=0.421 val_win_ROC=0.412 crit=0.3401
#     ep=03 loss=0.0566 val_ev_ROC=0.405 val_ev_PR=0.456 val_win_ROC=0.462 crit=0.4220
#     ep=04 loss=0.0123 val_ev_ROC=0.452 val_ev_PR=0.493 val_win_ROC=0.494 crit=0.4647
#     ep=05 loss=0.0031 val_ev_ROC=0.429 val_ev_PR=0.477 val_win_ROC=0.513 crit=0.4538
#     ep=06 loss=0.0020 val_ev_ROC=0.381 val_ev_PR=0.454 val_win_ROC=0.526 crit=0.4246
#     ep=07 loss=0.0051 val_ev_ROC=0.405 val_ev_PR=0.463 val_win_ROC=0.538 crit=0.4446
#     ep=08 loss=0.0017 val_ev_ROC=0.381 val_ev_PR=0.451 val_win_ROC=0.550 crit=0.4318
#     ep=09 loss=0.0007 val_ev_ROC=0.405 val_ev_PR=0.530 val_win_ROC=0.564 crit=0.4526
#     ep=10 loss=0.0023 val_ev_ROC=0.405 val_ev_PR=0.530 val_win_ROC=0.579 crit=0.4572
#     ep=11 loss=0.0019 val_ev_ROC=0.405 val_ev_PR=0.530 val_win_ROC=0.596 crit=0.4621
#     ep=12 loss=0.0005 val_ev_ROC=0.381 val_ev_PR=0.430 val_win_ROC=0.605 crit=0.4482
#     early stop at epoch 12 (best crit=0.4647)
#     ep=01 loss=0.7919 val_ev_ROC=0.357 val_ev_PR=0.417 val_win_ROC=0.305 crit=0.3414
#     ep=02 loss=0.2794 val_ev_ROC=0.452 val_ev_PR=0.472 val_win_ROC=0.348 crit=0.4211
#     ep=03 loss=0.0227 val_ev_ROC=0.524 val_ev_PR=0.588 val_win_ROC=0.396 crit=0.4856
#     ep=04 loss=0.0043 val_ev_ROC=0.476 val_ev_PR=0.565 val_win_ROC=0.462 crit=0.4720
#     ep=05 loss=0.0104 val_ev_ROC=0.452 val_ev_PR=0.553 val_win_ROC=0.523 crit=0.4737
#     ep=06 loss=0.0014 val_ev_ROC=0.429 val_ev_PR=0.543 val_win_ROC=0.562 crit=0.4686
#     ep=07 loss=0.0031 val_ev_ROC=0.405 val_ev_PR=0.536 val_win_ROC=0.585 crit=0.4590
#     ep=08 loss=0.0052 val_ev_ROC=0.429 val_ev_PR=0.543 val_win_ROC=0.600 crit=0.4800
#     ep=09 loss=0.0007 val_ev_ROC=0.429 val_ev_PR=0.548 val_win_ROC=0.610 crit=0.4831
#     ep=10 loss=0.0005 val_ev_ROC=0.405 val_ev_PR=0.542 val_win_ROC=0.619 crit=0.4689
#     ep=11 loss=0.0004 val_ev_ROC=0.429 val_ev_PR=0.551 val_win_ROC=0.625 crit=0.4875
#     ep=12 loss=0.0004 val_ev_ROC=0.452 val_ev_PR=0.579 val_win_ROC=0.629 crit=0.5054
#     ep=13 loss=0.0004 val_ev_ROC=0.429 val_ev_PR=0.570 val_win_ROC=0.631 crit=0.4894
#     ep=14 loss=0.0020 val_ev_ROC=0.405 val_ev_PR=0.542 val_win_ROC=0.630 crit=0.4724
#     ep=15 loss=0.0003 val_ev_ROC=0.429 val_ev_PR=0.551 val_win_ROC=0.632 crit=0.4896
#     ep=16 loss=0.0002 val_ev_ROC=0.429 val_ev_PR=0.551 val_win_ROC=0.634 crit=0.4902
#     ep=17 loss=0.0012 val_ev_ROC=0.429 val_ev_PR=0.551 val_win_ROC=0.634 crit=0.4903
#     ep=18 loss=0.0007 val_ev_ROC=0.500 val_ev_PR=0.577 val_win_ROC=0.638 crit=0.5413
#     ep=19 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.577 val_win_ROC=0.642 crit=0.5427
#     ep=20 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.577 val_win_ROC=0.647 crit=0.5441
#     ep=21 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.577 val_win_ROC=0.651 crit=0.5453
#     ep=22 loss=0.0001 val_ev_ROC=0.500 val_ev_PR=0.577 val_win_ROC=0.654 crit=0.5463
#     ep=23 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.657 crit=0.5638
#     ep=24 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.660 crit=0.5646
#     ep=25 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.662 crit=0.5652
#     ep=26 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.664 crit=0.5658
#     ep=27 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.666 crit=0.5664
#     ep=28 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.668 crit=0.5670
#     ep=29 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.670 crit=0.5677
#     ep=30 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.672 crit=0.5682
#     ep=31 loss=0.0001 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.674 crit=0.5687
#     ep=32 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.675 crit=0.5859
#     ep=33 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.676 crit=0.5863
#     ep=34 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.678 crit=0.5867
#     ep=35 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.679 crit=0.5871
#     ep=36 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.680 crit=0.5874
#     ep=37 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.681 crit=0.5877
#     ep=38 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.682 crit=0.5880
#     ep=39 loss=0.0009 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.683 crit=0.5882
#     ep=40 loss=0.0001 val_ev_ROC=0.548 val_ev_PR=0.603 val_win_ROC=0.684 crit=0.5884
#     ep=01 loss=0.7550 val_ev_ROC=0.548 val_ev_PR=0.600 val_win_ROC=0.594 crit=0.5615
#     ep=02 loss=0.2678 val_ev_ROC=0.500 val_ev_PR=0.584 val_win_ROC=0.622 crit=0.5365
#     ep=03 loss=0.0298 val_ev_ROC=0.500 val_ev_PR=0.643 val_win_ROC=0.646 crit=0.5437
#     ep=04 loss=0.0162 val_ev_ROC=0.452 val_ev_PR=0.630 val_win_ROC=0.648 crit=0.5111
#     ep=05 loss=0.0029 val_ev_ROC=0.476 val_ev_PR=0.637 val_win_ROC=0.635 crit=0.5240
#     ep=06 loss=0.0014 val_ev_ROC=0.500 val_ev_PR=0.646 val_win_ROC=0.618 crit=0.5354
#     ep=07 loss=0.0008 val_ev_ROC=0.476 val_ev_PR=0.637 val_win_ROC=0.608 crit=0.5158
#     ep=08 loss=0.0006 val_ev_ROC=0.452 val_ev_PR=0.582 val_win_ROC=0.602 crit=0.4974
#     ep=09 loss=0.0005 val_ev_ROC=0.452 val_ev_PR=0.582 val_win_ROC=0.600 crit=0.4966
#     early stop at epoch 9 (best crit=0.5615)
#     fold 4: tau=+1.5366  test TP=2 FN=2 FP=1 TN=3
#
# ==============================================================================================================
# MAIN  iTransformer (adapted)
# ==============================================================================================================
#   fold 0: train=33 val=12 test=13 events
#     ep=01 loss=0.8191 val_ev_ROC=0.429 val_ev_PR=0.536 val_win_ROC=0.384 crit=0.4152
#     ep=02 loss=0.2778 val_ev_ROC=0.486 val_ev_PR=0.497 val_win_ROC=0.336 crit=0.4408
#     ep=03 loss=0.0176 val_ev_ROC=0.514 val_ev_PR=0.469 val_win_ROC=0.304 crit=0.4511
#     ep=04 loss=0.0045 val_ev_ROC=0.514 val_ev_PR=0.469 val_win_ROC=0.305 crit=0.4514
#     ep=05 loss=0.0024 val_ev_ROC=0.486 val_ev_PR=0.455 val_win_ROC=0.314 crit=0.4341
#     ep=06 loss=0.0014 val_ev_ROC=0.457 val_ev_PR=0.421 val_win_ROC=0.322 crit=0.4166
#     ep=07 loss=0.0010 val_ev_ROC=0.429 val_ev_PR=0.411 val_win_ROC=0.329 crit=0.3986
#     ep=08 loss=0.0009 val_ev_ROC=0.429 val_ev_PR=0.411 val_win_ROC=0.336 crit=0.4008
#     ep=09 loss=0.0006 val_ev_ROC=0.429 val_ev_PR=0.411 val_win_ROC=0.340 crit=0.4019
#     ep=10 loss=0.0005 val_ev_ROC=0.429 val_ev_PR=0.411 val_win_ROC=0.342 crit=0.4025
#     ep=11 loss=0.0004 val_ev_ROC=0.400 val_ev_PR=0.391 val_win_ROC=0.341 crit=0.3823
#     ep=12 loss=0.0003 val_ev_ROC=0.400 val_ev_PR=0.391 val_win_ROC=0.339 crit=0.3818
#     early stop at epoch 12 (best crit=0.4514)
#     ep=01 loss=0.8323 val_ev_ROC=0.686 val_ev_PR=0.725 val_win_ROC=0.545 crit=0.6434
#     ep=02 loss=0.2764 val_ev_ROC=0.714 val_ev_PR=0.755 val_win_ROC=0.534 crit=0.6601
#     ep=03 loss=0.0117 val_ev_ROC=0.743 val_ev_PR=0.774 val_win_ROC=0.530 crit=0.6790
#     ep=04 loss=0.0033 val_ev_ROC=0.743 val_ev_PR=0.717 val_win_ROC=0.538 crit=0.6813
#     ep=05 loss=0.0017 val_ev_ROC=0.743 val_ev_PR=0.628 val_win_ROC=0.557 crit=0.6870
#     ep=06 loss=0.0010 val_ev_ROC=0.714 val_ev_PR=0.609 val_win_ROC=0.571 crit=0.6712
#     ep=07 loss=0.0007 val_ev_ROC=0.714 val_ev_PR=0.609 val_win_ROC=0.577 crit=0.6732
#     ep=08 loss=0.0005 val_ev_ROC=0.714 val_ev_PR=0.609 val_win_ROC=0.578 crit=0.6734
#     ep=09 loss=0.0004 val_ev_ROC=0.743 val_ev_PR=0.623 val_win_ROC=0.575 crit=0.6924
#     ep=10 loss=0.0003 val_ev_ROC=0.743 val_ev_PR=0.623 val_win_ROC=0.570 crit=0.6911
#     ep=11 loss=0.0003 val_ev_ROC=0.714 val_ev_PR=0.593 val_win_ROC=0.566 crit=0.6698
#     ep=12 loss=0.0002 val_ev_ROC=0.686 val_ev_PR=0.579 val_win_ROC=0.562 crit=0.6487
#     ep=13 loss=0.0002 val_ev_ROC=0.686 val_ev_PR=0.579 val_win_ROC=0.557 crit=0.6470
#     ep=14 loss=0.0002 val_ev_ROC=0.686 val_ev_PR=0.579 val_win_ROC=0.551 crit=0.6453
#     ep=15 loss=0.0002 val_ev_ROC=0.686 val_ev_PR=0.579 val_win_ROC=0.547 crit=0.6441
#     ep=16 loss=0.0002 val_ev_ROC=0.686 val_ev_PR=0.579 val_win_ROC=0.542 crit=0.6427
#     ep=17 loss=0.0001 val_ev_ROC=0.600 val_ev_PR=0.533 val_win_ROC=0.537 crit=0.5811
#     early stop at epoch 17 (best crit=0.6924)
#     ep=01 loss=0.7991 val_ev_ROC=0.343 val_ev_PR=0.397 val_win_ROC=0.322 crit=0.3366
#     ep=02 loss=0.2656 val_ev_ROC=0.429 val_ev_PR=0.446 val_win_ROC=0.369 crit=0.4106
#     ep=03 loss=0.0236 val_ev_ROC=0.343 val_ev_PR=0.371 val_win_ROC=0.387 crit=0.3562
#     ep=04 loss=0.0049 val_ev_ROC=0.343 val_ev_PR=0.371 val_win_ROC=0.394 crit=0.3582
#     ep=05 loss=0.0023 val_ev_ROC=0.343 val_ev_PR=0.371 val_win_ROC=0.401 crit=0.3603
#     ep=06 loss=0.0014 val_ev_ROC=0.343 val_ev_PR=0.371 val_win_ROC=0.404 crit=0.3613
#     ep=07 loss=0.0010 val_ev_ROC=0.343 val_ev_PR=0.372 val_win_ROC=0.405 crit=0.3614
#     ep=08 loss=0.0018 val_ev_ROC=0.371 val_ev_PR=0.383 val_win_ROC=0.402 crit=0.3805
#     ep=09 loss=0.0007 val_ev_ROC=0.371 val_ev_PR=0.383 val_win_ROC=0.390 crit=0.3771
#     ep=10 loss=0.0005 val_ev_ROC=0.371 val_ev_PR=0.383 val_win_ROC=0.382 crit=0.3747
#     early stop at epoch 10 (best crit=0.4106)
#     fold 0: tau=-0.6601  test TP=3 FN=3 FP=4 TN=3
#   fold 1: train=29 val=17 test=12 events
#     ep=01 loss=0.8301 val_ev_ROC=0.583 val_ev_PR=0.598 val_win_ROC=0.540 crit=0.5702
#     ep=02 loss=0.2965 val_ev_ROC=0.653 val_ev_PR=0.668 val_win_ROC=0.570 crit=0.6279
#     ep=03 loss=0.0170 val_ev_ROC=0.653 val_ev_PR=0.729 val_win_ROC=0.603 crit=0.6377
#     ep=04 loss=0.0042 val_ev_ROC=0.611 val_ev_PR=0.707 val_win_ROC=0.624 crit=0.6151
#     ep=05 loss=0.0023 val_ev_ROC=0.653 val_ev_PR=0.740 val_win_ROC=0.643 crit=0.6498
#     ep=06 loss=0.0015 val_ev_ROC=0.625 val_ev_PR=0.724 val_win_ROC=0.660 crit=0.6354
#     ep=07 loss=0.0010 val_ev_ROC=0.625 val_ev_PR=0.724 val_win_ROC=0.670 crit=0.6385
#     ep=08 loss=0.0007 val_ev_ROC=0.625 val_ev_PR=0.723 val_win_ROC=0.676 crit=0.6403
#     ep=09 loss=0.0005 val_ev_ROC=0.639 val_ev_PR=0.729 val_win_ROC=0.680 crit=0.6511
#     ep=10 loss=0.0004 val_ev_ROC=0.653 val_ev_PR=0.736 val_win_ROC=0.681 crit=0.6613
#     ep=11 loss=0.0004 val_ev_ROC=0.653 val_ev_PR=0.736 val_win_ROC=0.681 crit=0.6614
#     ep=12 loss=0.0003 val_ev_ROC=0.653 val_ev_PR=0.736 val_win_ROC=0.679 crit=0.6606
#     ep=13 loss=0.0003 val_ev_ROC=0.694 val_ev_PR=0.761 val_win_ROC=0.676 crit=0.6890
#     ep=14 loss=0.0002 val_ev_ROC=0.694 val_ev_PR=0.761 val_win_ROC=0.674 crit=0.6883
#     ep=15 loss=0.0002 val_ev_ROC=0.694 val_ev_PR=0.761 val_win_ROC=0.672 crit=0.6877
#     ep=16 loss=0.0002 val_ev_ROC=0.694 val_ev_PR=0.761 val_win_ROC=0.670 crit=0.6872
#     ep=17 loss=0.0002 val_ev_ROC=0.708 val_ev_PR=0.776 val_win_ROC=0.669 crit=0.6964
#     ep=18 loss=0.0001 val_ev_ROC=0.722 val_ev_PR=0.781 val_win_ROC=0.667 crit=0.7057
#     ep=19 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.666 crit=0.7151
#     ep=20 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.665 crit=0.7147
#     ep=21 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.664 crit=0.7145
#     ep=22 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.663 crit=0.7143
#     ep=23 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.663 crit=0.7141
#     ep=24 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.662 crit=0.7140
#     ep=25 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.662 crit=0.7139
#     ep=26 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.662 crit=0.7139
#     ep=27 loss=0.0001 val_ev_ROC=0.736 val_ev_PR=0.786 val_win_ROC=0.662 crit=0.7139
#     early stop at epoch 27 (best crit=0.7151)
#     ep=01 loss=0.8148 val_ev_ROC=0.333 val_ev_PR=0.439 val_win_ROC=0.461 crit=0.3716
#     ep=02 loss=0.2774 val_ev_ROC=0.361 val_ev_PR=0.505 val_win_ROC=0.470 crit=0.3937
#     ep=03 loss=0.0121 val_ev_ROC=0.375 val_ev_PR=0.522 val_win_ROC=0.490 crit=0.4096
#     ep=04 loss=0.0032 val_ev_ROC=0.403 val_ev_PR=0.568 val_win_ROC=0.519 crit=0.4375
#     ep=05 loss=0.0017 val_ev_ROC=0.403 val_ev_PR=0.522 val_win_ROC=0.547 crit=0.4461
#     ep=06 loss=0.0011 val_ev_ROC=0.444 val_ev_PR=0.543 val_win_ROC=0.575 crit=0.4836
#     ep=07 loss=0.0008 val_ev_ROC=0.444 val_ev_PR=0.535 val_win_ROC=0.599 crit=0.4909
#     ep=08 loss=0.0006 val_ev_ROC=0.486 val_ev_PR=0.568 val_win_ROC=0.619 crit=0.5260
#     ep=09 loss=0.0005 val_ev_ROC=0.500 val_ev_PR=0.577 val_win_ROC=0.635 crit=0.5405
#     ep=10 loss=0.0004 val_ev_ROC=0.486 val_ev_PR=0.565 val_win_ROC=0.647 crit=0.5344
#     ep=11 loss=0.0003 val_ev_ROC=0.500 val_ev_PR=0.570 val_win_ROC=0.656 crit=0.5469
#     ep=12 loss=0.0003 val_ev_ROC=0.542 val_ev_PR=0.623 val_win_ROC=0.664 crit=0.5783
#     ep=13 loss=0.0002 val_ev_ROC=0.528 val_ev_PR=0.582 val_win_ROC=0.667 crit=0.5696
#     ep=14 loss=0.0002 val_ev_ROC=0.542 val_ev_PR=0.587 val_win_ROC=0.670 crit=0.5803
#     ep=15 loss=0.0002 val_ev_ROC=0.542 val_ev_PR=0.587 val_win_ROC=0.673 crit=0.5811
#     ep=16 loss=0.0002 val_ev_ROC=0.514 val_ev_PR=0.579 val_win_ROC=0.676 crit=0.5624
#     ep=17 loss=0.0001 val_ev_ROC=0.514 val_ev_PR=0.579 val_win_ROC=0.678 crit=0.5630
#     ep=18 loss=0.0001 val_ev_ROC=0.514 val_ev_PR=0.579 val_win_ROC=0.679 crit=0.5635
#     ep=19 loss=0.0001 val_ev_ROC=0.514 val_ev_PR=0.579 val_win_ROC=0.681 crit=0.5640
#     ep=20 loss=0.0001 val_ev_ROC=0.514 val_ev_PR=0.579 val_win_ROC=0.682 crit=0.5644
#     ep=21 loss=0.0001 val_ev_ROC=0.514 val_ev_PR=0.579 val_win_ROC=0.683 crit=0.5647
#     ep=22 loss=0.0001 val_ev_ROC=0.528 val_ev_PR=0.591 val_win_ROC=0.684 crit=0.5747
#     ep=23 loss=0.0001 val_ev_ROC=0.528 val_ev_PR=0.591 val_win_ROC=0.685 crit=0.5749
#     early stop at epoch 23 (best crit=0.5811)
#     ep=01 loss=0.8098 val_ev_ROC=0.611 val_ev_PR=0.701 val_win_ROC=0.616 crit=0.6127
#     ep=02 loss=0.2698 val_ev_ROC=0.681 val_ev_PR=0.750 val_win_ROC=0.647 crit=0.6705
#     ep=03 loss=0.0190 val_ev_ROC=0.750 val_ev_PR=0.792 val_win_ROC=0.661 crit=0.7233
#     ep=04 loss=0.0052 val_ev_ROC=0.764 val_ev_PR=0.817 val_win_ROC=0.662 crit=0.7335
#     ep=05 loss=0.0025 val_ev_ROC=0.750 val_ev_PR=0.804 val_win_ROC=0.660 crit=0.7230
#     ep=06 loss=0.0016 val_ev_ROC=0.764 val_ev_PR=0.812 val_win_ROC=0.655 crit=0.7313
#     ep=07 loss=0.0011 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.652 crit=0.7693
#     ep=08 loss=0.0008 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.650 crit=0.7686
#     ep=09 loss=0.0006 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.649 crit=0.7682
#     ep=10 loss=0.0006 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.648 crit=0.7679
#     ep=11 loss=0.0004 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.646 crit=0.7675
#     ep=12 loss=0.0004 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.646 crit=0.7675
#     ep=13 loss=0.0003 val_ev_ROC=0.819 val_ev_PR=0.856 val_win_ROC=0.647 crit=0.7676
#     ep=14 loss=0.0003 val_ev_ROC=0.806 val_ev_PR=0.842 val_win_ROC=0.647 crit=0.7580
#     ep=15 loss=0.0003 val_ev_ROC=0.806 val_ev_PR=0.842 val_win_ROC=0.647 crit=0.7581
#     early stop at epoch 15 (best crit=0.7693)
#     fold 1: tau=+2.2203  test TP=0 FN=5 FP=1 TN=6
#   fold 2: train=33 val=8 test=17 events
#     ep=01 loss=0.8364 val_ev_ROC=0.688 val_ev_PR=0.646 val_win_ROC=0.607 crit=0.6632
#     ep=02 loss=0.3873 val_ev_ROC=0.562 val_ev_PR=0.604 val_win_ROC=0.624 crit=0.5809
#     ep=03 loss=0.0245 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.662 crit=0.6798
#     ep=04 loss=0.0043 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.686 crit=0.6870
#     ep=05 loss=0.0022 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.699 crit=0.6909
#     ep=06 loss=0.0013 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.705 crit=0.6927
#     ep=07 loss=0.0111 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.705 crit=0.6491
#     ep=08 loss=0.0008 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.705 crit=0.6489
#     ep=09 loss=0.0009 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.700 crit=0.6911
#     ep=10 loss=0.0005 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.700 crit=0.6475
#     ep=11 loss=0.0003 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.703 crit=0.6484
#     ep=12 loss=0.0003 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.706 crit=0.6055
#     ep=13 loss=0.0003 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.708 crit=0.6062
#     ep=14 loss=0.0002 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.710 crit=0.6067
#     early stop at epoch 14 (best crit=0.6927)
#     ep=01 loss=0.8319 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.612 crit=0.6648
#     ep=02 loss=0.3535 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.611 crit=0.6207
#     ep=03 loss=0.0168 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.617 crit=0.6664
#     ep=04 loss=0.0032 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.628 crit=0.6696
#     ep=05 loss=0.0017 val_ev_ROC=0.688 val_ev_PR=0.812 val_win_ROC=0.651 crit=0.6765
#     ep=06 loss=0.0010 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.680 crit=0.6414
#     ep=07 loss=0.0008 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.709 crit=0.6502
#     ep=08 loss=0.0005 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.733 crit=0.6574
#     ep=09 loss=0.0005 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.752 crit=0.6630
#     ep=10 loss=0.0004 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.764 crit=0.6666
#     ep=11 loss=0.0003 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.771 crit=0.6687
#     ep=12 loss=0.0003 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.775 crit=0.6701
#     ep=13 loss=0.0002 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.779 crit=0.7148
#     ep=14 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.781 crit=0.6719
#     ep=15 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.784 crit=0.6726
#     ep=16 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.784 crit=0.6728
#     ep=17 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.750 val_win_ROC=0.786 crit=0.6295
#     ep=18 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.750 val_win_ROC=0.787 crit=0.6299
#     ep=19 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.750 val_win_ROC=0.788 crit=0.6303
#     ep=20 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.750 val_win_ROC=0.790 crit=0.6306
#     ep=21 loss=0.0001 val_ev_ROC=0.562 val_ev_PR=0.750 val_win_ROC=0.791 crit=0.6309
#     early stop at epoch 21 (best crit=0.7148)
#     ep=01 loss=0.8292 val_ev_ROC=0.625 val_ev_PR=0.729 val_win_ROC=0.459 crit=0.5752
#     ep=02 loss=0.3354 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.504 crit=0.5887
#     ep=03 loss=0.0207 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.560 crit=0.6054
#     ep=04 loss=0.0048 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.598 crit=0.6607
#     ep=05 loss=0.0023 val_ev_ROC=0.625 val_ev_PR=0.768 val_win_ROC=0.625 crit=0.6249
#     ep=06 loss=0.0015 val_ev_ROC=0.625 val_ev_PR=0.768 val_win_ROC=0.648 crit=0.6319
#     ep=07 loss=0.0010 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.665 crit=0.6808
#     ep=08 loss=0.0008 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.680 crit=0.6853
#     ep=09 loss=0.0007 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.694 crit=0.6896
#     ep=10 loss=0.0005 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.708 crit=0.6937
#     ep=11 loss=0.0004 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.721 crit=0.6976
#     ep=12 loss=0.0004 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.732 crit=0.7008
#     ep=13 loss=0.0003 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.740 crit=0.7032
#     ep=14 loss=0.0003 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.747 crit=0.7055
#     ep=15 loss=0.0003 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.754 crit=0.6637
#     ep=16 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.759 crit=0.6653
#     ep=17 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.764 crit=0.6666
#     ep=18 loss=0.0002 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.768 crit=0.6241
#     ep=19 loss=0.0002 val_ev_ROC=0.562 val_ev_PR=0.692 val_win_ROC=0.772 crit=0.6253
#     ep=20 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.773 crit=0.6695
#     ep=21 loss=0.0002 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.776 crit=0.6703
#     ep=22 loss=0.0001 val_ev_ROC=0.625 val_ev_PR=0.710 val_win_ROC=0.779 crit=0.6712
#     early stop at epoch 22 (best crit=0.7055)
#     fold 2: tau=-0.0609  test TP=1 FN=7 FP=2 TN=7
#   fold 3: train=42 val=8 test=8 events
#     ep=01 loss=0.8418 val_ev_ROC=0.250 val_ev_PR=0.430 val_win_ROC=0.494 crit=0.3233
#     ep=02 loss=0.4358 val_ev_ROC=0.375 val_ev_PR=0.493 val_win_ROC=0.529 crit=0.4211
#     ep=03 loss=0.0850 val_ev_ROC=0.438 val_ev_PR=0.525 val_win_ROC=0.559 crit=0.4740
#     ep=04 loss=0.0060 val_ev_ROC=0.438 val_ev_PR=0.525 val_win_ROC=0.573 crit=0.4781
#     ep=05 loss=0.0025 val_ev_ROC=0.500 val_ev_PR=0.567 val_win_ROC=0.584 crit=0.5253
#     ep=06 loss=0.0014 val_ev_ROC=0.438 val_ev_PR=0.649 val_win_ROC=0.588 crit=0.4825
#     ep=07 loss=0.0068 val_ev_ROC=0.438 val_ev_PR=0.649 val_win_ROC=0.600 crit=0.4864
#     ep=08 loss=0.0009 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.605 crit=0.5314
#     ep=09 loss=0.0007 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.604 crit=0.5313
#     ep=10 loss=0.0005 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.605 crit=0.5316
#     ep=11 loss=0.0004 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.604 crit=0.5312
#     ep=12 loss=0.0003 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.603 crit=0.5308
#     ep=13 loss=0.0003 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.601 crit=0.5302
#     ep=14 loss=0.0003 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.598 crit=0.5294
#     ep=15 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.595 crit=0.5286
#     ep=16 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.593 crit=0.5279
#     ep=17 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.591 crit=0.5274
#     ep=18 loss=0.0002 val_ev_ROC=0.500 val_ev_PR=0.732 val_win_ROC=0.589 crit=0.5268
#     early stop at epoch 18 (best crit=0.5316)
#     ep=01 loss=0.8457 val_ev_ROC=0.562 val_ev_PR=0.585 val_win_ROC=0.494 crit=0.5419
#     ep=02 loss=0.4616 val_ev_ROC=0.500 val_ev_PR=0.543 val_win_ROC=0.502 crit=0.5005
#     ep=03 loss=0.0308 val_ev_ROC=0.500 val_ev_PR=0.643 val_win_ROC=0.514 crit=0.5043
#     ep=04 loss=0.0035 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.527 crit=0.5520
#     ep=05 loss=0.0023 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.536 crit=0.5545
#     ep=06 loss=0.0180 val_ev_ROC=0.500 val_ev_PR=0.560 val_win_ROC=0.549 crit=0.5146
#     ep=07 loss=0.0165 val_ev_ROC=0.375 val_ev_PR=0.500 val_win_ROC=0.554 crit=0.4288
#     ep=08 loss=0.0012 val_ev_ROC=0.375 val_ev_PR=0.607 val_win_ROC=0.558 crit=0.4300
#     ep=09 loss=0.0004 val_ev_ROC=0.375 val_ev_PR=0.600 val_win_ROC=0.552 crit=0.4282
#     ep=10 loss=0.0003 val_ev_ROC=0.312 val_ev_PR=0.582 val_win_ROC=0.551 crit=0.3840
#     ep=11 loss=0.0003 val_ev_ROC=0.312 val_ev_PR=0.582 val_win_ROC=0.550 crit=0.3837
#     ep=12 loss=0.0002 val_ev_ROC=0.312 val_ev_PR=0.582 val_win_ROC=0.548 crit=0.3832
#     ep=13 loss=0.0002 val_ev_ROC=0.250 val_ev_PR=0.457 val_win_ROC=0.547 crit=0.3390
#     early stop at epoch 13 (best crit=0.5545)
#     ep=01 loss=0.8189 val_ev_ROC=0.750 val_ev_PR=0.679 val_win_ROC=0.603 crit=0.7059
#     ep=02 loss=0.4015 val_ev_ROC=0.688 val_ev_PR=0.646 val_win_ROC=0.602 crit=0.6617
#     ep=03 loss=0.0470 val_ev_ROC=0.688 val_ev_PR=0.646 val_win_ROC=0.629 crit=0.6701
#     ep=04 loss=0.0055 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.656 crit=0.6780
#     ep=05 loss=0.0023 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.678 crit=0.6846
#     ep=06 loss=0.0023 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.695 crit=0.6898
#     ep=07 loss=0.0058 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.689 crit=0.6005
#     ep=08 loss=0.0008 val_ev_ROC=0.562 val_ev_PR=0.685 val_win_ROC=0.686 crit=0.5997
#     ep=09 loss=0.0006 val_ev_ROC=0.500 val_ev_PR=0.667 val_win_ROC=0.685 crit=0.5555
#     early stop at epoch 9 (best crit=0.7059)
#     fold 3: tau=+0.3229  test TP=1 FN=3 FP=0 TN=4
#   fold 4: train=37 val=13 test=8 events
#     ep=01 loss=0.8252 val_ev_ROC=0.405 val_ev_PR=0.435 val_win_ROC=0.500 crit=0.4333
#     ep=02 loss=0.3072 val_ev_ROC=0.357 val_ev_PR=0.419 val_win_ROC=0.519 crit=0.4056
#     ep=03 loss=0.0207 val_ev_ROC=0.405 val_ev_PR=0.463 val_win_ROC=0.540 crit=0.4454
#     ep=04 loss=0.0041 val_ev_ROC=0.405 val_ev_PR=0.463 val_win_ROC=0.557 crit=0.4503
#     ep=05 loss=0.0023 val_ev_ROC=0.476 val_ev_PR=0.494 val_win_ROC=0.565 crit=0.5028
#     ep=06 loss=0.0014 val_ev_ROC=0.524 val_ev_PR=0.522 val_win_ROC=0.569 crit=0.5373
#     ep=07 loss=0.0010 val_ev_ROC=0.548 val_ev_PR=0.550 val_win_ROC=0.571 crit=0.5547
#     ep=08 loss=0.0008 val_ev_ROC=0.571 val_ev_PR=0.566 val_win_ROC=0.573 crit=0.5718
#     ep=09 loss=0.0006 val_ev_ROC=0.595 val_ev_PR=0.591 val_win_ROC=0.573 crit=0.5887
#     ep=10 loss=0.0006 val_ev_ROC=0.595 val_ev_PR=0.591 val_win_ROC=0.574 crit=0.5889
#     ep=11 loss=0.0004 val_ev_ROC=0.595 val_ev_PR=0.591 val_win_ROC=0.576 crit=0.5894
#     ep=12 loss=0.0003 val_ev_ROC=0.595 val_ev_PR=0.591 val_win_ROC=0.577 crit=0.5897
#     ep=13 loss=0.0003 val_ev_ROC=0.595 val_ev_PR=0.591 val_win_ROC=0.577 crit=0.5898
#     ep=14 loss=0.0003 val_ev_ROC=0.619 val_ev_PR=0.600 val_win_ROC=0.577 crit=0.6065
#     ep=15 loss=0.0002 val_ev_ROC=0.619 val_ev_PR=0.600 val_win_ROC=0.578 crit=0.6067
#     ep=16 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.578 crit=0.6234
#     ep=17 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.578 crit=0.6234
#     ep=18 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.578 crit=0.6233
#     ep=19 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.577 crit=0.6232
#     ep=20 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.577 crit=0.6232
#     ep=21 loss=0.0001 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.577 crit=0.6231
#     ep=22 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.683 val_win_ROC=0.579 crit=0.6236
#     ep=23 loss=0.0002 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.581 crit=0.6410
#     ep=24 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.584 crit=0.6417
#     ep=25 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.585 crit=0.6422
#     ep=26 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.586 crit=0.6426
#     ep=27 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.587 crit=0.6428
#     ep=28 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.588 crit=0.6429
#     ep=29 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.588 crit=0.6431
#     ep=30 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6432
#     ep=31 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6433
#     ep=32 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6434
#     ep=33 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6434
#     ep=34 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6434
#     ep=35 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6434
#     ep=36 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6433
#     ep=37 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6433
#     ep=38 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.589 crit=0.6432
#     ep=39 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.588 crit=0.6432
#     ep=40 loss=0.0001 val_ev_ROC=0.667 val_ev_PR=0.739 val_win_ROC=0.588 crit=0.6432
#     ep=01 loss=0.8382 val_ev_ROC=0.405 val_ev_PR=0.501 val_win_ROC=0.526 crit=0.4410
#     ep=02 loss=0.3297 val_ev_ROC=0.381 val_ev_PR=0.474 val_win_ROC=0.536 crit=0.4275
#     ep=03 loss=0.0151 val_ev_ROC=0.381 val_ev_PR=0.463 val_win_ROC=0.545 crit=0.4303
#     ep=04 loss=0.0033 val_ev_ROC=0.357 val_ev_PR=0.441 val_win_ROC=0.562 crit=0.4186
#     ep=05 loss=0.0018 val_ev_ROC=0.429 val_ev_PR=0.541 val_win_ROC=0.572 crit=0.4715
#     ep=06 loss=0.0011 val_ev_ROC=0.429 val_ev_PR=0.543 val_win_ROC=0.564 crit=0.4693
#     ep=07 loss=0.0009 val_ev_ROC=0.429 val_ev_PR=0.543 val_win_ROC=0.562 crit=0.4686
#     ep=08 loss=0.0005 val_ev_ROC=0.476 val_ev_PR=0.577 val_win_ROC=0.560 crit=0.5014
#     ep=09 loss=0.0004 val_ev_ROC=0.524 val_ev_PR=0.594 val_win_ROC=0.559 crit=0.5344
#     ep=10 loss=0.0003 val_ev_ROC=0.595 val_ev_PR=0.702 val_win_ROC=0.558 crit=0.5840
#     ep=11 loss=0.0003 val_ev_ROC=0.619 val_ev_PR=0.744 val_win_ROC=0.557 crit=0.6003
#     ep=12 loss=0.0004 val_ev_ROC=0.619 val_ev_PR=0.744 val_win_ROC=0.558 crit=0.6007
# ...
#     ep=03 loss=0.0221 val_ev_ROC=0.500 val_ev_PR=0.615 val_win_ROC=0.460 crit=0.4880
#     ep=04 loss=0.0056 val_ev_ROC=0.486 val_ev_PR=0.567 val_win_ROC=0.446 crit=0.4740
#     ep=05 loss=0.0085 val_ev_ROC=0.431 val_ev_PR=0.530 val_win_ROC=0.436 crit=0.4321
#     ep=06 loss=0.0029 val_ev_ROC=0.417 val_ev_PR=0.524 val_win_ROC=0.435 crit=0.4221
#     ep=07 loss=0.0261 val_ev_ROC=0.403 val_ev_PR=0.528 val_win_ROC=0.426 crit=0.4097
#     ep=08 loss=0.0009 val_ev_ROC=0.403 val_ev_PR=0.528 val_win_ROC=0.422 crit=0.4085
#     ep=09 loss=0.0007 val_ev_ROC=0.417 val_ev_PR=0.541 val_win_ROC=0.421 crit=0.4181
#     ep=10 loss=0.0005 val_ev_ROC=0.431 val_ev_PR=0.545 val_win_ROC=0.425 crit=0.4290
#     ep=11 loss=0.0006 val_ev_ROC=0.431 val_ev_PR=0.545 val_win_ROC=0.430 crit=0.4304
#     early stop at epoch 11 (best crit=0.4880)
#     fold 1: tau=+0.3909  test TP=0 FN=5 FP=1 TN=6
#   fold 2: train=33 val=8 test=17 events
#     ep=01 loss=0.6750 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.420 crit=0.5635
#     ep=02 loss=0.1940 val_ev_ROC=0.438 val_ev_PR=0.518 val_win_ROC=0.422 crit=0.4328
#     ep=03 loss=0.0294 val_ev_ROC=0.438 val_ev_PR=0.618 val_win_ROC=0.474 crit=0.4485
#     ep=04 loss=0.0051 val_ev_ROC=0.438 val_ev_PR=0.618 val_win_ROC=0.497 crit=0.4552
#     ep=05 loss=0.0040 val_ev_ROC=0.438 val_ev_PR=0.618 val_win_ROC=0.521 crit=0.4626
#     ep=06 loss=0.0191 val_ev_ROC=0.438 val_ev_PR=0.618 val_win_ROC=0.512 crit=0.4597
#     ep=07 loss=0.0082 val_ev_ROC=0.500 val_ev_PR=0.643 val_win_ROC=0.530 crit=0.5089
#     ep=08 loss=0.0028 val_ev_ROC=0.500 val_ev_PR=0.643 val_win_ROC=0.533 crit=0.5098
#     ep=09 loss=0.0040 val_ev_ROC=0.500 val_ev_PR=0.643 val_win_ROC=0.522 crit=0.5066
#     early stop at epoch 9 (best crit=0.5635)
#     fold 2: tau=+0.1893  test TP=2 FN=6 FP=5 TN=4
#   fold 3: train=42 val=8 test=8 events
#     ep=01 loss=0.7540 val_ev_ROC=0.438 val_ev_PR=0.649 val_win_ROC=0.654 crit=0.5025
#     ep=02 loss=0.2636 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.754 crit=0.7076
#     ep=03 loss=0.0636 val_ev_ROC=0.875 val_ev_PR=0.887 val_win_ROC=0.824 crit=0.8598
#     ep=04 loss=0.0554 val_ev_ROC=1.000 val_ev_PR=1.000 val_win_ROC=0.828 crit=0.9484
#     ep=05 loss=0.0227 val_ev_ROC=0.875 val_ev_PR=0.917 val_win_ROC=0.828 crit=0.8608
#     ep=06 loss=0.0075 val_ev_ROC=0.812 val_ev_PR=0.893 val_win_ROC=0.825 crit=0.8163
#     ep=07 loss=0.0012 val_ev_ROC=0.750 val_ev_PR=0.875 val_win_ROC=0.833 crit=0.7750
#     ep=08 loss=0.0007 val_ev_ROC=0.750 val_ev_PR=0.875 val_win_ROC=0.837 crit=0.7761
#     ep=09 loss=0.0007 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.839 crit=0.7768
#     ep=10 loss=0.0007 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.843 crit=0.7778
#     ep=11 loss=0.0008 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.846 crit=0.7787
#     ep=12 loss=0.0003 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.850 crit=0.7799
#     early stop at epoch 12 (best crit=0.9484)
#     fold 3: tau=-0.6018  test TP=4 FN=0 FP=2 TN=2
#   fold 4: train=37 val=13 test=8 events
#     ep=01 loss=0.7118 val_ev_ROC=0.500 val_ev_PR=0.493 val_win_ROC=0.642 crit=0.5425
#     ep=02 loss=0.1848 val_ev_ROC=0.524 val_ev_PR=0.515 val_win_ROC=0.649 crit=0.5614
#     ep=03 loss=0.0279 val_ev_ROC=0.452 val_ev_PR=0.484 val_win_ROC=0.656 crit=0.5136
#     ep=04 loss=0.0462 val_ev_ROC=0.405 val_ev_PR=0.469 val_win_ROC=0.663 crit=0.4822
#     ep=05 loss=0.0064 val_ev_ROC=0.452 val_ev_PR=0.493 val_win_ROC=0.663 crit=0.5157
#     ep=06 loss=0.0015 val_ev_ROC=0.476 val_ev_PR=0.577 val_win_ROC=0.661 crit=0.5317
#     ep=07 loss=0.0230 val_ev_ROC=0.500 val_ev_PR=0.584 val_win_ROC=0.665 crit=0.5496
#     ep=08 loss=0.0097 val_ev_ROC=0.476 val_ev_PR=0.577 val_win_ROC=0.664 crit=0.5327
#     ep=09 loss=0.0010 val_ev_ROC=0.429 val_ev_PR=0.563 val_win_ROC=0.666 crit=0.4997
#     ep=10 loss=0.0034 val_ev_ROC=0.405 val_ev_PR=0.557 val_win_ROC=0.665 crit=0.4828
#     early stop at epoch 10 (best crit=0.5614)
#     fold 4: tau=+0.1398  test TP=3 FN=1 FP=3 TN=1
#
# ABLATION  A3 + Attentive Pooling  <- reusing the 'MS-WTFormer (Proposed)' runs (identical architecture)
#
# ==============================================================================================================
# ABLATION  A4 - context branch (10 h only)
# ==============================================================================================================
#   fold 0: train=33 val=12 test=13 events
#     ep=01 loss=0.6762 val_ev_ROC=0.371 val_ev_PR=0.416 val_win_ROC=0.591 crit=0.4372
#     ep=02 loss=0.1376 val_ev_ROC=0.571 val_ev_PR=0.603 val_win_ROC=0.728 crit=0.6183
#     ep=03 loss=0.0667 val_ev_ROC=0.657 val_ev_PR=0.600 val_win_ROC=0.772 crit=0.6917
#     ep=04 loss=0.0590 val_ev_ROC=0.543 val_ev_PR=0.526 val_win_ROC=0.766 crit=0.6097
#     ep=05 loss=0.0482 val_ev_ROC=0.429 val_ev_PR=0.475 val_win_ROC=0.714 crit=0.5141
#     ep=06 loss=0.0085 val_ev_ROC=0.371 val_ev_PR=0.403 val_win_ROC=0.643 crit=0.4528
#     ep=07 loss=0.0286 val_ev_ROC=0.343 val_ev_PR=0.388 val_win_ROC=0.584 crit=0.4153
#     ep=08 loss=0.0123 val_ev_ROC=0.314 val_ev_PR=0.372 val_win_ROC=0.530 crit=0.3789
#     ep=09 loss=0.0071 val_ev_ROC=0.286 val_ev_PR=0.358 val_win_ROC=0.481 crit=0.3443
#     ep=10 loss=0.0071 val_ev_ROC=0.286 val_ev_PR=0.358 val_win_ROC=0.447 crit=0.3342
#     ep=11 loss=0.0063 val_ev_ROC=0.200 val_ev_PR=0.330 val_win_ROC=0.421 crit=0.2664
#     early stop at epoch 11 (best crit=0.6917)
#     fold 0: tau=-0.0321  test TP=5 FN=1 FP=5 TN=2
#   fold 1: train=29 val=17 test=12 events
#     ep=01 loss=0.6484 val_ev_ROC=0.417 val_ev_PR=0.526 val_win_ROC=0.385 crit=0.4072
#     ep=02 loss=0.1001 val_ev_ROC=0.569 val_ev_PR=0.646 val_win_ROC=0.372 crit=0.5103
#     ep=03 loss=0.0121 val_ev_ROC=0.694 val_ev_PR=0.792 val_win_ROC=0.357 crit=0.5932
#     ep=04 loss=0.0055 val_ev_ROC=0.681 val_ev_PR=0.756 val_win_ROC=0.360 crit=0.5845
#     ep=05 loss=0.0332 val_ev_ROC=0.639 val_ev_PR=0.703 val_win_ROC=0.382 crit=0.5618
#     ep=06 loss=0.0028 val_ev_ROC=0.667 val_ev_PR=0.740 val_win_ROC=0.399 crit=0.5864
#     ep=07 loss=0.0011 val_ev_ROC=0.681 val_ev_PR=0.765 val_win_ROC=0.408 crit=0.5988
#     ep=08 loss=0.0007 val_ev_ROC=0.639 val_ev_PR=0.719 val_win_ROC=0.420 crit=0.5732
#     ep=09 loss=0.0005 val_ev_ROC=0.611 val_ev_PR=0.663 val_win_ROC=0.432 crit=0.5574
#     ep=10 loss=0.0004 val_ev_ROC=0.611 val_ev_PR=0.657 val_win_ROC=0.442 crit=0.5602
#     ep=11 loss=0.0003 val_ev_ROC=0.611 val_ev_PR=0.660 val_win_ROC=0.450 crit=0.5628
#     ep=12 loss=0.0006 val_ev_ROC=0.611 val_ev_PR=0.660 val_win_ROC=0.456 crit=0.5646
#     ep=13 loss=0.0003 val_ev_ROC=0.611 val_ev_PR=0.660 val_win_ROC=0.454 crit=0.5641
#     ep=14 loss=0.0002 val_ev_ROC=0.597 val_ev_PR=0.655 val_win_ROC=0.454 crit=0.5541
#     ep=15 loss=0.0002 val_ev_ROC=0.597 val_ev_PR=0.655 val_win_ROC=0.456 crit=0.5548
#     early stop at epoch 15 (best crit=0.5988)
#     fold 1: tau=-0.2396  test TP=0 FN=5 FP=2 TN=5
#   fold 2: train=33 val=8 test=17 events
#     ep=01 loss=0.6786 val_ev_ROC=0.375 val_ev_PR=0.476 val_win_ROC=0.336 crit=0.3632
#     ep=02 loss=0.1372 val_ev_ROC=0.375 val_ev_PR=0.476 val_win_ROC=0.394 crit=0.3807
#     ep=03 loss=0.0413 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.449 crit=0.5723
#     ep=04 loss=0.0182 val_ev_ROC=0.625 val_ev_PR=0.775 val_win_ROC=0.532 crit=0.5970
#     ep=05 loss=0.0027 val_ev_ROC=0.812 val_ev_PR=0.893 val_win_ROC=0.605 crit=0.7503
#     ep=06 loss=0.0105 val_ev_ROC=0.875 val_ev_PR=0.917 val_win_ROC=0.613 crit=0.7965
#     ep=07 loss=0.0017 val_ev_ROC=0.938 val_ev_PR=0.950 val_win_ROC=0.604 crit=0.8376
#     ep=08 loss=0.0007 val_ev_ROC=0.875 val_ev_PR=0.887 val_win_ROC=0.591 crit=0.7897
#     ep=09 loss=0.0006 val_ev_ROC=0.875 val_ev_PR=0.887 val_win_ROC=0.578 crit=0.7860
#     ep=10 loss=0.0004 val_ev_ROC=0.812 val_ev_PR=0.804 val_win_ROC=0.568 crit=0.7392
#     ep=11 loss=0.0003 val_ev_ROC=0.812 val_ev_PR=0.804 val_win_ROC=0.565 crit=0.7382
#     ep=12 loss=0.0003 val_ev_ROC=0.812 val_ev_PR=0.804 val_win_ROC=0.564 crit=0.7378
#     ep=13 loss=0.0097 val_ev_ROC=0.875 val_ev_PR=0.887 val_win_ROC=0.563 crit=0.7813
#     ep=14 loss=0.0284 val_ev_ROC=0.938 val_ev_PR=0.950 val_win_ROC=0.569 crit=0.8269
#     ep=15 loss=0.0470 val_ev_ROC=0.938 val_ev_PR=0.950 val_win_ROC=0.579 crit=0.8298
#     early stop at epoch 15 (best crit=0.8376)
#     fold 2: tau=-2.2925  test TP=5 FN=3 FP=3 TN=6
#   fold 3: train=42 val=8 test=8 events
#     ep=01 loss=0.7450 val_ev_ROC=0.625 val_ev_PR=0.608 val_win_ROC=0.455 crit=0.5739
#     ep=02 loss=0.3078 val_ev_ROC=0.562 val_ev_PR=0.567 val_win_ROC=0.540 crit=0.5556
#     ep=03 loss=0.0840 val_ev_ROC=0.688 val_ev_PR=0.733 val_win_ROC=0.615 crit=0.6656
#     ep=04 loss=0.0828 val_ev_ROC=0.688 val_ev_PR=0.646 val_win_ROC=0.672 crit=0.6828
#     ep=05 loss=0.0752 val_ev_ROC=0.688 val_ev_PR=0.646 val_win_ROC=0.700 crit=0.6912
#     ep=06 loss=0.0241 val_ev_ROC=0.688 val_ev_PR=0.646 val_win_ROC=0.717 crit=0.6964
#     ep=07 loss=0.0142 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.729 crit=0.6563
#     ep=08 loss=0.0115 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.736 crit=0.6584
#     ep=09 loss=0.0186 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.729 crit=0.6563
#     ep=10 loss=0.0054 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.706 crit=0.6492
#     ep=11 loss=0.0115 val_ev_ROC=0.625 val_ev_PR=0.622 val_win_ROC=0.686 crit=0.6434
#     ep=12 loss=0.0110 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.668 crit=0.6816
#     ep=13 loss=0.0011 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.664 crit=0.7241
#     ep=14 loss=0.0056 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.665 crit=0.7246
#     ep=15 loss=0.0220 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.681 crit=0.6855
#     ep=16 loss=0.0219 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.685 crit=0.6869
#     ep=17 loss=0.0157 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.687 crit=0.6873
#     ep=18 loss=0.0021 val_ev_ROC=0.688 val_ev_PR=0.793 val_win_ROC=0.693 crit=0.6893
#     ep=19 loss=0.0026 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.713 crit=0.7389
#     ep=20 loss=0.0066 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.724 crit=0.7422
#     ep=21 loss=0.0115 val_ev_ROC=0.750 val_ev_PR=0.830 val_win_ROC=0.722 crit=0.7417
#     ep=22 loss=0.0004 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.707 crit=0.6933
#     ep=23 loss=0.0020 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.703 crit=0.6923
#     ep=24 loss=0.0079 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.709 crit=0.6938
#     ep=25 loss=0.0002 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.714 crit=0.6955
#     ep=26 loss=0.0002 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.719 crit=0.6969
#     ep=27 loss=0.0004 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.723 crit=0.6980
#     ep=28 loss=0.0005 val_ev_ROC=0.688 val_ev_PR=0.747 val_win_ROC=0.731 crit=0.7006
#     early stop at epoch 28 (best crit=0.7422)
#     fold 3: tau=-3.0937  test TP=3 FN=1 FP=1 TN=3
#   fold 4: train=37 val=13 test=8 events
#     ep=01 loss=0.7200 val_ev_ROC=0.595 val_ev_PR=0.674 val_win_ROC=0.656 crit=0.6136
#     ep=02 loss=0.2247 val_ev_ROC=0.571 val_ev_PR=0.619 val_win_ROC=0.718 crit=0.6154
#     ep=03 loss=0.1278 val_ev_ROC=0.643 val_ev_PR=0.681 val_win_ROC=0.740 crit=0.6721
#     ep=04 loss=0.0481 val_ev_ROC=0.619 val_ev_PR=0.705 val_win_ROC=0.731 crit=0.6528
#     ep=05 loss=0.0216 val_ev_ROC=0.595 val_ev_PR=0.649 val_win_ROC=0.719 crit=0.6322
#     ep=06 loss=0.0279 val_ev_ROC=0.595 val_ev_PR=0.649 val_win_ROC=0.704 crit=0.6280
#     ep=07 loss=0.0147 val_ev_ROC=0.619 val_ev_PR=0.705 val_win_ROC=0.696 crit=0.6420
#     ep=08 loss=0.0135 val_ev_ROC=0.643 val_ev_PR=0.714 val_win_ROC=0.690 crit=0.6569
#     ep=09 loss=0.0135 val_ev_ROC=0.619 val_ev_PR=0.658 val_win_ROC=0.691 crit=0.6406
#     ep=10 loss=0.0075 val_ev_ROC=0.619 val_ev_PR=0.658 val_win_ROC=0.698 crit=0.6427
#     ep=11 loss=0.0056 val_ev_ROC=0.595 val_ev_PR=0.643 val_win_ROC=0.699 crit=0.6264
#     early stop at epoch 11 (best crit=0.6721)
#     fold 4: tau=+0.3789  test TP=0 FN=4 FP=0 TN=4
#
# ==============================================================================================================
# SECONDARY  frozen 32/13/13 split  —  MS-WTFormer (Proposed)
# ==============================================================================================================
#     ep=01 loss=0.7323 val_ev_ROC=0.619 val_ev_PR=0.574 val_win_ROC=0.646 crit=0.6270
#     ep=02 loss=0.1843 val_ev_ROC=0.667 val_ev_PR=0.577 val_win_ROC=0.693 crit=0.6745
#     ep=03 loss=0.0420 val_ev_ROC=0.619 val_ev_PR=0.629 val_win_ROC=0.712 crit=0.6470
#     ep=04 loss=0.0234 val_ev_ROC=0.571 val_ev_PR=0.632 val_win_ROC=0.715 crit=0.6144
#     ep=05 loss=0.0247 val_ev_ROC=0.619 val_ev_PR=0.713 val_win_ROC=0.720 crit=0.6493
#     ep=06 loss=0.0020 val_ev_ROC=0.571 val_ev_PR=0.691 val_win_ROC=0.716 crit=0.6147
#     ep=07 loss=0.0156 val_ev_ROC=0.571 val_ev_PR=0.691 val_win_ROC=0.711 crit=0.6132
#     ep=08 loss=0.0046 val_ev_ROC=0.548 val_ev_PR=0.666 val_win_ROC=0.705 crit=0.5948
#     ep=09 loss=0.0016 val_ev_ROC=0.595 val_ev_PR=0.699 val_win_ROC=0.708 crit=0.6289
#     ep=10 loss=0.0045 val_ev_ROC=0.595 val_ev_PR=0.699 val_win_ROC=0.709 crit=0.6295
#     early stop at epoch 10 (best crit=0.6745)
#     ep=01 loss=0.7181 val_ev_ROC=0.714 val_ev_PR=0.669 val_win_ROC=0.407 crit=0.6220
#     ep=02 loss=0.1601 val_ev_ROC=0.714 val_ev_PR=0.669 val_win_ROC=0.489 crit=0.6468
#     ep=03 loss=0.0324 val_ev_ROC=0.738 val_ev_PR=0.708 val_win_ROC=0.618 crit=0.7021
#     ep=04 loss=0.0158 val_ev_ROC=0.619 val_ev_PR=0.626 val_win_ROC=0.633 crit=0.6233
#     ep=05 loss=0.0098 val_ev_ROC=0.548 val_ev_PR=0.608 val_win_ROC=0.630 crit=0.5723
#     ep=06 loss=0.0029 val_ev_ROC=0.524 val_ev_PR=0.602 val_win_ROC=0.624 crit=0.5538
#     ep=07 loss=0.0121 val_ev_ROC=0.524 val_ev_PR=0.602 val_win_ROC=0.618 crit=0.5520
#     ep=08 loss=0.0073 val_ev_ROC=0.500 val_ev_PR=0.593 val_win_ROC=0.611 crit=0.5333
#     ep=09 loss=0.0143 val_ev_ROC=0.476 val_ev_PR=0.585 val_win_ROC=0.603 crit=0.5142
#     ep=10 loss=0.0009 val_ev_ROC=0.476 val_ev_PR=0.585 val_win_ROC=0.606 crit=0.5153
#     ep=11 loss=0.0067 val_ev_ROC=0.476 val_ev_PR=0.632 val_win_ROC=0.614 crit=0.5174
#     early stop at epoch 11 (best crit=0.7021)
#     ep=01 loss=0.6515 val_ev_ROC=0.476 val_ev_PR=0.486 val_win_ROC=0.466 crit=0.4733
#     ep=02 loss=0.1194 val_ev_ROC=0.571 val_ev_PR=0.552 val_win_ROC=0.598 crit=0.5794
#     ep=03 loss=0.0157 val_ev_ROC=0.667 val_ev_PR=0.672 val_win_ROC=0.663 crit=0.6657
#     ep=04 loss=0.0332 val_ev_ROC=0.643 val_ev_PR=0.663 val_win_ROC=0.695 crit=0.6585
#     ep=05 loss=0.0308 val_ev_ROC=0.619 val_ev_PR=0.695 val_win_ROC=0.683 crit=0.6383
#     ep=06 loss=0.0153 val_ev_ROC=0.595 val_ev_PR=0.683 val_win_ROC=0.681 crit=0.6210
#     ep=07 loss=0.0112 val_ev_ROC=0.619 val_ev_PR=0.711 val_win_ROC=0.705 crit=0.6448
#     ep=08 loss=0.0069 val_ev_ROC=0.643 val_ev_PR=0.753 val_win_ROC=0.716 crit=0.6648
#     ep=09 loss=0.0047 val_ev_ROC=0.690 val_ev_PR=0.767 val_win_ROC=0.722 crit=0.6998
#     ep=10 loss=0.0286 val_ev_ROC=0.690 val_ev_PR=0.767 val_win_ROC=0.711 crit=0.6965
#     ep=11 loss=0.0025 val_ev_ROC=0.714 val_ev_PR=0.776 val_win_ROC=0.713 crit=0.7139
#     ep=12 loss=0.0006 val_ev_ROC=0.714 val_ev_PR=0.776 val_win_ROC=0.714 crit=0.7141
#     ep=13 loss=0.0007 val_ev_ROC=0.714 val_ev_PR=0.776 val_win_ROC=0.716 crit=0.7148
#     ep=14 loss=0.0060 val_ev_ROC=0.714 val_ev_PR=0.776 val_win_ROC=0.722 crit=0.7165
#     ep=15 loss=0.0071 val_ev_ROC=0.690 val_ev_PR=0.734 val_win_ROC=0.721 crit=0.6998
#     ep=16 loss=0.0004 val_ev_ROC=0.690 val_ev_PR=0.734 val_win_ROC=0.723 crit=0.7003
#     ep=17 loss=0.0002 val_ev_ROC=0.667 val_ev_PR=0.725 val_win_ROC=0.725 crit=0.6843
#     ep=18 loss=0.0003 val_ev_ROC=0.667 val_ev_PR=0.725 val_win_ROC=0.726 crit=0.6844
#     ep=19 loss=0.0002 val_ev_ROC=0.667 val_ev_PR=0.758 val_win_ROC=0.726 crit=0.6843
#     ep=20 loss=0.0002 val_ev_ROC=0.667 val_ev_PR=0.758 val_win_ROC=0.726 crit=0.6844
#     ep=21 loss=0.0002 val_ev_ROC=0.643 val_ev_PR=0.748 val_win_ROC=0.725 crit=0.6676
#     ep=22 loss=0.0036 val_ev_ROC=0.643 val_ev_PR=0.748 val_win_ROC=0.725 crit=0.6674
#     early stop at epoch 22 (best crit=0.7165)
#
# All models trained. Event scores and window logits saved to /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4

# %%
# CELL 14 — Pooled metrics, cluster bootstrap, permutation tests

def pooled_metrics(oof):
    """
    PR-AUC / ROC-AUC pool scores produced by different folds. Report them as a pooled
    ranking summary of out-of-fold discrimination, not as a single calibrated model AUC.
    Threshold metrics are exact: each event was classified by its own fold's threshold.
    """
    y = oof.label.to_numpy(int)
    s = oof.score.to_numpy(float)
    p = oof.pred.to_numpy(int)
    tn, fp, fn, tp = confusion_matrix(y, p, labels=[0, 1]).ravel()
    return {
        "n_events": int(len(oof)), "n_pos": int(y.sum()),
        "PR-AUC": float(average_precision_score(y, s)),
        "ROC-AUC": float(roc_auc_score(y, s)),
        "Precision": float(precision_score(y, p, zero_division=0)),
        "Recall": float(recall_score(y, p, zero_division=0)),
        "F1": float(f1_score(y, p, zero_division=0)),
        "MCC": float(matthews_corrcoef(y, p)),
        "Balanced Accuracy": float(balanced_accuracy_score(y, p)),
        "Accuracy": float(accuracy_score(y, p)),
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp),
    }


def cluster_bootstrap(oof, n_boot=5000, seed=20260824):
    """Resample ASSETS: events from one turbine are not independent units."""
    rng = np.random.default_rng(seed)
    assets = oof.asset_id.unique()
    by = {a: oof[oof.asset_id == a] for a in assets}
    acc = {"PR-AUC": [], "ROC-AUC": [], "F1": [], "MCC": [], "Recall": []}
    for _ in range(n_boot):
        b = pd.concat([by[a] for a in rng.choice(assets, len(assets), replace=True)],
                      ignore_index=True)
        if b.label.nunique() < 2:
            continue
        acc["PR-AUC"].append(average_precision_score(b.label, b.score))
        acc["ROC-AUC"].append(roc_auc_score(b.label, b.score))
        acc["F1"].append(f1_score(b.label, b.pred, zero_division=0))
        acc["MCC"].append(matthews_corrcoef(b.label, b.pred))
        acc["Recall"].append(recall_score(b.label, b.pred, zero_division=0))
    out = {"n_valid_boot": len(acc["PR-AUC"])}
    for k, v in acc.items():
        out[f"{k} CI low"] = float(np.quantile(v, 0.025))
        out[f"{k} CI high"] = float(np.quantile(v, 0.975))
    return out


def paired_permutation(oof_a, oof_b, metric="PR-AUC", n_perm=10000, seed=1):
    """Asset-level paired permutation test for 'A discriminates better than B'."""
    a = oof_a.sort_values("event_id").reset_index(drop=True)
    b = oof_b.sort_values("event_id").reset_index(drop=True)
    assert (a.event_id.to_numpy() == b.event_id.to_numpy()).all()
    fn = average_precision_score if metric == "PR-AUC" else roc_auc_score
    y = a.label.to_numpy(int)
    sa, sb = a.score.to_numpy(float), b.score.to_numpy(float)
    obs = fn(y, sa) - fn(y, sb)
    rng = np.random.default_rng(seed)
    assets = a.asset_id.unique()
    cnt = 0
    for _ in range(n_perm):
        flip = a.asset_id.map({t: bool(rng.integers(0, 2)) for t in assets}).to_numpy()
        pa = np.where(flip, sb, sa)
        pb = np.where(flip, sa, sb)
        if abs(fn(y, pa) - fn(y, pb)) >= abs(obs):
            cnt += 1
    return obs, (cnt + 1) / (n_perm + 1)


results = pd.DataFrame([{"Model": nm, **pooled_metrics(o), **cluster_bootstrap(o)}
                        for nm, o in oof_bank.items()])
results = results.sort_values("PR-AUC", ascending=False).reset_index(drop=True)

abl_results = pd.DataFrame([{"Model": nm, **pooled_metrics(o), **cluster_bootstrap(o)}
                            for nm, o in abl_bank.items()])
abl_results["order"] = [list(ABLATION_MODELS).index(m) for m in abl_results.Model]
abl_results = abl_results.sort_values("order").drop(columns="order").reset_index(drop=True)

# Per-seed stability from the INNER-VALIDATION criterion, so no test peeking.
# Resumed runs return empty histories, hence the guard.
_h = [d for d in hist_bank.values() if len(d) and "criterion" in d.columns]
if _h:
    stability = (pd.concat(_h, ignore_index=True)
                   .sort_values(["model", "fold", "seed", "epoch"])
                   .groupby(["model", "fold", "seed"], as_index=False)
                   .agg(best_criterion=("criterion", "max"),
                        best_val_event_roc=("val_event_roc", "max"),
                        epochs_run=("epoch", "max"))
                   .groupby("model", as_index=False)
                   .agg(crit_mean=("best_criterion", "mean"),
                        crit_sd=("best_criterion", "std"),
                        val_ev_roc_mean=("best_val_event_roc", "mean"),
                        val_ev_roc_sd=("best_val_event_roc", "std"),
                        mean_epochs=("epochs_run", "mean")))
else:
    stability = pd.DataFrame(columns=["model", "crit_mean", "crit_sd",
                                      "val_ev_roc_mean", "val_ev_roc_sd", "mean_epochs"])
    print("NOTE: no training histories available (resumed run) - stability table skipped.")

frozen_metrics = metrics_from_event_df(frozen_test, tau=frozen_tau)

results.to_csv(RESULT / "MAIN_pooled_metrics_asset_bootstrap_CI.csv", index=False)
abl_results.to_csv(RESULT / "ABLATION_pooled_metrics.csv", index=False)
stability.to_csv(RESULT / "seed_stability_inner_validation.csv", index=False)

print("MAIN — 58 out-of-fold events, asset-grouped, 27 positives")
print(results[["Model", "PR-AUC", "PR-AUC CI low", "PR-AUC CI high",
               "ROC-AUC", "Recall", "Precision", "F1", "MCC",
               "TP", "FP", "TN", "FN"]].to_string(index=False))

print("\nPAIRED PERMUTATION TESTS vs " + PROPOSED)
for nm in oof_bank:
    if nm != PROPOSED:
        d, p = paired_permutation(oof_bank[PROPOSED], oof_bank[nm])
        print(f"  vs {nm:40s} dPR-AUC={d:+.3f}  p={p:.4f}")

print("\nSECONDARY — frozen 13-event split, " + PROPOSED)
print({k: (round(v, 4) if isinstance(v, float) else v) for k, v in frozen_metrics.items()})
# Out:
# MAIN — 58 out-of-fold events, asset-grouped, 27 positives
#                                Model   PR-AUC  PR-AUC CI low  PR-AUC CI high  ROC-AUC   Recall  Precision       F1       MCC  TP  FP  TN  FN
#                  ModernTCN (adapted) 0.620686       0.493160        0.755203 0.611708 0.629630   0.500000 0.557377  0.082281  17  17  14  10
#          TimeMixer++-style (adapted) 0.593292       0.505130        0.771172 0.611708 0.555556   0.468750 0.508475  0.007190  15  17  14  12
#               iTransformer (adapted) 0.541064       0.413916        0.718330 0.499403 0.222222   0.461538 0.300000 -0.004287   6   7  24  21
#               MS-WTFormer (Proposed) 0.538733       0.430003        0.723353 0.560335 0.555556   0.535714 0.545455  0.135957  15  13  18  12
#                    Plain Transformer 0.485072       0.413894        0.647277 0.500597 0.481481   0.500000 0.490566  0.062313  13  13  18  14
# Non-stationary Transformer (adapted) 0.472313       0.403257        0.623573 0.508961 0.370370   0.476190 0.416667  0.016120  10  11  20  17
#
# PAIRED PERMUTATION TESTS vs MS-WTFormer (Proposed)
#   vs Plain Transformer                        dPR-AUC=+0.054  p=0.3927
#   vs iTransformer (adapted)                   dPR-AUC=-0.002  p=0.9767
#   vs ModernTCN (adapted)                      dPR-AUC=-0.082  p=0.4218
#   vs TimeMixer++-style (adapted)              dPR-AUC=-0.055  p=0.5657
#   vs Non-stationary Transformer (adapted)     dPR-AUC=+0.066  p=0.3884
#
# SECONDARY — frozen 13-event split, MS-WTFormer (Proposed)
# {'PR-AUC': 0.3941, 'ROC-AUC': 0.2857, 'Precision': 0.4167, 'Recall': 0.8333, 'F1': 0.5556, 'MCC': -0.3118, 'Balanced Accuracy': 0.4167, 'Accuracy': 0.3846, 'TN': 0, 'FP': 7, 'FN': 1, 'TP': 5, 'Threshold': -2.5314}

# %%
# CELL 15 — Figure helpers, FIG1 main PR, FIG8 duration control

PALETTE = ["#0072B2", "#E69F00", "#009E73", "#CC79A7", "#56B4E9", "#6A3D9A", "#8B4513"]
DASHES = ["--", "-.", ":", (0, (5, 2)), (0, (3, 1, 1, 1)), (0, (1, 1)), (0, (6, 2, 1, 2))]


def style_for(names, highlight):
    out, k = {}, 0
    for n in names:
        if n == highlight:
            out[n] = ("#D55E00", "-", 3.3, 10)
        else:
            out[n] = (PALETTE[k % len(PALETTE)], DASHES[k % len(DASHES)], 1.9, 3)
            k += 1
    return out


def journal_axes(ax, grid=True):
    for sp in ("top", "right"):
        ax.spines[sp].set_visible(False)
    ax.tick_params(direction="in", length=5, width=0.9)
    if grid:
        ax.grid(True, linestyle="--", linewidth=0.55, alpha=0.18)
    ax.set_axisbelow(True)


def save_figure(fig, stem, tiff=False):
    fig.savefig(RESULT / f"{stem}.pdf", bbox_inches="tight")
    fig.savefig(RESULT / f"{stem}.png", dpi=600, bbox_inches="tight")
    if tiff:
        fig.savefig(RESULT / f"{stem}.tiff", dpi=600, bbox_inches="tight")
    print("saved:", stem)


def fig_curves(bank, names, kind, stem, highlight=PROPOSED, figsize=(7.3, 5.6)):
    """
    Step curves, not line plots: with a small discrete event set, interpolating between
    operating points draws points that do not exist.
    """
    st = style_for(names, highlight)
    fig, ax = plt.subplots(figsize=figsize)
    for nm in names:
        d = bank[nm]
        col, ls, lw, z = st[nm]
        y, s = d.label.to_numpy(int), d.score.to_numpy(float)
        if kind == "pr":
            p, r, _ = precision_recall_curve(y, s)
            ax.step(r, p, where="post", color=col, linestyle=ls, linewidth=lw, zorder=z,
                    label=f"{nm} (AP={average_precision_score(y, s):.3f})")
        else:
            fpr, tpr, _ = roc_curve(y, s)
            ax.step(fpr, tpr, where="post", color=col, linestyle=ls, linewidth=lw, zorder=z,
                    label=f"{nm} (AUC={roc_auc_score(y, s):.3f})")

    if kind == "pr":
        prev = bank[names[0]].label.mean()
        ax.axhline(prev, color="#777777", linestyle=(0, (4, 3)), linewidth=1.2,
                   label=f"Event prevalence ({prev:.3f})")
        ax.set_xlabel("Recall"); ax.set_ylabel("Precision")
        ax.legend(loc="lower left", frameon=False, handlelength=3.2, labelspacing=0.5)
    else:
        ax.plot([0, 1], [0, 1], color="#777777", linestyle=(0, (4, 3)), linewidth=1.2,
                label="Chance")
        ax.set_xlabel("False positive rate"); ax.set_ylabel("True positive rate")
        ax.legend(loc="lower right", frameon=False, handlelength=3.2, labelspacing=0.5)

    ax.set_xlim(0, 1.01); ax.set_ylim(0, 1.03)
    journal_axes(ax)
    fig.tight_layout()
    save_figure(fig, stem)
    plt.show()


def fig_duration_control(oof, stem="FIG8_duration_control"):
    """
    Anomaly events average 375.7 h vs 318.8 h for normal events, so a reviewer will ask
    whether duration alone explains the result. Answer it in the paper.
    """
    dmap = {s["event_id"]: (s["event_end_ns"] - s["event_start_ns"]) / 3.6e12 for s in STORE}
    d = oof.assign(duration_h=oof.event_id.map(dmap))
    auc_dur = roc_auc_score(d.label, d.duration_h)
    auc_mod = roc_auc_score(d.label, d.score)

    fig, ax = plt.subplots(figsize=(6.6, 5.0))
    for lab, mk, col in [(0, "o", "#222222"), (1, "s", "#D55E00")]:
        m = d.label == lab
        ax.scatter(d.duration_h[m], d.score[m], marker=mk, s=62, facecolor="white",
                   edgecolor=col, linewidth=1.4, label="Normal" if lab == 0 else "Fault")
    ax.set_xlabel("Event duration (h)")
    ax.set_ylabel("Out-of-fold event risk score")
    ax.set_title(f"duration-only AUC = {auc_dur:.3f}     model AUC = {auc_mod:.3f}")
    ax.legend(frameon=False)
    journal_axes(ax)
    fig.tight_layout()
    save_figure(fig, stem)
    plt.show()
    return auc_dur, auc_mod


MAIN_NAMES = list(MAIN_MODELS)
fig_curves(oof_bank, MAIN_NAMES, "pr", "FIG1_event_PR_main")
auc_dur, auc_mod = fig_duration_control(oof_bank[PROPOSED])

# %%
# CELL 16 — FIG2 main ROC

fig_curves(oof_bank, MAIN_NAMES, "roc", "FIG2_event_ROC_main")
# Out:
# saved: FIG2_event_ROC_main

# %%
# CELL 17 — Ablation table, FIG3 PR, FIG4 ROC

ABL_NAMES = list(ABLATION_MODELS)

ablation_table = abl_results[[
    "Model", "n_events", "n_pos",
    "PR-AUC", "PR-AUC CI low", "PR-AUC CI high",
    "ROC-AUC", "ROC-AUC CI low", "ROC-AUC CI high",
    "Precision", "Recall", "F1", "MCC",
    "TP", "FP", "TN", "FN",
]].copy()
ablation_table.to_csv(RESULT / "ABLATION_table.csv", index=False)

print("ABLATION LADDER (58 out-of-fold events)")
print(ablation_table.to_string(index=False))
print("\nReport this ladder as measured. Non-monotonic rungs are a result, not a defect:")
print("in the earlier V3 run the wavelet variant beat the full model on PR-AUC while the")
print("full model won ROC-AUC, recall, F1 and MCC.")

fig_curves(abl_bank, ABL_NAMES, "pr", "FIG3_ablation_PR",
           highlight="A3 + Attentive Pooling", figsize=(7.0, 5.4))
fig_curves(abl_bank, ABL_NAMES, "roc", "FIG4_ablation_ROC",
           highlight="A3 + Attentive Pooling", figsize=(7.0, 5.4))
# Out:
# ABLATION LADDER (58 out-of-fold events)
#                           Model  n_events  n_pos   PR-AUC  PR-AUC CI low  PR-AUC CI high  ROC-AUC  ROC-AUC CI low  ROC-AUC CI high  Precision   Recall       F1       MCC  TP  FP  TN  FN
#            A0 Plain Transformer        58     27 0.485072       0.413894        0.647277 0.500597        0.365181         0.639731   0.500000 0.481481 0.490566  0.062313  13  13  18  14
#       A1 + Multi-scale Temporal        58     27 0.519209       0.384002        0.708098 0.517324        0.346713         0.669137   0.550000 0.407407 0.468085  0.122873  11   9  22  16
#         A2 + Multi-scale + Haar        58     27 0.590125       0.477830        0.726217 0.578256        0.454283         0.705666   0.444444 0.444444 0.444444 -0.039427  12  15  16  15
#          A3 + Attentive Pooling        58     27 0.538733       0.430003        0.723353 0.560335        0.426517         0.700647   0.535714 0.555556 0.545455  0.135957  15  13  18  12
# A4 - context branch (10 h only)        58     27 0.508536       0.403190        0.693930 0.538829        0.394113         0.683358   0.541667 0.481481 0.509804  0.128262  13  11  20  14
#
# Report this ladder as measured. Non-monotonic rungs are a result, not a defect:
# in the earlier V3 run the wavelet variant beat the full model on PR-AUC while the
# full model won ROC-AUC, recall, F1 and MCC.
# saved: FIG3_ablation_PR
# saved: FIG4_ablation_ROC

# %%
# CELL 18 — FIG5 metric comparison (dot plot)

# Horizontal dot plot: a 19x10 inch grouped bar chart at font size 20 reads as a slide.
order = list(reversed(MAIN_NAMES))
md = results.set_index("Model").loc[order].reset_index()

fig, ax = plt.subplots(figsize=(7.6, 5.2))
ypos = np.arange(len(md))

for col, lab, mk in [("Recall", "Recall", "o"), ("F1", "F1", "s"), ("MCC", "MCC", "D")]:
    ax.scatter(md[col], ypos, marker=mk, s=76, facecolor="white",
               edgecolor="#222222", linewidth=1.35, label=lab, zorder=5)

hl = np.flatnonzero(md.Model.to_numpy() == PROPOSED)
if len(hl):
    ax.axhspan(hl[0] - 0.42, hl[0] + 0.42, color="#D55E00", alpha=0.08, zorder=0)

ax.set_yticks(ypos)
ax.set_yticklabels(md.Model)
ax.set_xlabel("Score (58 out-of-fold events)")
ax.set_xlim(0, 1.02)
journal_axes(ax)
ax.grid(axis="y", visible=False)
ax.legend(frameon=False, ncol=3, loc="lower right")
fig.tight_layout()
save_figure(fig, "FIG5_metric_comparison")
plt.show()
# Out:
# saved: FIG5_metric_comparison

# %%
# CELL 19 — FIG6 confusion matrices

def plot_confusion(oof, title, stem):
    """
    Built from oof.pred, which already carries each fold's own inner-validation
    threshold. There is no single global tau to re-apply, and no number is typed by hand.
    """
    cm = confusion_matrix(oof.label.to_numpy(int), oof.pred.to_numpy(int), labels=[0, 1])
    fig, ax = plt.subplots(figsize=(5.6, 5.1))
    ax.imshow(cm, cmap="Blues", vmin=0, vmax=max(1, cm.max()))
    for i in range(2):
        for j in range(2):
            ax.text(j, i, str(cm[i, j]), ha="center", va="center",
                    fontsize=24, fontweight="bold",
                    color="white" if cm[i, j] > 0.55 * cm.max() else "#111111")
    ax.set_xticks([0, 1]); ax.set_xticklabels(["Normal", "Fault event"])
    ax.set_yticks([0, 1]); ax.set_yticklabels(["Normal", "Fault event"])
    ax.set_xlabel("Predicted class"); ax.set_ylabel("True class")
    ax.set_title(f"{title}\n{len(oof)} events "
                 f"({int((oof.label == 0).sum())} normal, {int(oof.label.sum())} fault)")
    ax.tick_params(length=0)
    for sp in ax.spines.values():
        sp.set_visible(False)
    fig.tight_layout()
    save_figure(fig, stem)
    plt.show()
    return cm


cm_prop = plot_confusion(oof_bank[PROPOSED],
                         f"{PROPOSED} — pooled out-of-fold",
                         "FIG6A_proposed_confusion")

best_model = str(results.iloc[0]["Model"])
cm_best = plot_confusion(oof_bank[best_model],
                         f"Best pooled PR-AUC: {best_model}",
                         "FIG6B_best_model_confusion")

cm_frozen = plot_confusion(frozen_test,
                           f"{PROPOSED} — frozen 13-event split (secondary)",
                           "FIG6C_frozen_split_confusion")

print("proposed, pooled 58 events:\n", cm_prop)
print("\nfrozen 13-event split:\n", cm_frozen)
# Out:
# saved: FIG6A_proposed_confusion
# saved: FIG6B_best_model_confusion
# saved: FIG6C_frozen_split_confusion
# proposed, pooled 58 events:
#  [[18 13]
#  [12 15]]
#
# frozen 13-event split:
#  [[0 7]
#  [1 5]]

# %%
# CELL 20 — Operational rolling-6h alarm and lead-time evaluation

# Verify the lead-time reference point BEFORE trusting any number below.
_chk = event_info.assign(dur_h=(event_info.event_end_dt - event_info.event_start_dt)
                         .dt.total_seconds() / 3600.0)
print("EVENT FRAME DURATION BY CLASS (h)")
print(_chk.groupby("is_anomaly").dur_h.describe()[["count", "mean", "50%", "min", "max"]]
      .to_string())
print("\nlead_hours is measured as (event_end - first_alarm). If event_end is only the end")
print("of the CSV prediction section rather than the recorded fault time, lead times are")
print("inflated by the post-fault tail and must be restated in the manuscript.\n")


def rolling_risk(win_df, window=OP_WINDOW, q=TOP_FRACTION):
    """Rolling 6-h tail-mean of window logits, per event."""
    out = {}
    for eid, g in win_df.groupby("event_id", sort=True):
        g = g.sort_values("timestamp_ns").reset_index(drop=True)
        v = g.logit.to_numpy()
        risk = np.empty(len(v))
        for i in range(len(v)):
            seg = np.sort(v[max(0, i - window + 1):i + 1])
            k = max(1, int(math.ceil(q * len(seg))))
            risk[i] = seg[-k:].mean()
        out[int(eid)] = g.assign(rolling_risk=risk)
    return out


def _event_stat(roll, tail_q=OP_TAIL_Q):
    """Tail quantile, not max: a maximum over a longer sequence is larger for free."""
    return pd.DataFrame([{"event_id": e,
                          "asset_id": g.asset_id.iloc[0],
                          "label": int(g.label.iloc[0]),
                          "score": float(np.quantile(g.rolling_risk, tail_q))}
                         for e, g in roll.items()])


def operational_report(win_test, win_val):
    """
    Nested: within each fold the alarm threshold is derived from that fold's inner
    validation events, then applied to that fold's test events. Results are pooled.
    """
    ev_rows, lead_rows = [], []

    for fi in sorted(win_test.fold.unique()):
        rt = rolling_risk(win_test[win_test.fold == fi])
        rv = rolling_risk(win_val[win_val.fold == fi])

        vstat = _event_stat(rv)
        tau = choose_threshold(vstat.label.to_numpy(), vstat.score.to_numpy())

        tstat = _event_stat(rt)
        tstat["pred"] = (tstat.score >= tau).astype(int)
        tstat["fold"] = fi
        tstat["threshold"] = tau
        ev_rows.append(tstat)

        for e, g in rt.items():
            cr = g[g.rolling_risk >= tau]
            lead, first = np.nan, pd.NaT
            if len(cr):
                fns = int(cr.iloc[0].timestamp_ns)
                first = pd.to_datetime(fns)
                lead = (int(g.event_end_ns.iloc[0]) - fns) / 3.6e12
            lead_rows.append({
                "event_id": e, "asset_id": g.asset_id.iloc[0],
                "label": int(g.label.iloc[0]), "fold": fi,
                "alarmed": bool(len(cr) > 0), "first_alarm": first,
                "lead_hours": lead,
                "observed_hours": (g.timestamp_ns.max() - g.timestamp_ns.min()) / 3.6e12,
                "threshold": tau,
            })

    op_ev = pd.concat(ev_rows, ignore_index=True)
    lead_df = pd.DataFrame(lead_rows)

    an = lead_df[lead_df.label == 1]
    no = lead_df[lead_df.label == 0]
    horizons = np.array([1, 3, 6, 12, 24, 48, 72], dtype=float)
    frac = np.array([float(((an.alarmed) & (an.lead_hours >= h)).mean()) for h in horizons])

    # exposure-normalised false alarms, not "n of N events"
    fa_100d = (no.alarmed.sum() / max(no.observed_hours.sum() / 24.0, 1e-9)) * 100.0

    summary = {
        "faults_detected": f"{int(an.alarmed.sum())}/{len(an)}",
        "normal_events_with_alarm": f"{int(no.alarmed.sum())}/{len(no)}",
        "false_alarms_per_100_normal_event_days": round(float(fa_100d), 3),
        "median_lead_h": (round(float(an.loc[an.alarmed, "lead_hours"].median()), 2)
                          if an.alarmed.any() else None),
        "min_lead_h": (round(float(an.loc[an.alarmed, "lead_hours"].min()), 2)
                       if an.alarmed.any() else None),
        "max_lead_h": (round(float(an.loc[an.alarmed, "lead_hours"].max()), 2)
                       if an.alarmed.any() else None),
        **{f"detected_ge_{int(h)}h": round(float(f), 4) for h, f in zip(horizons, frac)},
    }
    return lead_df, op_ev, summary, horizons, frac


lead_df, op_ev, op_sum, horizons, fractions = operational_report(
    win_bank[PROPOSED]["test"], win_bank[PROPOSED]["val"])

op_metrics = metrics_from_event_df(op_ev, pred_col="pred")

lead_df.to_csv(RESULT / "OP_lead_times.csv", index=False)
pd.DataFrame({"lead_h": horizons, "detected_fraction": fractions}).to_csv(
    RESULT / "OP_leadtime_curve.csv", index=False)
with open(RESULT / "OP_summary.json", "w") as f:
    json.dump(op_sum, f, indent=2, default=str)

print("OPERATIONAL ROLLING-6H ANALYSIS — " + PROPOSED)
print(json.dumps(op_sum, indent=2, default=str))
print("\nevent-level metrics at the operational threshold:")
print({k: (round(v, 4) if isinstance(v, float) else v) for k, v in op_metrics.items()})

fig, ax = plt.subplots(figsize=(7.2, 5.1))
x = np.arange(len(horizons))
ax.plot(x, 100 * fractions, color="#D55E00", linewidth=2.8, marker="o", markersize=7,
        markerfacecolor="white", markeredgecolor="#D55E00", markeredgewidth=1.8)
for xi, v in zip(x, 100 * fractions):
    ax.annotate(f"{v:.1f}%", (xi, v), xytext=(0, 9), textcoords="offset points",
                ha="center", fontsize=10)
ax.axvline(list(horizons).index(6.0), color="#555555", linestyle=(0, (4, 3)), linewidth=1.1)
ax.set_xticks(x)
ax.set_xticklabels([str(int(h)) for h in horizons])
ax.set_xlabel("Minimum warning lead time (h)")
ax.set_ylabel("Detected fault events (%)")
ax.set_ylim(0, 103)
journal_axes(ax)
fig.tight_layout()
save_figure(fig, "FIG7_lead_time_curve")
plt.show()

# %%
# CELL 21 — Save event scores and protocol metadata

for nm, o in {**oof_bank, **abl_bank}.items():
    o.to_csv(RESULT / f"OOF_event_scores_{safe_name(nm)}.csv", index=False)

frozen_val.to_csv(RESULT / "FROZEN_val_event_scores_proposed.csv", index=False)

protocol = {
    "protocol_version": PROTOCOL_VERSION,
    "dataset": "CARE to Compare v6",
    "wind_farm": "C",
    "n_events": int(len(event_info)),
    "n_anomaly": int(event_info.is_anomaly.sum()),
    "n_normal": int((~event_info.is_anomaly).sum()),
    "n_assets": int(event_info.asset_id.nunique()),
    "input_channels_available": int(NF),
    "input_channels_used": int(NKEEP),
    "channel_hygiene_rules": ["degenerate baseline scale",
                              "cumulative/counter channels",
                              "clipping-rate label leakage"],
    "input": f"{LOOKBACK} x {NKEEP} 10-min window (10 h) + {NCTX}-dim baseline-deviation "
             f"context at 1 d / 7 d / 30 d",
    "normalisation": f"per-event historical healthy baseline, robust median/IQR, "
                     f"clipped at +/-{CLIP}",
    "status_policy": "status_type_id is never a model feature; abnormal-status endpoints "
                     "are excluded from the event frame",
    "training_objective": f"event-bag MIL: BCE(mean of top-{int(TOP_FRACTION*100)}% window "
                          f"logits, y_event) + {LAMBDA_NEG} * BCE(window logits, 0) on "
                          f"normal events only",
    "event_aggregation": f"mean of top {int(TOP_FRACTION*100)}% window logits "
                         f"(identical to the training statistic)",
    "checkpoint_selection": "0.7 * val event ROC-AUC + 0.3 * val window ROC-AUC, EMA weights",
    "operating_threshold": "inner validation only, 0.7 * MCC + 0.3 * F1",
    "primary_evaluation": f"{N_FOLDS}-fold asset-grouped nested CV over all 58 events; "
                          f"threshold from each fold's own inner validation",
    "secondary_evaluation": "frozen 32/13/13 asset-disjoint split",
    "uncertainty": "cluster bootstrap over assets (5000) + asset-level paired "
                   "permutation test (10000)",
    "operational_analysis": f"rolling {OP_WINDOW}-sample (6 h) tail-mean risk; event "
                            f"statistic = quantile {OP_TAIL_Q}; false alarms reported per "
                            f"100 normal-event days",
    "duration_control": {"duration_only_ROC_AUC": round(float(auc_dur), 4),
                         "model_ROC_AUC": round(float(auc_mod), 4)},
    "seeds": SEEDS,
    "test_role": "reporting only; never used for checkpoint, threshold or hyperparameter "
                 "selection",
    "modern_baseline_note": "Named modern architectures are task adaptations evaluated "
                            "under one common CARE protocol, not byte-identical "
                            "reproductions of external repositories.",
    "sample_size_note": "The independent test units are events (58 out-of-fold, 27 "
                        "positive). Windows are repeated overlapping observations of "
                        "those events and must never be reported as a sample size.",
}

with open(RESULT / "protocol.json", "w") as f:
    json.dump(protocol, f, indent=2)

print("Saved all event score files and protocol.json to", RESULT)
# Out:
# Saved all event score files and protocol.json to /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4

# %%
# CELL 22 — Final report

print("=" * 135)
print("CARE WIND FARM C — EVENT-LEVEL EARLY FAULT DETECTION")
print("=" * 135)

print("\nDATA")
print("  events              :", len(event_info))
print("  anomaly / normal    :", int(event_info.is_anomaly.sum()), "/",
      int((~event_info.is_anomaly).sum()))
print("  assets              :", event_info.asset_id.nunique())
print("  channels available  :", NF)
print("  channels used       :", NKEEP, "(after hygiene)")
print("  window              :", f"{LOOKBACK} x {NKEEP} = 10.0 h")
print("  context             :", f"{NCTX} dims (1 d / 7 d / 30 d baseline deviation)")
print("  seeds per fold      :", len(SEEDS))

print("\nPRIMARY — 5-fold asset-grouped nested CV, 58 events, 27 positive")
cols = ["Model", "PR-AUC", "PR-AUC CI low", "PR-AUC CI high",
        "ROC-AUC", "ROC-AUC CI low", "ROC-AUC CI high",
        "Precision", "Recall", "F1", "MCC",
        "Balanced Accuracy", "Accuracy", "TP", "FP", "TN", "FN"]
print(results[cols].to_string(index=False))

print("\nABLATION")
print(ablation_table.to_string(index=False))

print("\nSEED / FOLD STABILITY (inner-validation criterion, no test peeking)")
if len(stability):
    print(stability.sort_values("crit_mean", ascending=False).to_string(index=False))
else:
    print("  unavailable on a resumed run")

print("\nDURATION CONTROL")
print(f"  duration-only ROC-AUC : {auc_dur:.4f}")
print(f"  model ROC-AUC         : {auc_mod:.4f}")
if auc_dur > 0.65:
    print("  WARNING: event duration alone is informative. Report this control explicitly.")

ours = results[results.Model == PROPOSED].iloc[0]
rank = int((results["PR-AUC"] > ours["PR-AUC"]).sum() + 1)

print(f"\n{PROPOSED}")
for k in ["PR-AUC", "PR-AUC CI low", "PR-AUC CI high",
          "ROC-AUC", "ROC-AUC CI low", "ROC-AUC CI high",
          "Precision", "Recall", "F1", "MCC", "Balanced Accuracy", "Accuracy"]:
    print(f"  {k:22s}: {float(ours[k]):.4f}")
print(f"  {'pooled PR-AUC rank':22s}: {rank}/{len(results)}")

print("\nSECONDARY — frozen 13-event split")
for k, v in frozen_metrics.items():
    print(f"  {k:22s}: {v:.4f}" if isinstance(v, float) else f"  {k:22s}: {v}")

print("\nOPERATIONAL ROLLING-6H")
for k, v in op_sum.items():
    print(f"  {k:42s}: {v}")

if rank == 1:
    print(f"\nRANK STATEMENT: {PROPOSED} is #1 of {len(results)} by pooled PR-AUC.")
    print("Rank 1 is NOT significance. Quote the paired permutation p-values and note")
    print("that the 95% asset-bootstrap intervals overlap before making any claim.")
else:
    print(f"\nRANK STATEMENT: {PROPOSED} is #{rank} of {len(results)} by pooled PR-AUC.")
    print("Do NOT claim numerical SOTA from this benchmark.")

print("\nSAMPLE-SIZE STATEMENT FOR THE MANUSCRIPT")
print("  58 independent out-of-fold events (27 positive) from 22 asset-disjoint turbines.")
print("  Window counts are repeated, overlapping observations of those events and are")
print("  never reported as a sample size.")

print("\nOUTPUT DIRECTORY:", RESULT)
print("\nGENERATED FILES")
for p in sorted(RESULT.iterdir()):
    if p.is_file():
        print("  -", p.name)

print("=" * 135)
print("BENCHMARK COMPLETE")
print("=" * 135)
# Out:
# =======================================================================================================================================
# CARE WIND FARM C — EVENT-LEVEL EARLY FAULT DETECTION
# =======================================================================================================================================
#
# DATA
#   events              : 58
#   anomaly / normal    : 27 / 31
#   assets              : 22
#   channels available  : 238
#   channels used       : 234 (after hygiene)
#   window              : 60 x 234 = 10.0 h
#   context             : 702 dims (1 d / 7 d / 30 d baseline deviation)
#   seeds per fold      : 3
#
# PRIMARY — 5-fold asset-grouped nested CV, 58 events, 27 positive
#                                Model   PR-AUC  PR-AUC CI low  PR-AUC CI high  ROC-AUC  ROC-AUC CI low  ROC-AUC CI high  Precision   Recall       F1       MCC  Balanced Accuracy  Accuracy  TP  FP  TN  FN
#                  ModernTCN (adapted) 0.620686       0.493160        0.755203 0.611708        0.470895         0.742948   0.500000 0.629630 0.557377  0.082281           0.540621  0.534483  17  17  14  10
#          TimeMixer++-style (adapted) 0.593292       0.505130        0.771172 0.611708        0.478822         0.741343   0.468750 0.555556 0.508475  0.007190           0.503584  0.500000  15  17  14  12
#               iTransformer (adapted) 0.541064       0.413916        0.718330 0.499403        0.337035         0.683672   0.461538 0.222222 0.300000 -0.004287           0.498208  0.517241   6   7  24  21
#               MS-WTFormer (Proposed) 0.538733       0.430003        0.723353 0.560335        0.426517         0.700647   0.535714 0.555556 0.545455  0.135957           0.568100  0.568966  15  13  18  12
#                    Plain Transformer 0.485072       0.413894        0.647277 0.500597        0.365181         0.639731   0.500000 0.481481 0.490566  0.062313           0.531063  0.534483  13  13  18  14
# Non-stationary Transformer (adapted) 0.472313       0.403257        0.623573 0.508961        0.411234         0.617779   0.476190 0.370370 0.416667  0.016120           0.507766  0.517241  10  11  20  17
#
# ABLATION
#                           Model  n_events  n_pos   PR-AUC  PR-AUC CI low  PR-AUC CI high  ROC-AUC  ROC-AUC CI low  ROC-AUC CI high  Precision   Recall       F1       MCC  TP  FP  TN  FN
#            A0 Plain Transformer        58     27 0.485072       0.413894        0.647277 0.500597        0.365181         0.639731   0.500000 0.481481 0.490566  0.062313  13  13  18  14
#       A1 + Multi-scale Temporal        58     27 0.519209       0.384002        0.708098 0.517324        0.346713         0.669137   0.550000 0.407407 0.468085  0.122873  11   9  22  16
#         A2 + Multi-scale + Haar        58     27 0.590125       0.477830        0.726217 0.578256        0.454283         0.705666   0.444444 0.444444 0.444444 -0.039427  12  15  16  15
#          A3 + Attentive Pooling        58     27 0.538733       0.430003        0.723353 0.560335        0.426517         0.700647   0.535714 0.555556 0.545455  0.135957  15  13  18  12
# A4 - context branch (10 h only)        58     27 0.508536       0.403190        0.693930 0.538829        0.394113         0.683358   0.541667 0.481481 0.509804  0.128262  13  11  20  14
#
# SEED / FOLD STABILITY (inner-validation criterion, no test peeking)
#                                model  crit_mean  crit_sd  val_ev_roc_mean  val_ev_roc_sd  mean_epochs
#                  ModernTCN (adapted)   0.700040 0.103746         0.716362       0.112849    14.066667
#               MS-WTFormer (Proposed)   0.697580 0.145682         0.711984       0.179377    16.866667
#          TimeMixer++-style (adapted)   0.646642 0.145919         0.637063       0.159261    16.933333
# Non-stationary Transformer (adapted)   0.637165 0.086041         0.649854       0.108682    22.200000
#               iTransformer (adapted)   0.630919 0.104298         0.645450       0.110257    19.800000
#                    Plain Transformer   0.607013 0.105785         0.601138       0.139837    18.800000
#
# DURATION CONTROL
#   duration-only ROC-AUC : 0.5024
#   model ROC-AUC         : 0.5603
#
# MS-WTFormer (Proposed)
#   PR-AUC                : 0.5387
#   PR-AUC CI low         : 0.4300
#   PR-AUC CI high        : 0.7234
#   ROC-AUC               : 0.5603
#   ROC-AUC CI low        : 0.4265
#   ROC-AUC CI high       : 0.7006
#   Precision             : 0.5357
#   Recall                : 0.5556
#   F1                    : 0.5455
#   MCC                   : 0.1360
#   Balanced Accuracy     : 0.5681
#   Accuracy              : 0.5690
#   pooled PR-AUC rank    : 4/6
#
# SECONDARY — frozen 13-event split
#   PR-AUC                : 0.3941
#   ROC-AUC               : 0.2857
#   Precision             : 0.4167
#   Recall                : 0.8333
#   F1                    : 0.5556
#   MCC                   : -0.3118
#   Balanced Accuracy     : 0.4167
#   Accuracy              : 0.3846
#   TN                    : 0
#   FP                    : 7
#   FN                    : 1
#   TP                    : 5
#   Threshold             : -2.5314
#
# OPERATIONAL ROLLING-6H
#   faults_detected                           : 20/27
#   normal_events_with_alarm                  : 21/31
#   false_alarms_per_100_normal_event_days    : 5.107
#   median_lead_h                             : 323.33
#   min_lead_h                                : 1.0
#   max_lead_h                                : 1569.67
#   detected_ge_1h                            : 0.7407
#   detected_ge_3h                            : 0.7037
#   detected_ge_6h                            : 0.6667
#   detected_ge_12h                           : 0.6667
#   detected_ge_24h                           : 0.6667
#   detected_ge_48h                           : 0.5926
#   detected_ge_72h                           : 0.5556
#
# RANK STATEMENT: MS-WTFormer (Proposed) is #4 of 6 by pooled PR-AUC.
# Do NOT claim numerical SOTA from this benchmark.
#
# SAMPLE-SIZE STATEMENT FOR THE MANUSCRIPT
#   58 independent out-of-fold events (27 positive) from 22 asset-disjoint turbines.
#   Window counts are repeated, overlapping observations of those events and are
#   never reported as a sample size.
#
# OUTPUT DIRECTORY: /content/gdrive_care_final/MyDrive/Tarun/new dataset/CARE_WindFarmC_Project/results_CARE_C_EVENT_MIL_V4
#
# GENERATED FILES
#   - ABLATION_pooled_metrics.csv
#   - ABLATION_table.csv
#   - D5_classical_baseline_oof.csv
#   - FIG1_event_PR_main.pdf
#   - FIG1_event_PR_main.png
#   - FIG2_event_ROC_main.pdf
#   - FIG2_event_ROC_main.png
#   - FIG3_ablation_PR.pdf
#   - FIG3_ablation_PR.png
#   - FIG4_ablation_ROC.pdf
#   - FIG4_ablation_ROC.png
#   - FIG5_metric_comparison.pdf
#   - FIG5_metric_comparison.png
#   - FIG6A_proposed_confusion.pdf
#   - FIG6A_proposed_confusion.png
#   - FIG6B_best_model_confusion.pdf
#   - FIG6B_best_model_confusion.png
#   - FIG6C_frozen_split_confusion.pdf
#   - FIG6C_frozen_split_confusion.png
#   - FIG7_lead_time_curve.pdf
#   - FIG7_lead_time_curve.png
#   - FIG8_duration_control.pdf
#   - FIG8_duration_control.png
#   - FROZEN_split_test_event_scores.csv
#   - FROZEN_val_event_scores_proposed.csv
#   - MAIN_pooled_metrics_asset_bootstrap_CI.csv
#   - OOF_event_scores_A0_Plain_Transformer.csv
#   - OOF_event_scores_A1_plus_Multi_scale_Temporal.csv
#   - OOF_event_scores_A2_plus_Multi_scale_plus_Haar.csv
#   - OOF_event_scores_A3_plus_Attentive_Pooling.csv
#   - OOF_event_scores_A4___context_branch_10_h_only.csv
#   - OOF_event_scores_MS_WTFormer_Proposed.csv
#   - OOF_event_scores_ModernTCN_adapted.csv
#   - OOF_event_scores_Non_stationary_Transformer_adapted.csv
#   - OOF_event_scores_Plain_Transformer.csv
#   - OOF_event_scores_TimeMixerplusplus_style_adapted.csv
#   - OOF_event_scores_ablation.csv
#   - OOF_event_scores_iTransformer_adapted.csv
#   - OOF_event_scores_main.csv
#   - OOF_window_logits_proposed_test.csv
#   - OP_lead_times.csv
#   - OP_leadtime_curve.csv
#   - OP_summary.json
#   - asset_folds.csv
#   - channel_hygiene.csv
#   - event_split.csv
#   - protocol.json
#   - seed_stability_inner_validation.csv
#   - training_histories.csv
# =======================================================================================================================================
# BENCHMARK COMPLETE
# =======================================================================================================================================
